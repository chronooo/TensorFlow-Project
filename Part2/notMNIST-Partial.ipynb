# %% [markdown]
# #Original Author: Jonathan Hudson
# #CPSC 501 F22

# %%
import tensorflow as tf
import numpy as np

tf.random.set_seed(1234)

print("--Get data--")
with np.load("notMNIST.npz", allow_pickle=True) as f:
    x_train, y_train = f['x_train'], f['y_train']
    x_test, y_test = f['x_test'], f['y_test']

print("--Process data--")
x_train, x_test = x_train / 255.0, x_test / 255.0

x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)
input_shape = (28, 28, 1)
# Out:
# --Get data--
# --Process data--

# %%
print("--Make model--")
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28,1)),
  tf.keras.layers.Dense(64, activation='relu'),
  tf.keras.layers.Dense(64, activation='relu'),
  tf.keras.layers.Dense(10, activation='softmax'),
])
model.compile(optimizer='sgd', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

print("--Fit model--")
model.fit(x_train, y_train, epochs=100, verbose=2)
# Out:
# --Make model--
# --Fit model--
# Epoch 1/100
# 1875/1875 - 2s - loss: 0.7986 - accuracy: 0.7823 - 2s/epoch - 954us/step
# Epoch 2/100
# 1875/1875 - 2s - loss: 0.5975 - accuracy: 0.8307 - 2s/epoch - 852us/step
# Epoch 3/100
# 1875/1875 - 2s - loss: 0.5533 - accuracy: 0.8400 - 2s/epoch - 856us/step
# Epoch 4/100
# 1875/1875 - 2s - loss: 0.5267 - accuracy: 0.8458 - 2s/epoch - 846us/step
# Epoch 5/100
# 1875/1875 - 2s - loss: 0.5063 - accuracy: 0.8500 - 2s/epoch - 850us/step
# Epoch 6/100
# 1875/1875 - 2s - loss: 0.4901 - accuracy: 0.8552 - 2s/epoch - 866us/step
# Epoch 7/100
# 1875/1875 - 2s - loss: 0.4759 - accuracy: 0.8596 - 2s/epoch - 854us/step
# Epoch 8/100
# 1875/1875 - 2s - loss: 0.4635 - accuracy: 0.8627 - 2s/epoch - 878us/step
# Epoch 9/100
# 1875/1875 - 2s - loss: 0.4522 - accuracy: 0.8662 - 2s/epoch - 875us/step
# Epoch 10/100
# 1875/1875 - 2s - loss: 0.4420 - accuracy: 0.8683 - 2s/epoch - 852us/step
# Epoch 11/100
# 1875/1875 - 2s - loss: 0.4316 - accuracy: 0.8712 - 2s/epoch - 860us/step
# Epoch 12/100
# 1875/1875 - 2s - loss: 0.4233 - accuracy: 0.8744 - 2s/epoch - 856us/step
# Epoch 13/100
# 1875/1875 - 2s - loss: 0.4143 - accuracy: 0.8770 - 2s/epoch - 851us/step
# Epoch 14/100
# 1875/1875 - 2s - loss: 0.4062 - accuracy: 0.8793 - 2s/epoch - 856us/step
# Epoch 15/100
# 1875/1875 - 2s - loss: 0.3992 - accuracy: 0.8822 - 2s/epoch - 862us/step
# Epoch 16/100
# 1875/1875 - 2s - loss: 0.3914 - accuracy: 0.8828 - 2s/epoch - 861us/step
# Epoch 17/100
# 1875/1875 - 2s - loss: 0.3848 - accuracy: 0.8853 - 2s/epoch - 851us/step
# Epoch 18/100
# 1875/1875 - 2s - loss: 0.3782 - accuracy: 0.8875 - 2s/epoch - 859us/step
# Epoch 19/100
# 1875/1875 - 2s - loss: 0.3714 - accuracy: 0.8890 - 2s/epoch - 852us/step
# Epoch 20/100
# 1875/1875 - 2s - loss: 0.3659 - accuracy: 0.8909 - 2s/epoch - 860us/step
# Epoch 21/100
# 1875/1875 - 2s - loss: 0.3597 - accuracy: 0.8925 - 2s/epoch - 857us/step
# Epoch 22/100
# 1875/1875 - 2s - loss: 0.3550 - accuracy: 0.8933 - 2s/epoch - 861us/step
# Epoch 23/100
# 1875/1875 - 2s - loss: 0.3494 - accuracy: 0.8960 - 2s/epoch - 860us/step
# Epoch 24/100
# 1875/1875 - 2s - loss: 0.3441 - accuracy: 0.8972 - 2s/epoch - 851us/step
# Epoch 25/100
# 1875/1875 - 2s - loss: 0.3384 - accuracy: 0.8989 - 2s/epoch - 856us/step
# Epoch 26/100
# 1875/1875 - 2s - loss: 0.3333 - accuracy: 0.8999 - 2s/epoch - 866us/step
# Epoch 27/100
# 1875/1875 - 2s - loss: 0.3292 - accuracy: 0.9004 - 2s/epoch - 861us/step
# Epoch 28/100
# 1875/1875 - 2s - loss: 0.3249 - accuracy: 0.9028 - 2s/epoch - 852us/step
# Epoch 29/100
# 1875/1875 - 2s - loss: 0.3198 - accuracy: 0.9036 - 2s/epoch - 848us/step
# Epoch 30/100
# 1875/1875 - 2s - loss: 0.3155 - accuracy: 0.9051 - 2s/epoch - 847us/step
# Epoch 31/100
# 1875/1875 - 2s - loss: 0.3113 - accuracy: 0.9066 - 2s/epoch - 865us/step
# Epoch 32/100
# 1875/1875 - 2s - loss: 0.3067 - accuracy: 0.9081 - 2s/epoch - 858us/step
# Epoch 33/100
# 1875/1875 - 2s - loss: 0.3027 - accuracy: 0.9086 - 2s/epoch - 857us/step
# Epoch 34/100
# 1875/1875 - 2s - loss: 0.2975 - accuracy: 0.9108 - 2s/epoch - 854us/step
# Epoch 35/100
# 1875/1875 - 2s - loss: 0.2944 - accuracy: 0.9117 - 2s/epoch - 849us/step
# Epoch 36/100
# 1875/1875 - 2s - loss: 0.2905 - accuracy: 0.9128 - 2s/epoch - 854us/step
# Epoch 37/100
# 1875/1875 - 2s - loss: 0.2865 - accuracy: 0.9138 - 2s/epoch - 859us/step
# Epoch 38/100
# 1875/1875 - 2s - loss: 0.2831 - accuracy: 0.9150 - 2s/epoch - 863us/step
# Epoch 39/100
# 1875/1875 - 2s - loss: 0.2796 - accuracy: 0.9159 - 2s/epoch - 846us/step
# Epoch 40/100
# 1875/1875 - 2s - loss: 0.2751 - accuracy: 0.9173 - 2s/epoch - 858us/step
# Epoch 41/100
# 1875/1875 - 2s - loss: 0.2713 - accuracy: 0.9190 - 2s/epoch - 862us/step
# Epoch 42/100
# 1875/1875 - 2s - loss: 0.2685 - accuracy: 0.9189 - 2s/epoch - 844us/step
# Epoch 43/100
# 1875/1875 - 2s - loss: 0.2647 - accuracy: 0.9198 - 2s/epoch - 858us/step
# Epoch 44/100
# 1875/1875 - 2s - loss: 0.2609 - accuracy: 0.9224 - 2s/epoch - 854us/step
# Epoch 45/100
# 1875/1875 - 2s - loss: 0.2581 - accuracy: 0.9222 - 2s/epoch - 857us/step
# Epoch 46/100
# 1875/1875 - 2s - loss: 0.2538 - accuracy: 0.9241 - 2s/epoch - 847us/step
# Epoch 47/100
# 1875/1875 - 2s - loss: 0.2509 - accuracy: 0.9251 - 2s/epoch - 868us/step
# Epoch 48/100
# 1875/1875 - 2s - loss: 0.2478 - accuracy: 0.9260 - 2s/epoch - 862us/step
# Epoch 49/100
# 1875/1875 - 2s - loss: 0.2442 - accuracy: 0.9275 - 2s/epoch - 863us/step
# Epoch 50/100
# 1875/1875 - 2s - loss: 0.2417 - accuracy: 0.9274 - 2s/epoch - 856us/step
# Epoch 51/100
# 1875/1875 - 2s - loss: 0.2390 - accuracy: 0.9287 - 2s/epoch - 854us/step
# Epoch 52/100
# 1875/1875 - 2s - loss: 0.2350 - accuracy: 0.9295 - 2s/epoch - 851us/step
# Epoch 53/100
# 1875/1875 - 2s - loss: 0.2329 - accuracy: 0.9299 - 2s/epoch - 856us/step
# Epoch 54/100
# 1875/1875 - 2s - loss: 0.2297 - accuracy: 0.9310 - 2s/epoch - 854us/step
# Epoch 55/100
# 1875/1875 - 2s - loss: 0.2270 - accuracy: 0.9324 - 2s/epoch - 858us/step
# Epoch 56/100
# 1875/1875 - 2s - loss: 0.2233 - accuracy: 0.9336 - 2s/epoch - 862us/step
# Epoch 57/100
# 1875/1875 - 2s - loss: 0.2212 - accuracy: 0.9341 - 2s/epoch - 858us/step
# Epoch 58/100
# 1875/1875 - 2s - loss: 0.2179 - accuracy: 0.9349 - 2s/epoch - 863us/step
# Epoch 59/100
# 1875/1875 - 2s - loss: 0.2154 - accuracy: 0.9358 - 2s/epoch - 857us/step
# Epoch 60/100
# 1875/1875 - 2s - loss: 0.2127 - accuracy: 0.9367 - 2s/epoch - 850us/step
# Epoch 61/100
# 1875/1875 - 2s - loss: 0.2101 - accuracy: 0.9368 - 2s/epoch - 854us/step
# Epoch 62/100
# 1875/1875 - 2s - loss: 0.2074 - accuracy: 0.9379 - 2s/epoch - 863us/step
# Epoch 63/100
# 1875/1875 - 2s - loss: 0.2049 - accuracy: 0.9384 - 2s/epoch - 858us/step
# Epoch 64/100
# 1875/1875 - 2s - loss: 0.2016 - accuracy: 0.9393 - 2s/epoch - 848us/step
# Epoch 65/100
# 1875/1875 - 2s - loss: 0.2001 - accuracy: 0.9400 - 2s/epoch - 852us/step
# Epoch 66/100
# 1875/1875 - 2s - loss: 0.1971 - accuracy: 0.9417 - 2s/epoch - 865us/step
# Epoch 67/100
# 1875/1875 - 2s - loss: 0.1946 - accuracy: 0.9426 - 2s/epoch - 875us/step
# Epoch 68/100
# 1875/1875 - 2s - loss: 0.1918 - accuracy: 0.9435 - 2s/epoch - 861us/step
# Epoch 69/100
# 1875/1875 - 2s - loss: 0.1896 - accuracy: 0.9434 - 2s/epoch - 870us/step
# Epoch 70/100
# 1875/1875 - 2s - loss: 0.1887 - accuracy: 0.9438 - 2s/epoch - 865us/step
# Epoch 71/100
# 1875/1875 - 2s - loss: 0.1856 - accuracy: 0.9443 - 2s/epoch - 857us/step
# Epoch 72/100
# 1875/1875 - 2s - loss: 0.1833 - accuracy: 0.9459 - 2s/epoch - 855us/step
# Epoch 73/100
# 1875/1875 - 2s - loss: 0.1803 - accuracy: 0.9467 - 2s/epoch - 855us/step
# Epoch 74/100
# 1875/1875 - 2s - loss: 0.1773 - accuracy: 0.9478 - 2s/epoch - 858us/step
# Epoch 75/100
# 1875/1875 - 2s - loss: 0.1759 - accuracy: 0.9481 - 2s/epoch - 864us/step
# Epoch 76/100
# 1875/1875 - 2s - loss: 0.1731 - accuracy: 0.9496 - 2s/epoch - 863us/step
# Epoch 77/100
# 1875/1875 - 2s - loss: 0.1722 - accuracy: 0.9495 - 2s/epoch - 850us/step
# Epoch 78/100
# 1875/1875 - 2s - loss: 0.1695 - accuracy: 0.9501 - 2s/epoch - 857us/step
# Epoch 79/100
# 1875/1875 - 2s - loss: 0.1674 - accuracy: 0.9511 - 2s/epoch - 863us/step
# Epoch 80/100
# 1875/1875 - 2s - loss: 0.1652 - accuracy: 0.9519 - 2s/epoch - 861us/step
# Epoch 81/100
# 1875/1875 - 2s - loss: 0.1627 - accuracy: 0.9527 - 2s/epoch - 861us/step
# Epoch 82/100
# 1875/1875 - 2s - loss: 0.1614 - accuracy: 0.9530 - 2s/epoch - 860us/step
# Epoch 83/100
# 1875/1875 - 2s - loss: 0.1589 - accuracy: 0.9539 - 2s/epoch - 856us/step
# Epoch 84/100
# 1875/1875 - 2s - loss: 0.1572 - accuracy: 0.9541 - 2s/epoch - 935us/step
# Epoch 85/100
# 1875/1875 - 2s - loss: 0.1553 - accuracy: 0.9556 - 2s/epoch - 866us/step
# Epoch 86/100
# 1875/1875 - 2s - loss: 0.1536 - accuracy: 0.9554 - 2s/epoch - 864us/step
# Epoch 87/100
# 1875/1875 - 2s - loss: 0.1516 - accuracy: 0.9567 - 2s/epoch - 866us/step
# Epoch 88/100
# 1875/1875 - 2s - loss: 0.1491 - accuracy: 0.9569 - 2s/epoch - 936us/step
# Epoch 89/100
# 1875/1875 - 2s - loss: 0.1480 - accuracy: 0.9579 - 2s/epoch - 885us/step
# Epoch 90/100
# 1875/1875 - 2s - loss: 0.1462 - accuracy: 0.9585 - 2s/epoch - 865us/step
# Epoch 91/100
# 1875/1875 - 2s - loss: 0.1447 - accuracy: 0.9587 - 2s/epoch - 852us/step
# Epoch 92/100
# 1875/1875 - 2s - loss: 0.1423 - accuracy: 0.9592 - 2s/epoch - 852us/step
# Epoch 93/100
# 1875/1875 - 2s - loss: 0.1409 - accuracy: 0.9601 - 2s/epoch - 897us/step
# Epoch 94/100
# 1875/1875 - 2s - loss: 0.1380 - accuracy: 0.9606 - 2s/epoch - 924us/step
# Epoch 95/100
# 1875/1875 - 2s - loss: 0.1372 - accuracy: 0.9611 - 2s/epoch - 884us/step
# Epoch 96/100
# 1875/1875 - 2s - loss: 0.1347 - accuracy: 0.9623 - 2s/epoch - 856us/step
# Epoch 97/100
# 1875/1875 - 2s - loss: 0.1340 - accuracy: 0.9618 - 2s/epoch - 852us/step
# Epoch 98/100
# 1875/1875 - 2s - loss: 0.1322 - accuracy: 0.9629 - 2s/epoch - 857us/step
# Epoch 99/100
# 1875/1875 - 2s - loss: 0.1311 - accuracy: 0.9624 - 2s/epoch - 856us/step
# Epoch 100/100
# 1875/1875 - 2s - loss: 0.1293 - accuracy: 0.9640 - 2s/epoch - 851us/step

# %%
print("--Evaluate model--")
model_loss1, model_acc1 = model.evaluate(x_train,  y_train, verbose=2)
model_loss2, model_acc2 = model.evaluate(x_test,  y_test, verbose=2)
print(f"Train / Test Accuracy: {model_acc1*100:.1f}% / {model_acc2*100:.1f}%")
model.save("notMNIST_partial_model", save_format="h5")
# Out:
# --Evaluate model--
# 1875/1875 - 1s - loss: 0.1183 - accuracy: 0.9682 - 1s/epoch - 716us/step
# 313/313 - 0s - loss: 0.3504 - accuracy: 0.9250 - 311ms/epoch - 994us/step
# Train / Test Accuracy: 96.8% / 92.5%
