# %% [markdown]
# #Original Author: Jonathan Hudson
# #CPSC 501 F22

# %%
import tensorflow as tf
import numpy as np

tf.random.set_seed(1234)

print("--Get data--")
with np.load("notMNIST.npz", allow_pickle=True) as f:
    x_train, y_train = f['x_train'], f['y_train']
    x_test, y_test = f['x_test'], f['y_test']

print("--Process data--")
x_train, x_test = x_train / 255.0, x_test / 255.0

x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)
input_shape = (28, 28, 1)
# Out:
# --Get data--
# --Process data--

# %%
print("--Make model--")
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28,1)),
  tf.keras.layers.Dense(64, activation='relu'),
  tf.keras.layers.Dense(64, activation='relu'),
  tf.keras.layers.Dense(10, activation='softmax'),
])
model.compile(optimizer='sgd', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

print("--Fit model--")
model.fit(x_train, y_train, epochs=100, verbose=2)
# Out:
# --Make model--
# --Fit model--
# Epoch 1/100
# 1875/1875 - 2s - loss: 0.8237 - accuracy: 0.7729 - 2s/epoch - 960us/step
# Epoch 2/100
# 1875/1875 - 2s - loss: 0.6065 - accuracy: 0.8282 - 2s/epoch - 860us/step
# Epoch 3/100
# 1875/1875 - 2s - loss: 0.5603 - accuracy: 0.8386 - 2s/epoch - 855us/step
# Epoch 4/100
# 1875/1875 - 2s - loss: 0.5306 - accuracy: 0.8453 - 2s/epoch - 847us/step
# Epoch 5/100
# 1875/1875 - 2s - loss: 0.5091 - accuracy: 0.8492 - 2s/epoch - 874us/step
# Epoch 6/100
# 1875/1875 - 2s - loss: 0.4916 - accuracy: 0.8542 - 2s/epoch - 861us/step
# Epoch 7/100
# 1875/1875 - 2s - loss: 0.4770 - accuracy: 0.8581 - 2s/epoch - 854us/step
# Epoch 8/100
# 1875/1875 - 2s - loss: 0.4639 - accuracy: 0.8618 - 2s/epoch - 857us/step
# Epoch 9/100
# 1875/1875 - 2s - loss: 0.4525 - accuracy: 0.8651 - 2s/epoch - 852us/step
# Epoch 10/100
# 1875/1875 - 2s - loss: 0.4419 - accuracy: 0.8684 - 2s/epoch - 852us/step
# Epoch 11/100
# 1875/1875 - 2s - loss: 0.4318 - accuracy: 0.8710 - 2s/epoch - 854us/step
# Epoch 12/100
# 1875/1875 - 2s - loss: 0.4235 - accuracy: 0.8738 - 2s/epoch - 850us/step
# Epoch 13/100
# 1875/1875 - 2s - loss: 0.4142 - accuracy: 0.8758 - 2s/epoch - 860us/step
# Epoch 14/100
# 1875/1875 - 2s - loss: 0.4066 - accuracy: 0.8780 - 2s/epoch - 872us/step
# Epoch 15/100
# 1875/1875 - 2s - loss: 0.3995 - accuracy: 0.8800 - 2s/epoch - 861us/step
# Epoch 16/100
# 1875/1875 - 2s - loss: 0.3920 - accuracy: 0.8825 - 2s/epoch - 858us/step
# Epoch 17/100
# 1875/1875 - 2s - loss: 0.3855 - accuracy: 0.8835 - 2s/epoch - 856us/step
# Epoch 18/100
# 1875/1875 - 2s - loss: 0.3792 - accuracy: 0.8874 - 2s/epoch - 855us/step
# Epoch 19/100
# 1875/1875 - 2s - loss: 0.3725 - accuracy: 0.8885 - 2s/epoch - 856us/step
# Epoch 20/100
# 1875/1875 - 2s - loss: 0.3671 - accuracy: 0.8896 - 2s/epoch - 875us/step
# Epoch 21/100
# 1875/1875 - 2s - loss: 0.3612 - accuracy: 0.8919 - 2s/epoch - 856us/step
# Epoch 22/100
# 1875/1875 - 2s - loss: 0.3558 - accuracy: 0.8932 - 2s/epoch - 865us/step
# Epoch 23/100
# 1875/1875 - 2s - loss: 0.3507 - accuracy: 0.8941 - 2s/epoch - 855us/step
# Epoch 24/100
# 1875/1875 - 2s - loss: 0.3455 - accuracy: 0.8962 - 2s/epoch - 853us/step
# Epoch 25/100
# 1875/1875 - 2s - loss: 0.3402 - accuracy: 0.8978 - 2s/epoch - 869us/step
# Epoch 26/100
# 1875/1875 - 2s - loss: 0.3352 - accuracy: 0.8981 - 2s/epoch - 861us/step
# Epoch 27/100
# 1875/1875 - 2s - loss: 0.3311 - accuracy: 0.9010 - 2s/epoch - 853us/step
# Epoch 28/100
# 1875/1875 - 2s - loss: 0.3266 - accuracy: 0.9021 - 2s/epoch - 858us/step
# Epoch 29/100
# 1875/1875 - 2s - loss: 0.3216 - accuracy: 0.9035 - 2s/epoch - 863us/step
# Epoch 30/100
# 1875/1875 - 2s - loss: 0.3172 - accuracy: 0.9042 - 2s/epoch - 875us/step
# Epoch 31/100
# 1875/1875 - 2s - loss: 0.3135 - accuracy: 0.9061 - 2s/epoch - 874us/step
# Epoch 32/100
# 1875/1875 - 2s - loss: 0.3095 - accuracy: 0.9061 - 2s/epoch - 863us/step
# Epoch 33/100
# 1875/1875 - 2s - loss: 0.3050 - accuracy: 0.9076 - 2s/epoch - 852us/step
# Epoch 34/100
# 1875/1875 - 2s - loss: 0.3003 - accuracy: 0.9096 - 2s/epoch - 855us/step
# Epoch 35/100
# 1875/1875 - 2s - loss: 0.2975 - accuracy: 0.9103 - 2s/epoch - 865us/step
# Epoch 36/100
# 1875/1875 - 2s - loss: 0.2928 - accuracy: 0.9114 - 2s/epoch - 866us/step
# Epoch 37/100
# 1875/1875 - 2s - loss: 0.2895 - accuracy: 0.9125 - 2s/epoch - 849us/step
# Epoch 38/100
# 1875/1875 - 2s - loss: 0.2862 - accuracy: 0.9129 - 2s/epoch - 857us/step
# Epoch 39/100
# 1875/1875 - 2s - loss: 0.2826 - accuracy: 0.9150 - 2s/epoch - 863us/step
# Epoch 40/100
# 1875/1875 - 2s - loss: 0.2784 - accuracy: 0.9167 - 2s/epoch - 863us/step
# Epoch 41/100
# 1875/1875 - 2s - loss: 0.2748 - accuracy: 0.9175 - 2s/epoch - 851us/step
# Epoch 42/100
# 1875/1875 - 2s - loss: 0.2716 - accuracy: 0.9175 - 2s/epoch - 853us/step
# Epoch 43/100
# 1875/1875 - 2s - loss: 0.2680 - accuracy: 0.9194 - 2s/epoch - 866us/step
# Epoch 44/100
# 1875/1875 - 2s - loss: 0.2653 - accuracy: 0.9197 - 2s/epoch - 932us/step
# Epoch 45/100
# 1875/1875 - 2s - loss: 0.2613 - accuracy: 0.9207 - 2s/epoch - 852us/step
# Epoch 46/100
# 1875/1875 - 2s - loss: 0.2578 - accuracy: 0.9222 - 2s/epoch - 866us/step
# Epoch 47/100
# 1875/1875 - 2s - loss: 0.2556 - accuracy: 0.9234 - 2s/epoch - 865us/step
# Epoch 48/100
# 1875/1875 - 2s - loss: 0.2516 - accuracy: 0.9236 - 2s/epoch - 934us/step
# Epoch 49/100
# 1875/1875 - 2s - loss: 0.2485 - accuracy: 0.9256 - 2s/epoch - 884us/step
# Epoch 50/100
# 1875/1875 - 2s - loss: 0.2462 - accuracy: 0.9256 - 2s/epoch - 870us/step
# Epoch 51/100
# 1875/1875 - 2s - loss: 0.2434 - accuracy: 0.9264 - 2s/epoch - 852us/step
# Epoch 52/100
# 1875/1875 - 2s - loss: 0.2400 - accuracy: 0.9274 - 2s/epoch - 854us/step
# Epoch 53/100
# 1875/1875 - 2s - loss: 0.2372 - accuracy: 0.9283 - 2s/epoch - 944us/step
# Epoch 54/100
# 1875/1875 - 2s - loss: 0.2342 - accuracy: 0.9305 - 2s/epoch - 904us/step
# Epoch 55/100
# 1875/1875 - 2s - loss: 0.2314 - accuracy: 0.9297 - 2s/epoch - 881us/step
# Epoch 56/100
# 1875/1875 - 2s - loss: 0.2286 - accuracy: 0.9316 - 2s/epoch - 864us/step
# Epoch 57/100
# 1875/1875 - 2s - loss: 0.2256 - accuracy: 0.9321 - 2s/epoch - 864us/step
# Epoch 58/100
# 1875/1875 - 2s - loss: 0.2236 - accuracy: 0.9323 - 2s/epoch - 867us/step
# Epoch 59/100
# 1875/1875 - 2s - loss: 0.2203 - accuracy: 0.9340 - 2s/epoch - 853us/step
# Epoch 60/100
# 1875/1875 - 2s - loss: 0.2179 - accuracy: 0.9353 - 2s/epoch - 847us/step
# Epoch 61/100
# 1875/1875 - 2s - loss: 0.2149 - accuracy: 0.9360 - 2s/epoch - 858us/step
# Epoch 62/100
# 1875/1875 - 2s - loss: 0.2128 - accuracy: 0.9369 - 2s/epoch - 857us/step
# Epoch 63/100
# 1875/1875 - 2s - loss: 0.2095 - accuracy: 0.9373 - 2s/epoch - 862us/step
# Epoch 64/100
# 1875/1875 - 2s - loss: 0.2079 - accuracy: 0.9383 - 2s/epoch - 860us/step
# Epoch 65/100
# 1875/1875 - 2s - loss: 0.2063 - accuracy: 0.9379 - 2s/epoch - 861us/step
# Epoch 66/100
# 1875/1875 - 2s - loss: 0.2023 - accuracy: 0.9393 - 2s/epoch - 855us/step
# Epoch 67/100
# 1875/1875 - 2s - loss: 0.2010 - accuracy: 0.9399 - 2s/epoch - 850us/step
# Epoch 68/100
# 1875/1875 - 2s - loss: 0.1981 - accuracy: 0.9405 - 2s/epoch - 869us/step
# Epoch 69/100
# 1875/1875 - 2s - loss: 0.1955 - accuracy: 0.9416 - 2s/epoch - 853us/step
# Epoch 70/100
# 1875/1875 - 2s - loss: 0.1935 - accuracy: 0.9423 - 2s/epoch - 854us/step
# Epoch 71/100
# 1875/1875 - 2s - loss: 0.1911 - accuracy: 0.9434 - 2s/epoch - 855us/step
# Epoch 72/100
# 1875/1875 - 2s - loss: 0.1891 - accuracy: 0.9432 - 2s/epoch - 866us/step
# Epoch 73/100
# 1875/1875 - 2s - loss: 0.1859 - accuracy: 0.9451 - 2s/epoch - 856us/step
# Epoch 74/100
# 1875/1875 - 2s - loss: 0.1840 - accuracy: 0.9456 - 2s/epoch - 854us/step
# Epoch 75/100
# 1875/1875 - 2s - loss: 0.1829 - accuracy: 0.9453 - 2s/epoch - 861us/step
# Epoch 76/100
# 1875/1875 - 2s - loss: 0.1803 - accuracy: 0.9471 - 2s/epoch - 870us/step
# Epoch 77/100
# 1875/1875 - 2s - loss: 0.1774 - accuracy: 0.9476 - 2s/epoch - 865us/step
# Epoch 78/100
# 1875/1875 - 2s - loss: 0.1756 - accuracy: 0.9483 - 2s/epoch - 856us/step
# Epoch 79/100
# 1875/1875 - 2s - loss: 0.1740 - accuracy: 0.9487 - 2s/epoch - 853us/step
# Epoch 80/100
# 1875/1875 - 2s - loss: 0.1711 - accuracy: 0.9496 - 2s/epoch - 862us/step
# Epoch 81/100
# 1875/1875 - 2s - loss: 0.1697 - accuracy: 0.9502 - 2s/epoch - 851us/step
# Epoch 82/100
# 1875/1875 - 2s - loss: 0.1678 - accuracy: 0.9499 - 2s/epoch - 857us/step
# Epoch 83/100
# 1875/1875 - 2s - loss: 0.1657 - accuracy: 0.9517 - 2s/epoch - 861us/step
# Epoch 84/100
# 1875/1875 - 2s - loss: 0.1643 - accuracy: 0.9510 - 2s/epoch - 864us/step
# Epoch 85/100
# 1875/1875 - 2s - loss: 0.1620 - accuracy: 0.9530 - 2s/epoch - 873us/step
# Epoch 86/100
# 1875/1875 - 2s - loss: 0.1604 - accuracy: 0.9536 - 2s/epoch - 851us/step
# Epoch 87/100
# 1875/1875 - 2s - loss: 0.1572 - accuracy: 0.9536 - 2s/epoch - 848us/step
# Epoch 88/100
# 1875/1875 - 2s - loss: 0.1554 - accuracy: 0.9545 - 2s/epoch - 849us/step
# Epoch 89/100
# 1875/1875 - 2s - loss: 0.1548 - accuracy: 0.9549 - 2s/epoch - 857us/step
# Epoch 90/100
# 1875/1875 - 2s - loss: 0.1517 - accuracy: 0.9554 - 2s/epoch - 861us/step
# Epoch 91/100
# 1875/1875 - 2s - loss: 0.1502 - accuracy: 0.9562 - 2s/epoch - 865us/step
# Epoch 92/100
# 1875/1875 - 2s - loss: 0.1485 - accuracy: 0.9570 - 2s/epoch - 858us/step
# Epoch 93/100
# 1875/1875 - 2s - loss: 0.1468 - accuracy: 0.9581 - 2s/epoch - 848us/step
# Epoch 94/100
# 1875/1875 - 2s - loss: 0.1462 - accuracy: 0.9575 - 2s/epoch - 855us/step
# Epoch 95/100
# 1875/1875 - 2s - loss: 0.1429 - accuracy: 0.9591 - 2s/epoch - 855us/step
# Epoch 96/100
# 1875/1875 - 2s - loss: 0.1419 - accuracy: 0.9596 - 2s/epoch - 858us/step
# Epoch 97/100
# 1875/1875 - 2s - loss: 0.1410 - accuracy: 0.9594 - 2s/epoch - 850us/step
# Epoch 98/100
# 1875/1875 - 2s - loss: 0.1394 - accuracy: 0.9599 - 2s/epoch - 852us/step
# Epoch 99/100
# 1875/1875 - 2s - loss: 0.1364 - accuracy: 0.9609 - 2s/epoch - 863us/step
# Epoch 100/100
# 1875/1875 - 2s - loss: 0.1352 - accuracy: 0.9607 - 2s/epoch - 857us/step

# %%
print("--Evaluate model--")
model_loss1, model_acc1 = model.evaluate(x_train,  y_train, verbose=2)
model_loss2, model_acc2 = model.evaluate(x_test,  y_test, verbose=2)
print(f"Train / Test Accuracy: {model_acc1*100:.1f}% / {model_acc2*100:.1f}%")
model.save("notMNIST_partial_model", save_format="h5")
# Out:
# --Evaluate model--
# 1875/1875 - 1s - loss: 0.1190 - accuracy: 0.9679 - 1s/epoch - 741us/step
# 313/313 - 0s - loss: 0.3423 - accuracy: 0.9244 - 309ms/epoch - 987us/step
# Train / Test Accuracy: 96.8% / 92.4%
