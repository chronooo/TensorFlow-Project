# %%
#Main Project Stage 1: Data Science and Machine Learning
# Import the required libraries

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn
import tensorflow as tf

# Set sns theme to your preferred color palette
sns.set_theme(palette = "mako")

data = pd.read_csv('../data/data-input.csv')  # read csv file
data.to_csv("../data/data.csv",index=False)
#data input is the data that I had previously cleaned before starting the assignment
data = pd.read_csv("../data/data.csv") #pretty confused as to why the instructions ask for this, but I guess its not a big deal
data['median_income']=pd.cut(data['median_income'],bins=[0, 1.5, 2.5, 4, 6, 8, 10, 1000], 
include_lowest=True, 
labels=['poverty','below average','average','above average','well off','wealthy','rich'])
df = data.copy()  # create a copy to use for future reference, so I have a copy of my original dataset when needed

data.head()
#Cleaned data (now called data-input.csv) by hand beforehand before reading instructions, so my data is already good.
#Will be skipping the pandas clean data step
# Out:
# 2022-11-12 16:34:37.156265: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-12 16:34:38.437494: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-11-12 16:34:38.437514: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-11-12 16:34:38.577042: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-11-12 16:34:40.892943: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2022-11-12 16:34:40.893486: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2022-11-12 16:34:40.893493: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0        wealthy            452600.0        NEAR BAY
# 1      2401.0      1138.0        wealthy            358500.0        NEAR BAY
# 2       496.0       177.0       well off            352100.0        NEAR BAY
# 3       558.0       219.0  above average            341300.0        NEAR BAY
# 4       565.0       259.0        average            342200.0        NEAR BAY

# %%
#Histogram showing distribution of housing age in the market
agehist = sns.histplot(data=df, x = "housing_median_age")
fig = agehist.get_figure()
fig.savefig("../plots/plot1.png")

# %%
#Visualization of relationship (and variation) in housing price based on its age
age_value_lineplot = sns.lineplot(data=df, x = "housing_median_age", y = "median_house_value")
fig = age_value_lineplot.get_figure()
fig.savefig("../plots/plot2.png")

# %%
#Visualization of price distribution of houses in california
house_value_histplot = sns.histplot(data=df, x = "median_house_value")
fig = house_value_histplot.get_figure()
fig.savefig("../plots/plot3.png") 
#Can see from output that a majority of the houses are from 150k to 250k

# %% [markdown]
# Where the data came from.:
#
# https://www.kaggle.com/datasets/kathuman/housing
# I will be using the dataset on Housing Prices in California found on Kaggle with a creative Commons Public Domain License
# Description of data from creator:
# "This dataset is based on data from the 1990 California Census, and incluides metrics such as the population, median income, and median housing proice for each block group in California.
# Block groups are the smallest geographical unit for which the US Census Bureau publishes sample data., and each block typically has between 600 to 3000 people."
#
# The goal I have with this dataset is to be able to get my model to guess the price of houses given all the other information.
#
#
# Challenges cleaning:
#
# One of the challenges I had cleaning was that the dataset was humongous (22k rows) so I worried that I missed some stuff while cleaning but overall it was pretty straightforward. I cleaned it by hand before starting the assignment, and the biggest issue was that there was a lot of data to delete by hand. There was a lot of cells that just had nothing inside it, so I had to delete the entire line, which meant I couldnt automate it with find and replace. But other than that, the data seems pretty clean, and there are some spots in the data that I might need to go back and change, but for now I think the data looks reliable, based on the distribution I've seen from my graphs.
#
# Three visualizations:
#
# plot1 is a distribution of the age of the house. We can see that california has a wide range of ages for their houses. But their seems to be a spike in houses that are around 20, 30, and 50+ years old. Overall I think the distribution in that column is pretty good, and should pose no issues in training my model.
#
# plot2 is a visualization of relationship (and variation) in housing price based on its age. One thing that bothered me in this, is that from the graph, the house prices seem to very a lot for some age groups, specifically ~10 years old and ~50 years old. I worry that this will have negative effects in the model, but at the same time, logically speaking this is a realistic scenario. As old houses that are still standing are likely to be very nice to begin with, and new houses that are being built are being built for many different types of people with different incomes, especially in california where there is a large amount of wealthy and average people concentrated in one area.
#
# plot3 is a visualization of price distribution of houses in california. I wanted to see where the price of houses was concentrated, this graph allowed me to see that a majority of the houses in california in the dataset are around $150k-250k. But there is also a sizeable amount of houses below and above that number. Which should pose as good variation to give model a wide range of information to make accurate estimates.
#
# Part 2 code begins after this report
# --

# %%
df.shape  # Will return the number of rows and columns
# Out:
# (20433, 10)

# %%
df.info()  # Will inform you of the datatype of each variable, as well as if there are any null or missing values in each column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20433 entries, 0 to 20432
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  category
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: category(1), float64(8), object(1)
# memory usage: 1.4+ MB

# %%
df.describe().T # Describe the data-frame (transposed) - defaults to describing only numerical
# If you want to describe all, run the following command:
# data.describe(include = "all").T
# Out:
#                       count           mean            std       min  \
# longitude           20433.0    -119.570689       2.003578   -124.35
# latitude            20433.0      35.633221       2.136348     32.54
# housing_median_age  20433.0      28.633094      12.591805      1.00
# total_rooms         20433.0    2636.504233    2185.269567      2.00
# total_bedrooms      20433.0     537.870553     421.385070      1.00
# population          20433.0    1424.946949    1133.208490      3.00
# households          20433.0     499.433465     382.299226      1.00
# median_house_value  20433.0  206864.413155  115435.667099  14999.00
#
#                           25%        50%        75%        max
# longitude             -121.80    -118.49    -118.01    -114.31
# latitude                33.93      34.26      37.72      41.95
# housing_median_age      18.00      29.00      37.00      52.00
# total_rooms           1450.00    2127.00    3143.00   39320.00
# total_bedrooms         296.00     435.00     647.00    6445.00
# population             787.00    1166.00    1722.00   35682.00
# households             280.00     409.00     604.00    6082.00
# median_house_value  119500.00  179700.00  264700.00  500001.00

# %%
df.isnull().sum()  # Checking for null values
# In this case there are no null values. If there are some, you can use a heatmap to visualize them if you want.
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
#Organizing categorical data
#Citation is from Joweria's heartdisease tutorial notebook
from pandas.core.arrays import categorical 
categorical_data = ["ocean_proximity","median_income"]

codes = {}  # Create a dictionary to store the codes of the conversion
for i in df:  # For each variable in the data frame 
  if i in categorical_data:  # For each variable that was classified as categorical
    specific_codes = {}  # Create a dictionary for that variable's code conversion 
    df[i] = df[i].astype("category")  # Convert that variable from 'object' datatype to category
    df[i] = df[i].cat.codes  # Create codes for the categories and replace in the dataset 
    coded = df[i].unique()  # Get the unique values (the codes) from the variable
    count = 0  # Count initialized. Later used for accessing specific indexes
    for j in data[i].unique():  # For each unique value
      specific_codes[j] = coded[count]  # Create an item in the dictionary with the value, and tell it which code correlates
      count += 1  # Count incremented
    codes[i] = specific_codes  # Create a new item in the overall dictionary with the dictionary created for this specific variable's codes


# View our created dictionary:
for i in codes:
  print("{} -".format(i))
  for j in codes[i]:
    print("{}: {}".format(j, codes[i][j]))
  print()
# Out:
# median_income -
# wealthy: 5
# well off: 4
# above average: 3
# average: 2
# below average: 1
# poverty: 0
# rich: 6
#
# ocean_proximity -
# NEAR BAY: 3
# <1H OCEAN: 0
# INLAND: 1
# NEAR OCEAN: 4
# ISLAND: 2

# %%
df.head()
#Checking that data is no longer categorical and now an integer at the end
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value  ocean_proximity
# 0       322.0       126.0              5            452600.0                3
# 1      2401.0      1138.0              5            358500.0                3
# 2       496.0       177.0              4            352100.0                3
# 3       558.0       219.0              3            341300.0                3
# 4       565.0       259.0              2            342200.0                3

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler
fs_data = df.copy() # copy of dataset for feature selection
x = fs_data.iloc[:,[0,1,2,3,4,5,6,8]]  # independent variables
y = fs_data.iloc[:,[9]]    # target column / what we're trying to predict


#https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html
#Found this easy way to split training data in the scikit documentation
#Shuffles data, and allocated 80% of it to be used for training, and 20% of it to be used for testing
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2) # splitting up dataset to training and testing

scl = RobustScaler() # Preprocess numerical data 
x_train = scl.fit_transform(x_train) 
x_test = scl.transform(x_test)

# %%
#x_train.head()

# %%
normalizer = tf.keras.layers.Normalization(axis=-1)
normalizer.adapt(x_train)
print(normalizer.mean.numpy())
# Out:
# 2022-11-12 16:34:46.702205: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-12 16:34:46.703346: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-11-12 16:34:46.703854: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory
# 2022-11-12 16:34:46.704474: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory
# 2022-11-12 16:34:46.704974: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory
# 2022-11-12 16:34:46.705549: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcurand.so.10'; dlerror: libcurand.so.10: cannot open shared object file: No such file or directory
# 2022-11-12 16:34:46.706077: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory
# 2022-11-12 16:34:46.706636: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory
# 2022-11-12 16:34:46.707199: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2022-11-12 16:34:46.707210: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2022-11-12 16:34:46.709397: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [[-0.2849948   0.36381653 -0.02341471  0.30008554  0.2942361   0.27459118
#    0.27484912  0.29199794  0.1859257 ]]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Flatten


print("--Make model--")
model = tf.keras.models.Sequential([
  normalizer,
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dropout(0.4),
  tf.keras.layers.Dense(64, activation='relu'),
  tf.keras.layers.Dense(64, activation='relu'),
  tf.keras.layers.Dense(10, activation='softmax'),
])
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

print("--Fit model--")
model.fit(x_train, y_train, epochs=200, verbose=2)
# Out:
# --Make model--
# --Fit model--
# Epoch 1/200
# 511/511 - 1s - loss: 0.7707 - accuracy: 0.7160 - 709ms/epoch - 1ms/step
# Epoch 2/200
# 511/511 - 0s - loss: 0.4988 - accuracy: 0.8014 - 452ms/epoch - 885us/step
# Epoch 3/200
# 511/511 - 0s - loss: 0.4251 - accuracy: 0.8319 - 441ms/epoch - 864us/step
# Epoch 4/200
# 511/511 - 0s - loss: 0.3877 - accuracy: 0.8377 - 442ms/epoch - 866us/step
# Epoch 5/200
# 511/511 - 0s - loss: 0.3586 - accuracy: 0.8526 - 435ms/epoch - 851us/step
# Epoch 6/200
# 511/511 - 0s - loss: 0.3407 - accuracy: 0.8603 - 440ms/epoch - 862us/step
# Epoch 7/200
# 511/511 - 0s - loss: 0.3205 - accuracy: 0.8682 - 443ms/epoch - 866us/step
# Epoch 8/200
# 511/511 - 0s - loss: 0.3015 - accuracy: 0.8750 - 444ms/epoch - 869us/step
# Epoch 9/200
# 511/511 - 0s - loss: 0.2830 - accuracy: 0.8843 - 442ms/epoch - 864us/step
# Epoch 10/200
# 511/511 - 0s - loss: 0.2780 - accuracy: 0.8849 - 435ms/epoch - 852us/step
# Epoch 11/200
# 511/511 - 0s - loss: 0.2632 - accuracy: 0.8906 - 443ms/epoch - 866us/step
# Epoch 12/200
# 511/511 - 0s - loss: 0.2613 - accuracy: 0.8927 - 437ms/epoch - 854us/step
# Epoch 13/200
# 511/511 - 0s - loss: 0.2535 - accuracy: 0.8934 - 440ms/epoch - 861us/step
# Epoch 14/200
# 511/511 - 0s - loss: 0.2459 - accuracy: 0.8981 - 441ms/epoch - 864us/step
# Epoch 15/200
# 511/511 - 0s - loss: 0.2445 - accuracy: 0.8997 - 441ms/epoch - 863us/step
# Epoch 16/200
# 511/511 - 0s - loss: 0.2380 - accuracy: 0.9007 - 443ms/epoch - 867us/step
# Epoch 17/200
# 511/511 - 0s - loss: 0.2300 - accuracy: 0.9053 - 442ms/epoch - 865us/step
# Epoch 18/200
# 511/511 - 0s - loss: 0.2304 - accuracy: 0.9031 - 444ms/epoch - 869us/step
# Epoch 19/200
# 511/511 - 0s - loss: 0.2260 - accuracy: 0.9041 - 434ms/epoch - 849us/step
# Epoch 20/200
# 511/511 - 0s - loss: 0.2182 - accuracy: 0.9088 - 448ms/epoch - 876us/step
# Epoch 21/200
# 511/511 - 0s - loss: 0.2192 - accuracy: 0.9069 - 443ms/epoch - 866us/step
# Epoch 22/200
# 511/511 - 0s - loss: 0.2229 - accuracy: 0.9071 - 479ms/epoch - 938us/step
# Epoch 23/200
# 511/511 - 0s - loss: 0.2114 - accuracy: 0.9128 - 441ms/epoch - 863us/step
# Epoch 24/200
# 511/511 - 0s - loss: 0.2156 - accuracy: 0.9077 - 441ms/epoch - 862us/step
# Epoch 25/200
# 511/511 - 0s - loss: 0.2068 - accuracy: 0.9131 - 441ms/epoch - 863us/step
# Epoch 26/200
# 511/511 - 0s - loss: 0.2104 - accuracy: 0.9109 - 439ms/epoch - 859us/step
# Epoch 27/200
# 511/511 - 0s - loss: 0.2083 - accuracy: 0.9134 - 438ms/epoch - 858us/step
# Epoch 28/200
# 511/511 - 0s - loss: 0.2048 - accuracy: 0.9135 - 442ms/epoch - 865us/step
# Epoch 29/200
# 511/511 - 0s - loss: 0.2070 - accuracy: 0.9129 - 438ms/epoch - 858us/step
# Epoch 30/200
# 511/511 - 0s - loss: 0.1989 - accuracy: 0.9160 - 438ms/epoch - 857us/step
# Epoch 31/200
# 511/511 - 0s - loss: 0.1982 - accuracy: 0.9153 - 445ms/epoch - 872us/step
# Epoch 32/200
# 511/511 - 0s - loss: 0.2027 - accuracy: 0.9150 - 441ms/epoch - 863us/step
# Epoch 33/200
# 511/511 - 0s - loss: 0.1970 - accuracy: 0.9155 - 441ms/epoch - 863us/step
# Epoch 34/200
# 511/511 - 0s - loss: 0.2037 - accuracy: 0.9146 - 441ms/epoch - 863us/step
# Epoch 35/200
# 511/511 - 0s - loss: 0.1960 - accuracy: 0.9164 - 441ms/epoch - 864us/step
# Epoch 36/200
# 511/511 - 0s - loss: 0.1945 - accuracy: 0.9176 - 441ms/epoch - 863us/step
# Epoch 37/200
# 511/511 - 0s - loss: 0.1970 - accuracy: 0.9161 - 445ms/epoch - 870us/step
# Epoch 38/200
# 511/511 - 0s - loss: 0.1921 - accuracy: 0.9194 - 440ms/epoch - 860us/step
# Epoch 39/200
# 511/511 - 0s - loss: 0.1924 - accuracy: 0.9183 - 436ms/epoch - 854us/step
# Epoch 40/200
# 511/511 - 0s - loss: 0.1929 - accuracy: 0.9192 - 442ms/epoch - 865us/step
# Epoch 41/200
# 511/511 - 0s - loss: 0.1915 - accuracy: 0.9176 - 438ms/epoch - 856us/step
# Epoch 42/200
# 511/511 - 0s - loss: 0.1917 - accuracy: 0.9188 - 440ms/epoch - 861us/step
# Epoch 43/200
# 511/511 - 0s - loss: 0.1918 - accuracy: 0.9181 - 441ms/epoch - 863us/step
# Epoch 44/200
# 511/511 - 0s - loss: 0.1947 - accuracy: 0.9161 - 439ms/epoch - 859us/step
# Epoch 45/200
# 511/511 - 0s - loss: 0.1864 - accuracy: 0.9205 - 448ms/epoch - 877us/step
# Epoch 46/200
# 511/511 - 0s - loss: 0.1907 - accuracy: 0.9189 - 438ms/epoch - 857us/step
# Epoch 47/200
# 511/511 - 0s - loss: 0.1831 - accuracy: 0.9235 - 451ms/epoch - 883us/step
# Epoch 48/200
# 511/511 - 0s - loss: 0.1843 - accuracy: 0.9225 - 440ms/epoch - 861us/step
# Epoch 49/200
# 511/511 - 0s - loss: 0.1800 - accuracy: 0.9253 - 435ms/epoch - 850us/step
# Epoch 50/200
# 511/511 - 0s - loss: 0.1802 - accuracy: 0.9251 - 439ms/epoch - 859us/step
# Epoch 51/200
# 511/511 - 0s - loss: 0.1842 - accuracy: 0.9206 - 434ms/epoch - 850us/step
# Epoch 52/200
# 511/511 - 0s - loss: 0.1848 - accuracy: 0.9205 - 440ms/epoch - 861us/step
# Epoch 53/200
# 511/511 - 0s - loss: 0.1769 - accuracy: 0.9241 - 442ms/epoch - 865us/step
# Epoch 54/200
# 511/511 - 0s - loss: 0.1803 - accuracy: 0.9218 - 443ms/epoch - 867us/step
# Epoch 55/200
# 511/511 - 0s - loss: 0.1878 - accuracy: 0.9200 - 439ms/epoch - 859us/step
# Epoch 56/200
# 511/511 - 0s - loss: 0.1828 - accuracy: 0.9219 - 439ms/epoch - 859us/step
# Epoch 57/200
# 511/511 - 0s - loss: 0.1757 - accuracy: 0.9258 - 441ms/epoch - 863us/step
# Epoch 58/200
# 511/511 - 0s - loss: 0.1766 - accuracy: 0.9241 - 441ms/epoch - 863us/step
# Epoch 59/200
# 511/511 - 0s - loss: 0.1742 - accuracy: 0.9263 - 442ms/epoch - 864us/step
# Epoch 60/200
# 511/511 - 0s - loss: 0.1766 - accuracy: 0.9260 - 444ms/epoch - 869us/step
# Epoch 61/200
# 511/511 - 0s - loss: 0.1749 - accuracy: 0.9250 - 449ms/epoch - 879us/step
# Epoch 62/200
# 511/511 - 0s - loss: 0.1779 - accuracy: 0.9233 - 435ms/epoch - 851us/step
# Epoch 63/200
# 511/511 - 0s - loss: 0.1765 - accuracy: 0.9233 - 440ms/epoch - 861us/step
# Epoch 64/200
# 511/511 - 0s - loss: 0.1729 - accuracy: 0.9255 - 443ms/epoch - 868us/step
# Epoch 65/200
# 511/511 - 0s - loss: 0.1717 - accuracy: 0.9272 - 442ms/epoch - 864us/step
# Epoch 66/200
# 511/511 - 0s - loss: 0.1716 - accuracy: 0.9279 - 442ms/epoch - 866us/step
# Epoch 67/200
# 511/511 - 0s - loss: 0.1725 - accuracy: 0.9249 - 436ms/epoch - 853us/step
# Epoch 68/200
# 511/511 - 0s - loss: 0.1729 - accuracy: 0.9274 - 443ms/epoch - 866us/step
# Epoch 69/200
# 511/511 - 0s - loss: 0.1711 - accuracy: 0.9281 - 435ms/epoch - 851us/step
# Epoch 70/200
# 511/511 - 0s - loss: 0.1677 - accuracy: 0.9289 - 446ms/epoch - 872us/step
# Epoch 71/200
# 511/511 - 0s - loss: 0.1705 - accuracy: 0.9266 - 435ms/epoch - 851us/step
# Epoch 72/200
# 511/511 - 0s - loss: 0.1689 - accuracy: 0.9298 - 441ms/epoch - 863us/step
# Epoch 73/200
# 511/511 - 0s - loss: 0.1683 - accuracy: 0.9288 - 481ms/epoch - 942us/step
# Epoch 74/200
# 511/511 - 0s - loss: 0.1661 - accuracy: 0.9301 - 443ms/epoch - 866us/step
# Epoch 75/200
# 511/511 - 0s - loss: 0.1697 - accuracy: 0.9282 - 435ms/epoch - 852us/step
# Epoch 76/200
# 511/511 - 0s - loss: 0.1684 - accuracy: 0.9283 - 441ms/epoch - 863us/step
# Epoch 77/200
# 511/511 - 0s - loss: 0.1686 - accuracy: 0.9300 - 433ms/epoch - 847us/step
# Epoch 78/200
# 511/511 - 0s - loss: 0.1670 - accuracy: 0.9280 - 442ms/epoch - 865us/step
# Epoch 79/200
# 511/511 - 0s - loss: 0.1646 - accuracy: 0.9317 - 435ms/epoch - 851us/step
# Epoch 80/200
# 511/511 - 0s - loss: 0.1698 - accuracy: 0.9276 - 440ms/epoch - 861us/step
# Epoch 81/200
# 511/511 - 0s - loss: 0.1658 - accuracy: 0.9287 - 442ms/epoch - 864us/step
# Epoch 82/200
# 511/511 - 0s - loss: 0.1637 - accuracy: 0.9309 - 438ms/epoch - 858us/step
# Epoch 83/200
# 511/511 - 0s - loss: 0.1652 - accuracy: 0.9301 - 436ms/epoch - 853us/step
# Epoch 84/200
# 511/511 - 0s - loss: 0.1639 - accuracy: 0.9322 - 442ms/epoch - 865us/step
# Epoch 85/200
# 511/511 - 0s - loss: 0.1662 - accuracy: 0.9298 - 438ms/epoch - 858us/step
# Epoch 86/200
# 511/511 - 0s - loss: 0.1654 - accuracy: 0.9304 - 439ms/epoch - 858us/step
# Epoch 87/200
# 511/511 - 0s - loss: 0.1623 - accuracy: 0.9301 - 441ms/epoch - 862us/step
# Epoch 88/200
# 511/511 - 0s - loss: 0.1647 - accuracy: 0.9298 - 441ms/epoch - 864us/step
# Epoch 89/200
# 511/511 - 0s - loss: 0.1629 - accuracy: 0.9301 - 440ms/epoch - 862us/step
# Epoch 90/200
# 511/511 - 0s - loss: 0.1625 - accuracy: 0.9303 - 447ms/epoch - 875us/step
# Epoch 91/200
# 511/511 - 0s - loss: 0.1625 - accuracy: 0.9279 - 443ms/epoch - 868us/step
# Epoch 92/200
# 511/511 - 0s - loss: 0.1636 - accuracy: 0.9325 - 436ms/epoch - 853us/step
# Epoch 93/200
# 511/511 - 0s - loss: 0.1630 - accuracy: 0.9320 - 446ms/epoch - 873us/step
# Epoch 94/200
# 511/511 - 0s - loss: 0.1626 - accuracy: 0.9315 - 445ms/epoch - 871us/step
# Epoch 95/200
# 511/511 - 0s - loss: 0.1636 - accuracy: 0.9306 - 443ms/epoch - 866us/step
# Epoch 96/200
# 511/511 - 0s - loss: 0.1597 - accuracy: 0.9310 - 446ms/epoch - 872us/step
# Epoch 97/200
# 511/511 - 0s - loss: 0.1604 - accuracy: 0.9315 - 440ms/epoch - 860us/step
# Epoch 98/200
# 511/511 - 0s - loss: 0.1606 - accuracy: 0.9311 - 447ms/epoch - 874us/step
# Epoch 99/200
# 511/511 - 0s - loss: 0.1595 - accuracy: 0.9327 - 441ms/epoch - 864us/step
# Epoch 100/200
# 511/511 - 0s - loss: 0.1549 - accuracy: 0.9340 - 440ms/epoch - 862us/step
# Epoch 101/200
# 511/511 - 0s - loss: 0.1572 - accuracy: 0.9352 - 440ms/epoch - 860us/step
# Epoch 102/200
# 511/511 - 0s - loss: 0.1583 - accuracy: 0.9329 - 446ms/epoch - 872us/step
# Epoch 103/200
# 511/511 - 0s - loss: 0.1599 - accuracy: 0.9307 - 435ms/epoch - 850us/step
# Epoch 104/200
# 511/511 - 0s - loss: 0.1568 - accuracy: 0.9327 - 447ms/epoch - 874us/step
# Epoch 105/200
# 511/511 - 0s - loss: 0.1616 - accuracy: 0.9295 - 440ms/epoch - 862us/step
# Epoch 106/200
# 511/511 - 0s - loss: 0.1608 - accuracy: 0.9329 - 435ms/epoch - 851us/step
# Epoch 107/200
# 511/511 - 0s - loss: 0.1596 - accuracy: 0.9306 - 436ms/epoch - 854us/step
# Epoch 108/200
# 511/511 - 0s - loss: 0.1595 - accuracy: 0.9314 - 435ms/epoch - 850us/step
# Epoch 109/200
# 511/511 - 0s - loss: 0.1558 - accuracy: 0.9352 - 437ms/epoch - 855us/step
# Epoch 110/200
# 511/511 - 0s - loss: 0.1556 - accuracy: 0.9331 - 426ms/epoch - 833us/step
# Epoch 111/200
# 511/511 - 0s - loss: 0.1541 - accuracy: 0.9358 - 432ms/epoch - 844us/step
# Epoch 112/200
# 511/511 - 0s - loss: 0.1541 - accuracy: 0.9346 - 439ms/epoch - 859us/step
# Epoch 113/200
# 511/511 - 0s - loss: 0.1504 - accuracy: 0.9359 - 450ms/epoch - 881us/step
# Epoch 114/200
# 511/511 - 0s - loss: 0.1557 - accuracy: 0.9339 - 439ms/epoch - 860us/step
# Epoch 115/200
# 511/511 - 0s - loss: 0.1555 - accuracy: 0.9331 - 441ms/epoch - 862us/step
# Epoch 116/200
# 511/511 - 0s - loss: 0.1600 - accuracy: 0.9326 - 445ms/epoch - 871us/step
# Epoch 117/200
# 511/511 - 0s - loss: 0.1586 - accuracy: 0.9306 - 440ms/epoch - 861us/step
# Epoch 118/200
# 511/511 - 0s - loss: 0.1574 - accuracy: 0.9326 - 447ms/epoch - 874us/step
# Epoch 119/200
# 511/511 - 0s - loss: 0.1514 - accuracy: 0.9349 - 443ms/epoch - 867us/step
# Epoch 120/200
# 511/511 - 0s - loss: 0.1574 - accuracy: 0.9340 - 441ms/epoch - 863us/step
# Epoch 121/200
# 511/511 - 0s - loss: 0.1511 - accuracy: 0.9354 - 444ms/epoch - 870us/step
# Epoch 122/200
# 511/511 - 0s - loss: 0.1550 - accuracy: 0.9342 - 442ms/epoch - 866us/step
# Epoch 123/200
# 511/511 - 0s - loss: 0.1582 - accuracy: 0.9322 - 439ms/epoch - 858us/step
# Epoch 124/200
# 511/511 - 0s - loss: 0.1557 - accuracy: 0.9341 - 477ms/epoch - 934us/step
# Epoch 125/200
# 511/511 - 0s - loss: 0.1530 - accuracy: 0.9319 - 443ms/epoch - 867us/step
# Epoch 126/200
# 511/511 - 0s - loss: 0.1555 - accuracy: 0.9328 - 442ms/epoch - 864us/step
# Epoch 127/200
# 511/511 - 0s - loss: 0.1511 - accuracy: 0.9352 - 437ms/epoch - 855us/step
# Epoch 128/200
# 511/511 - 0s - loss: 0.1580 - accuracy: 0.9318 - 444ms/epoch - 869us/step
# Epoch 129/200
# 511/511 - 0s - loss: 0.1503 - accuracy: 0.9361 - 437ms/epoch - 855us/step
# Epoch 130/200
# 511/511 - 0s - loss: 0.1559 - accuracy: 0.9342 - 432ms/epoch - 846us/step
# Epoch 131/200
# 511/511 - 0s - loss: 0.1530 - accuracy: 0.9363 - 435ms/epoch - 851us/step
# Epoch 132/200
# 511/511 - 0s - loss: 0.1503 - accuracy: 0.9356 - 431ms/epoch - 844us/step
# Epoch 133/200
# 511/511 - 0s - loss: 0.1530 - accuracy: 0.9360 - 436ms/epoch - 853us/step
# Epoch 134/200
# 511/511 - 0s - loss: 0.1458 - accuracy: 0.9383 - 434ms/epoch - 850us/step
# Epoch 135/200
# 511/511 - 0s - loss: 0.1488 - accuracy: 0.9364 - 428ms/epoch - 837us/step
# Epoch 136/200
# 511/511 - 0s - loss: 0.1461 - accuracy: 0.9393 - 441ms/epoch - 862us/step
# Epoch 137/200
# 511/511 - 0s - loss: 0.1503 - accuracy: 0.9350 - 432ms/epoch - 846us/step
# Epoch 138/200
# 511/511 - 0s - loss: 0.1483 - accuracy: 0.9368 - 443ms/epoch - 866us/step
# Epoch 139/200
# 511/511 - 0s - loss: 0.1470 - accuracy: 0.9389 - 441ms/epoch - 863us/step
# Epoch 140/200
# 511/511 - 0s - loss: 0.1481 - accuracy: 0.9374 - 449ms/epoch - 879us/step
# Epoch 141/200
# 511/511 - 0s - loss: 0.1464 - accuracy: 0.9401 - 439ms/epoch - 859us/step
# Epoch 142/200
# 511/511 - 0s - loss: 0.1519 - accuracy: 0.9352 - 440ms/epoch - 860us/step
# Epoch 143/200
# 511/511 - 0s - loss: 0.1502 - accuracy: 0.9342 - 443ms/epoch - 866us/step
# Epoch 144/200
# 511/511 - 0s - loss: 0.1407 - accuracy: 0.9389 - 426ms/epoch - 833us/step
# Epoch 145/200
# 511/511 - 0s - loss: 0.1501 - accuracy: 0.9359 - 447ms/epoch - 876us/step
# Epoch 146/200
# 511/511 - 0s - loss: 0.1485 - accuracy: 0.9377 - 439ms/epoch - 858us/step
# Epoch 147/200
# 511/511 - 0s - loss: 0.1489 - accuracy: 0.9363 - 440ms/epoch - 860us/step
# Epoch 148/200
# 511/511 - 0s - loss: 0.1488 - accuracy: 0.9356 - 439ms/epoch - 859us/step
# Epoch 149/200
# 511/511 - 0s - loss: 0.1483 - accuracy: 0.9346 - 439ms/epoch - 859us/step
# Epoch 150/200
# 511/511 - 0s - loss: 0.1461 - accuracy: 0.9388 - 434ms/epoch - 850us/step
# Epoch 151/200
# 511/511 - 0s - loss: 0.1468 - accuracy: 0.9382 - 430ms/epoch - 842us/step
# Epoch 152/200
# 511/511 - 0s - loss: 0.1486 - accuracy: 0.9368 - 440ms/epoch - 861us/step
# Epoch 153/200
# 511/511 - 0s - loss: 0.1461 - accuracy: 0.9380 - 442ms/epoch - 865us/step
# Epoch 154/200
# 511/511 - 0s - loss: 0.1517 - accuracy: 0.9348 - 434ms/epoch - 850us/step
# Epoch 155/200
# 511/511 - 0s - loss: 0.1455 - accuracy: 0.9380 - 435ms/epoch - 851us/step
# Epoch 156/200
# 511/511 - 0s - loss: 0.1453 - accuracy: 0.9367 - 441ms/epoch - 863us/step
# Epoch 157/200
# 511/511 - 0s - loss: 0.1494 - accuracy: 0.9381 - 442ms/epoch - 865us/step
# Epoch 158/200
# 511/511 - 0s - loss: 0.1408 - accuracy: 0.9393 - 438ms/epoch - 857us/step
# Epoch 159/200
# 511/511 - 0s - loss: 0.1464 - accuracy: 0.9365 - 442ms/epoch - 866us/step
# Epoch 160/200
# 511/511 - 0s - loss: 0.1419 - accuracy: 0.9406 - 445ms/epoch - 871us/step
# Epoch 161/200
# 511/511 - 0s - loss: 0.1435 - accuracy: 0.9382 - 442ms/epoch - 866us/step
# Epoch 162/200
# 511/511 - 0s - loss: 0.1445 - accuracy: 0.9393 - 436ms/epoch - 854us/step
# Epoch 163/200
# 511/511 - 0s - loss: 0.1434 - accuracy: 0.9409 - 438ms/epoch - 857us/step
# Epoch 164/200
# 511/511 - 0s - loss: 0.1426 - accuracy: 0.9402 - 440ms/epoch - 862us/step
# Epoch 165/200
# 511/511 - 0s - loss: 0.1456 - accuracy: 0.9383 - 445ms/epoch - 871us/step
# Epoch 166/200
# 511/511 - 0s - loss: 0.1447 - accuracy: 0.9413 - 437ms/epoch - 855us/step
# Epoch 167/200
# 511/511 - 0s - loss: 0.1445 - accuracy: 0.9398 - 442ms/epoch - 865us/step
# Epoch 168/200
# 511/511 - 0s - loss: 0.1407 - accuracy: 0.9401 - 438ms/epoch - 857us/step
# Epoch 169/200
# 511/511 - 0s - loss: 0.1393 - accuracy: 0.9414 - 439ms/epoch - 860us/step
# Epoch 170/200
# 511/511 - 0s - loss: 0.1425 - accuracy: 0.9389 - 445ms/epoch - 871us/step
# Epoch 171/200
# 511/511 - 0s - loss: 0.1417 - accuracy: 0.9386 - 440ms/epoch - 862us/step
# Epoch 172/200
# 511/511 - 0s - loss: 0.1457 - accuracy: 0.9386 - 454ms/epoch - 888us/step
# Epoch 173/200
# 511/511 - 0s - loss: 0.1386 - accuracy: 0.9411 - 447ms/epoch - 875us/step
# Epoch 174/200
# 511/511 - 0s - loss: 0.1417 - accuracy: 0.9397 - 445ms/epoch - 871us/step
# Epoch 175/200
# 511/511 - 0s - loss: 0.1365 - accuracy: 0.9410 - 465ms/epoch - 910us/step
# Epoch 176/200
# 511/511 - 0s - loss: 0.1449 - accuracy: 0.9385 - 431ms/epoch - 843us/step
# Epoch 177/200
# 511/511 - 0s - loss: 0.1420 - accuracy: 0.9381 - 441ms/epoch - 863us/step
# Epoch 178/200
# 511/511 - 0s - loss: 0.1427 - accuracy: 0.9393 - 435ms/epoch - 852us/step
# Epoch 179/200
# 511/511 - 0s - loss: 0.1409 - accuracy: 0.9411 - 436ms/epoch - 853us/step
# Epoch 180/200
# 511/511 - 0s - loss: 0.1415 - accuracy: 0.9402 - 436ms/epoch - 854us/step
# Epoch 181/200
# 511/511 - 0s - loss: 0.1366 - accuracy: 0.9418 - 434ms/epoch - 850us/step
# Epoch 182/200
# 511/511 - 0s - loss: 0.1415 - accuracy: 0.9421 - 442ms/epoch - 864us/step
# Epoch 183/200
# 511/511 - 0s - loss: 0.1378 - accuracy: 0.9418 - 437ms/epoch - 855us/step
# Epoch 184/200
# 511/511 - 0s - loss: 0.1400 - accuracy: 0.9417 - 449ms/epoch - 878us/step
# Epoch 185/200
# 511/511 - 0s - loss: 0.1436 - accuracy: 0.9381 - 440ms/epoch - 860us/step
# Epoch 186/200
# 511/511 - 0s - loss: 0.1360 - accuracy: 0.9414 - 435ms/epoch - 851us/step
# Epoch 187/200
# 511/511 - 0s - loss: 0.1353 - accuracy: 0.9446 - 439ms/epoch - 859us/step
# Epoch 188/200
# 511/511 - 0s - loss: 0.1370 - accuracy: 0.9420 - 445ms/epoch - 871us/step
# Epoch 189/200
# 511/511 - 0s - loss: 0.1405 - accuracy: 0.9408 - 435ms/epoch - 852us/step
# Epoch 190/200
# 511/511 - 0s - loss: 0.1359 - accuracy: 0.9406 - 441ms/epoch - 862us/step
# Epoch 191/200
# 511/511 - 0s - loss: 0.1403 - accuracy: 0.9389 - 437ms/epoch - 856us/step
# Epoch 192/200
# 511/511 - 0s - loss: 0.1356 - accuracy: 0.9432 - 448ms/epoch - 876us/step
# Epoch 193/200
# 511/511 - 0s - loss: 0.1428 - accuracy: 0.9389 - 437ms/epoch - 856us/step
# Epoch 194/200
# 511/511 - 0s - loss: 0.1344 - accuracy: 0.9422 - 443ms/epoch - 867us/step
# Epoch 195/200
# 511/511 - 0s - loss: 0.1355 - accuracy: 0.9430 - 435ms/epoch - 852us/step
# Epoch 196/200
# 511/511 - 0s - loss: 0.1346 - accuracy: 0.9441 - 435ms/epoch - 852us/step
# Epoch 197/200
# 511/511 - 0s - loss: 0.1389 - accuracy: 0.9404 - 450ms/epoch - 881us/step
# Epoch 198/200
# 511/511 - 0s - loss: 0.1401 - accuracy: 0.9410 - 439ms/epoch - 860us/step
# Epoch 199/200
# 511/511 - 0s - loss: 0.1378 - accuracy: 0.9411 - 439ms/epoch - 859us/step
# Epoch 200/200
# 511/511 - 0s - loss: 0.1345 - accuracy: 0.9441 - 434ms/epoch - 850us/step

# %%
#Saving model
model.save("main3classif", save_format='h5')

# %%
print("--Evaluate model--")
model_loss1, model_acc1 = model.evaluate(x_train,  y_train, verbose=2)
model_loss2, model_acc2 = model.evaluate(x_test,  y_test, verbose=2)
print(f"Train / Test Accuracy: {model_acc1*100:.1f}% / {model_acc2*100:.1f}%")
# Out:
# --Evaluate model--
# 511/511 - 0s - loss: 0.0942 - accuracy: 0.9640 - 372ms/epoch - 728us/step
# 128/128 - 0s - loss: 0.1213 - accuracy: 0.9479 - 83ms/epoch - 652us/step
# Train / Test Accuracy: 96.4% / 94.8%

# %% [markdown]
# Report for Main part 2:
#
# Before I start I want to point out that for this part of the assignment, I converted my median_income from a numerical income to a categorical one by using pandas.
# ```py
# data['median_income']=pd.cut(data['median_income'],bins=[0, 1.5, 2.5, 4, 6, 8, 10, 1000],
# include_lowest=True,
# labels=['poverty','below average','average','above average','well off','wealthy','rich'])
# ```
# I did this for two reasons, the major reason was due to the fact that I wanted to use ocean_proximity as an output, which would leave me with no categorical inputs for my model. The second and important reason was, that I felt that these income values made no sense, and were just random floats, essentially diving areas into wealth classes, which I felt would be better represented as categories. So thats what I did, since the values had a wide range, I used a pandas function to map each of the values in the column to an appropriate tag, based on how high the median_income was in that neighborhood.
#
# Columns used as input and output
# Input: longitude	latitude	housing_median_age	total_rooms	total_bedrooms	population	households	median_house_value
# Output: ocean_proximity
#
# For my input, I chose every column except median_income as that was categorical, and ocean_proximity as that was my output.
# The reason for this was because that I was hoping my model would be able to make a connection between the richer and higher demand areas in california, would have houses with more rooms/bedrooms, and the house would be worth more in general. That way when the model see's a house thats worth a lot and has a lot of rooms, it might have a baseline assumption that x house is in y rich area, and the same goes for the houses worth less.
#
# I split my training and testing data in a 80/20 split. This was because after randomizing my data, I decided that it would be much more worthwhile to give my data a significantly larger variety to train on than test on. This is because testing is used to see the accuracy of the model, and to get higher accuracy, the model needs to train on a much larger variety, so that if the test has a strange input, it can still make a decision based on the experience that it has, but if I make my training input smaller, it becomes more and more likely that the test will have an input that the model has little to no experience for.
#
# Two decisions that I made for my model design was to process my input. One thing that I did that I felt had a big impact on the accuracy was that I scaled the numerical inputs with the RobustScaler from sklearn (Based on Joweria's process), the second thing that I felt had a big impact was that I normalized the inputs, as the inputs were all numbers that were very different from each other. Normalizing them was important for the model to be able to make sense of things with less difficulty.
#
# In terms of hyper parameters, I had my normalizer, and then I just attempted to make a relatively dense model with lots of layers with the relu activation. Meaning i added lots of the Dense layers. I found that I haven't needed to mess with the units in the softmax layer yet, but I will probably begin experimenting with it during part 3 or 4 of main.
#
# Currently my model is quite accurate, getting 97.2% accuracy on the training, and 94.4% accuracy on the test. Despite this being a pretty acceptable number, I think this discrepency between the two shows that my model is over-fitted to the training data, and the test shouldnt have a signficicant amount of outliers in comparison to the training data, so for the next iterations I will try to fix this discrepency between training and test data. But I also believe that overall accuracy will rise with the introduction of the income column (categorical) column later on.

# %% [markdown]
# Part 3 Report
# --
