# %%
#Main Project Stage 1: Data Science and Machine Learning
# Import the required libraries

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn
import tensorflow as tf

# Set sns theme to your preferred color palette
sns.set_theme(palette = "mako")

data = pd.read_csv('../data/data-input.csv')  # read csv file
data.to_csv("../data/data.csv",index=False)
#data input is the data that I had previously cleaned before starting the assignment
data = pd.read_csv("../data/data.csv") #pretty confused as to why the instructions ask for this, but I guess its not a big deal
data['median_income']=pd.cut(data['median_income'],bins=[0, 1.5, 2.5, 4, 6, 8, 10, 1000], 
include_lowest=True, 
labels=['poverty','below average','average','above average','well off','wealthy','rich'])
df = data.copy()  # create a copy to use for future reference, so I have a copy of my original dataset when needed

data.head()
#Cleaned data (now called data-input.csv) by hand beforehand before reading instructions, so my data is already good.
#Will be skipping the pandas clean data step
# Out:
# 2022-11-12 19:21:24.583294: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-12 19:21:25.761935: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-11-12 19:21:25.761950: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-11-12 19:21:25.887136: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-11-12 19:21:28.607449: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2022-11-12 19:21:28.608654: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2022-11-12 19:21:28.608689: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0        wealthy            452600.0        NEAR BAY
# 1      2401.0      1138.0        wealthy            358500.0        NEAR BAY
# 2       496.0       177.0       well off            352100.0        NEAR BAY
# 3       558.0       219.0  above average            341300.0        NEAR BAY
# 4       565.0       259.0        average            342200.0        NEAR BAY

# %%
#Histogram showing distribution of housing age in the market
agehist = sns.histplot(data=df, x = "housing_median_age")
fig = agehist.get_figure()
fig.savefig("../plots/plot1.png")

# %%
#Visualization of relationship (and variation) in housing price based on its age
age_value_lineplot = sns.lineplot(data=df, x = "housing_median_age", y = "median_house_value")
fig = age_value_lineplot.get_figure()
fig.savefig("../plots/plot2.png")

# %%
#Visualization of price distribution of houses in california
house_value_histplot = sns.histplot(data=df, x = "median_house_value")
fig = house_value_histplot.get_figure()
fig.savefig("../plots/plot3.png") 
#Can see from output that a majority of the houses are from 150k to 250k

# %% [markdown]
# Where the data came from.:
#
# https://www.kaggle.com/datasets/kathuman/housing
# I will be using the dataset on Housing Prices in California found on Kaggle with a creative Commons Public Domain License
# Description of data from creator:
# "This dataset is based on data from the 1990 California Census, and incluides metrics such as the population, median income, and median housing proice for each block group in California.
# Block groups are the smallest geographical unit for which the US Census Bureau publishes sample data., and each block typically has between 600 to 3000 people."
#
# The goal I have with this dataset is to be able to get my model to guess the price of houses given all the other information.
#
#
# Challenges cleaning:
#
# One of the challenges I had cleaning was that the dataset was humongous (22k rows) so I worried that I missed some stuff while cleaning but overall it was pretty straightforward. I cleaned it by hand before starting the assignment, and the biggest issue was that there was a lot of data to delete by hand. There was a lot of cells that just had nothing inside it, so I had to delete the entire line, which meant I couldnt automate it with find and replace. But other than that, the data seems pretty clean, and there are some spots in the data that I might need to go back and change, but for now I think the data looks reliable, based on the distribution I've seen from my graphs.
#
# Three visualizations:
#
# plot1 is a distribution of the age of the house. We can see that california has a wide range of ages for their houses. But their seems to be a spike in houses that are around 20, 30, and 50+ years old. Overall I think the distribution in that column is pretty good, and should pose no issues in training my model.
#
# plot2 is a visualization of relationship (and variation) in housing price based on its age. One thing that bothered me in this, is that from the graph, the house prices seem to very a lot for some age groups, specifically ~10 years old and ~50 years old. I worry that this will have negative effects in the model, but at the same time, logically speaking this is a realistic scenario. As old houses that are still standing are likely to be very nice to begin with, and new houses that are being built are being built for many different types of people with different incomes, especially in california where there is a large amount of wealthy and average people concentrated in one area.
#
# plot3 is a visualization of price distribution of houses in california. I wanted to see where the price of houses was concentrated, this graph allowed me to see that a majority of the houses in california in the dataset are around $150k-250k. But there is also a sizeable amount of houses below and above that number. Which should pose as good variation to give model a wide range of information to make accurate estimates.
#
# Part 2 code begins after this report
# --

# %%
df.shape  # Will return the number of rows and columns
# Out:
# (20433, 10)

# %%
df.info()  # Will inform you of the datatype of each variable, as well as if there are any null or missing values in each column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20433 entries, 0 to 20432
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  category
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: category(1), float64(8), object(1)
# memory usage: 1.4+ MB

# %%
df.describe().T # Describe the data-frame (transposed) - defaults to describing only numerical
# If you want to describe all, run the following command:
# data.describe(include = "all").T
# Out:
#                       count           mean            std       min  \
# longitude           20433.0    -119.570689       2.003578   -124.35
# latitude            20433.0      35.633221       2.136348     32.54
# housing_median_age  20433.0      28.633094      12.591805      1.00
# total_rooms         20433.0    2636.504233    2185.269567      2.00
# total_bedrooms      20433.0     537.870553     421.385070      1.00
# population          20433.0    1424.946949    1133.208490      3.00
# households          20433.0     499.433465     382.299226      1.00
# median_house_value  20433.0  206864.413155  115435.667099  14999.00
#
#                           25%        50%        75%        max
# longitude             -121.80    -118.49    -118.01    -114.31
# latitude                33.93      34.26      37.72      41.95
# housing_median_age      18.00      29.00      37.00      52.00
# total_rooms           1450.00    2127.00    3143.00   39320.00
# total_bedrooms         296.00     435.00     647.00    6445.00
# population             787.00    1166.00    1722.00   35682.00
# households             280.00     409.00     604.00    6082.00
# median_house_value  119500.00  179700.00  264700.00  500001.00

# %%
df.isnull().sum()  # Checking for null values
# In this case there are no null values. If there are some, you can use a heatmap to visualize them if you want.
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
#Organizing categorical data
#Citation is from Joweria's heartdisease tutorial notebook
from pandas.core.arrays import categorical 
categorical_data = ["ocean_proximity","median_income"]

codes = {}  # Create a dictionary to store the codes of the conversion
for i in df:  # For each variable in the data frame 
  if i in categorical_data:  # For each variable that was classified as categorical
    specific_codes = {}  # Create a dictionary for that variable's code conversion 
    df[i] = df[i].astype("category")  # Convert that variable from 'object' datatype to category
    df[i] = df[i].cat.codes  # Create codes for the categories and replace in the dataset 
    coded = df[i].unique()  # Get the unique values (the codes) from the variable
    count = 0  # Count initialized. Later used for accessing specific indexes
    for j in data[i].unique():  # For each unique value
      specific_codes[j] = coded[count]  # Create an item in the dictionary with the value, and tell it which code correlates
      count += 1  # Count incremented
    codes[i] = specific_codes  # Create a new item in the overall dictionary with the dictionary created for this specific variable's codes


# View our created dictionary:
for i in codes:
  print("{} -".format(i))
  for j in codes[i]:
    print("{}: {}".format(j, codes[i][j]))
  print()
# Out:
# median_income -
# wealthy: 5
# well off: 4
# above average: 3
# average: 2
# below average: 1
# poverty: 0
# rich: 6
#
# ocean_proximity -
# NEAR BAY: 3
# <1H OCEAN: 0
# INLAND: 1
# NEAR OCEAN: 4
# ISLAND: 2

# %%
df.head()
#Checking that data is no longer categorical and now an integer at the end
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value  ocean_proximity
# 0       322.0       126.0              5            452600.0                3
# 1      2401.0      1138.0              5            358500.0                3
# 2       496.0       177.0              4            352100.0                3
# 3       558.0       219.0              3            341300.0                3
# 4       565.0       259.0              2            342200.0                3

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler
fs_data = df.copy() # copy of dataset for feature selection
x = fs_data.iloc[:,[0,1,2,3,4,5,6,7,8]]  # independent variables
y = fs_data.iloc[:,[9]]    # target column / what we're trying to predict


#https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html
#Found this easy way to split training data in the scikit documentation
#Shuffles data, and allocated 80% of it to be used for training, and 20% of it to be used for testing
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2) # splitting up dataset to training and testing

scl = RobustScaler() # Preprocess numerical data 
x_train = scl.fit_transform(x_train) 
x_test = scl.transform(x_test)

# %%
#x_train.head()

# %%
normalizer = tf.keras.layers.Normalization(axis=-1)
normalizer.adapt(x_train)
print(normalizer.mean.numpy())
# Out:
# 2022-11-12 19:21:36.183124: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-12 19:21:36.185464: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-11-12 19:21:36.186837: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory
# 2022-11-12 19:21:36.188102: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory
# 2022-11-12 19:21:36.189386: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory
# 2022-11-12 19:21:36.190651: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcurand.so.10'; dlerror: libcurand.so.10: cannot open shared object file: No such file or directory
# 2022-11-12 19:21:36.191841: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory
# 2022-11-12 19:21:36.193077: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory
# 2022-11-12 19:21:36.194146: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2022-11-12 19:21:36.194191: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2022-11-12 19:21:36.197428: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [[-0.28321138  0.3645564  -0.01974087  0.2989745   0.2933066   0.2739802
#    0.27874917  0.28172025  0.18621494]]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Flatten


print("--Make model--")
model = tf.keras.models.Sequential([
  normalizer,
  tf.keras.layers.Dense(256, activation='relu'),
  tf.keras.layers.Dropout(0.4),
  tf.keras.layers.Dense(256, activation='relu'),
  tf.keras.layers.Dropout(0.4),
  tf.keras.layers.Dense(10, activation='softmax'),
])
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

print("--Fit model--")
model.fit(x_train, y_train, epochs=200, verbose=2)
# Out:
# --Make model--
# --Fit model--
# Epoch 1/200
# 511/511 - 1s - loss: 0.7198 - accuracy: 0.7325 - 809ms/epoch - 2ms/step
# Epoch 2/200
# 511/511 - 1s - loss: 0.4922 - accuracy: 0.8046 - 574ms/epoch - 1ms/step
# Epoch 3/200
# 511/511 - 1s - loss: 0.4132 - accuracy: 0.8334 - 584ms/epoch - 1ms/step
# Epoch 4/200
# 511/511 - 1s - loss: 0.3708 - accuracy: 0.8509 - 580ms/epoch - 1ms/step
# Epoch 5/200
# 511/511 - 1s - loss: 0.3461 - accuracy: 0.8599 - 580ms/epoch - 1ms/step
# Epoch 6/200
# 511/511 - 1s - loss: 0.3243 - accuracy: 0.8711 - 561ms/epoch - 1ms/step
# Epoch 7/200
# 511/511 - 1s - loss: 0.3050 - accuracy: 0.8744 - 576ms/epoch - 1ms/step
# Epoch 8/200
# 511/511 - 1s - loss: 0.2989 - accuracy: 0.8791 - 573ms/epoch - 1ms/step
# Epoch 9/200
# 511/511 - 1s - loss: 0.2837 - accuracy: 0.8839 - 562ms/epoch - 1ms/step
# Epoch 10/200
# 511/511 - 1s - loss: 0.2774 - accuracy: 0.8893 - 591ms/epoch - 1ms/step
# Epoch 11/200
# 511/511 - 1s - loss: 0.2657 - accuracy: 0.8940 - 582ms/epoch - 1ms/step
# Epoch 12/200
# 511/511 - 1s - loss: 0.2589 - accuracy: 0.8951 - 616ms/epoch - 1ms/step
# Epoch 13/200
# 511/511 - 1s - loss: 0.2515 - accuracy: 0.8998 - 580ms/epoch - 1ms/step
# Epoch 14/200
# 511/511 - 1s - loss: 0.2523 - accuracy: 0.8990 - 564ms/epoch - 1ms/step
# Epoch 15/200
# 511/511 - 1s - loss: 0.2444 - accuracy: 0.9003 - 582ms/epoch - 1ms/step
# Epoch 16/200
# 511/511 - 1s - loss: 0.2427 - accuracy: 0.8991 - 582ms/epoch - 1ms/step
# Epoch 17/200
# 511/511 - 1s - loss: 0.2390 - accuracy: 0.9032 - 571ms/epoch - 1ms/step
# Epoch 18/200
# 511/511 - 1s - loss: 0.2367 - accuracy: 0.9036 - 579ms/epoch - 1ms/step
# Epoch 19/200
# 511/511 - 1s - loss: 0.2354 - accuracy: 0.9027 - 567ms/epoch - 1ms/step
# Epoch 20/200
# 511/511 - 1s - loss: 0.2320 - accuracy: 0.9079 - 566ms/epoch - 1ms/step
# Epoch 21/200
# 511/511 - 1s - loss: 0.2299 - accuracy: 0.9085 - 580ms/epoch - 1ms/step
# Epoch 22/200
# 511/511 - 1s - loss: 0.2258 - accuracy: 0.9078 - 582ms/epoch - 1ms/step
# Epoch 23/200
# 511/511 - 1s - loss: 0.2275 - accuracy: 0.9090 - 578ms/epoch - 1ms/step
# Epoch 24/200
# 511/511 - 1s - loss: 0.2199 - accuracy: 0.9092 - 582ms/epoch - 1ms/step
# Epoch 25/200
# 511/511 - 1s - loss: 0.2212 - accuracy: 0.9099 - 590ms/epoch - 1ms/step
# Epoch 26/200
# 511/511 - 1s - loss: 0.2159 - accuracy: 0.9127 - 591ms/epoch - 1ms/step
# Epoch 27/200
# 511/511 - 1s - loss: 0.2178 - accuracy: 0.9109 - 561ms/epoch - 1ms/step
# Epoch 28/200
# 511/511 - 1s - loss: 0.2159 - accuracy: 0.9114 - 558ms/epoch - 1ms/step
# Epoch 29/200
# 511/511 - 1s - loss: 0.2098 - accuracy: 0.9127 - 579ms/epoch - 1ms/step
# Epoch 30/200
# 511/511 - 1s - loss: 0.2105 - accuracy: 0.9143 - 582ms/epoch - 1ms/step
# Epoch 31/200
# 511/511 - 1s - loss: 0.2142 - accuracy: 0.9126 - 567ms/epoch - 1ms/step
# Epoch 32/200
# 511/511 - 1s - loss: 0.2145 - accuracy: 0.9104 - 570ms/epoch - 1ms/step
# Epoch 33/200
# 511/511 - 1s - loss: 0.2060 - accuracy: 0.9147 - 580ms/epoch - 1ms/step
# Epoch 34/200
# 511/511 - 1s - loss: 0.2079 - accuracy: 0.9152 - 577ms/epoch - 1ms/step
# Epoch 35/200
# 511/511 - 1s - loss: 0.2060 - accuracy: 0.9167 - 578ms/epoch - 1ms/step
# Epoch 36/200
# 511/511 - 1s - loss: 0.2053 - accuracy: 0.9159 - 559ms/epoch - 1ms/step
# Epoch 37/200
# 511/511 - 1s - loss: 0.2031 - accuracy: 0.9161 - 547ms/epoch - 1ms/step
# Epoch 38/200
# 511/511 - 1s - loss: 0.2017 - accuracy: 0.9170 - 548ms/epoch - 1ms/step
# Epoch 39/200
# 511/511 - 1s - loss: 0.1987 - accuracy: 0.9173 - 567ms/epoch - 1ms/step
# Epoch 40/200
# 511/511 - 1s - loss: 0.2037 - accuracy: 0.9192 - 562ms/epoch - 1ms/step
# Epoch 41/200
# 511/511 - 1s - loss: 0.1996 - accuracy: 0.9185 - 570ms/epoch - 1ms/step
# Epoch 42/200
# 511/511 - 1s - loss: 0.2033 - accuracy: 0.9158 - 595ms/epoch - 1ms/step
# Epoch 43/200
# 511/511 - 1s - loss: 0.1974 - accuracy: 0.9163 - 604ms/epoch - 1ms/step
# Epoch 44/200
# 511/511 - 1s - loss: 0.1994 - accuracy: 0.9191 - 587ms/epoch - 1ms/step
# Epoch 45/200
# 511/511 - 1s - loss: 0.2012 - accuracy: 0.9174 - 578ms/epoch - 1ms/step
# Epoch 46/200
# 511/511 - 1s - loss: 0.1993 - accuracy: 0.9177 - 574ms/epoch - 1ms/step
# Epoch 47/200
# 511/511 - 1s - loss: 0.1962 - accuracy: 0.9189 - 577ms/epoch - 1ms/step
# Epoch 48/200
# 511/511 - 1s - loss: 0.1925 - accuracy: 0.9199 - 619ms/epoch - 1ms/step
# Epoch 49/200
# 511/511 - 1s - loss: 0.1919 - accuracy: 0.9197 - 581ms/epoch - 1ms/step
# Epoch 50/200
# 511/511 - 1s - loss: 0.1924 - accuracy: 0.9185 - 587ms/epoch - 1ms/step
# Epoch 51/200
# 511/511 - 1s - loss: 0.1971 - accuracy: 0.9197 - 575ms/epoch - 1ms/step
# Epoch 52/200
# 511/511 - 1s - loss: 0.1971 - accuracy: 0.9204 - 592ms/epoch - 1ms/step
# Epoch 53/200
# 511/511 - 1s - loss: 0.1933 - accuracy: 0.9215 - 592ms/epoch - 1ms/step
# Epoch 54/200
# 511/511 - 1s - loss: 0.1919 - accuracy: 0.9206 - 561ms/epoch - 1ms/step
# Epoch 55/200
# 511/511 - 1s - loss: 0.1906 - accuracy: 0.9227 - 570ms/epoch - 1ms/step
# Epoch 56/200
# 511/511 - 1s - loss: 0.1856 - accuracy: 0.9228 - 582ms/epoch - 1ms/step
# Epoch 57/200
# 511/511 - 1s - loss: 0.1870 - accuracy: 0.9241 - 579ms/epoch - 1ms/step
# Epoch 58/200
# 511/511 - 1s - loss: 0.1883 - accuracy: 0.9221 - 567ms/epoch - 1ms/step
# Epoch 59/200
# 511/511 - 1s - loss: 0.1883 - accuracy: 0.9225 - 570ms/epoch - 1ms/step
# Epoch 60/200
# 511/511 - 1s - loss: 0.1886 - accuracy: 0.9218 - 559ms/epoch - 1ms/step
# Epoch 61/200
# 511/511 - 1s - loss: 0.1868 - accuracy: 0.9248 - 569ms/epoch - 1ms/step
# Epoch 62/200
# 511/511 - 1s - loss: 0.1920 - accuracy: 0.9210 - 578ms/epoch - 1ms/step
# Epoch 63/200
# 511/511 - 1s - loss: 0.1788 - accuracy: 0.9254 - 574ms/epoch - 1ms/step
# Epoch 64/200
# 511/511 - 1s - loss: 0.1866 - accuracy: 0.9223 - 565ms/epoch - 1ms/step
# Epoch 65/200
# 511/511 - 1s - loss: 0.1862 - accuracy: 0.9243 - 557ms/epoch - 1ms/step
# Epoch 66/200
# 511/511 - 1s - loss: 0.1834 - accuracy: 0.9234 - 581ms/epoch - 1ms/step
# Epoch 67/200
# 511/511 - 1s - loss: 0.1857 - accuracy: 0.9208 - 580ms/epoch - 1ms/step
# Epoch 68/200
# 511/511 - 1s - loss: 0.1760 - accuracy: 0.9255 - 575ms/epoch - 1ms/step
# Epoch 69/200
# 511/511 - 1s - loss: 0.1796 - accuracy: 0.9256 - 566ms/epoch - 1ms/step
# Epoch 70/200
# 511/511 - 1s - loss: 0.1786 - accuracy: 0.9272 - 577ms/epoch - 1ms/step
# Epoch 71/200
# 511/511 - 1s - loss: 0.1875 - accuracy: 0.9237 - 578ms/epoch - 1ms/step
# Epoch 72/200
# 511/511 - 1s - loss: 0.1764 - accuracy: 0.9259 - 589ms/epoch - 1ms/step
# Epoch 73/200
# 511/511 - 1s - loss: 0.1861 - accuracy: 0.9212 - 585ms/epoch - 1ms/step
# Epoch 74/200
# 511/511 - 1s - loss: 0.1768 - accuracy: 0.9268 - 583ms/epoch - 1ms/step
# Epoch 75/200
# 511/511 - 1s - loss: 0.1811 - accuracy: 0.9274 - 586ms/epoch - 1ms/step
# Epoch 76/200
# 511/511 - 1s - loss: 0.1774 - accuracy: 0.9273 - 616ms/epoch - 1ms/step
# Epoch 77/200
# 511/511 - 1s - loss: 0.1807 - accuracy: 0.9259 - 584ms/epoch - 1ms/step
# Epoch 78/200
# 511/511 - 1s - loss: 0.1732 - accuracy: 0.9287 - 577ms/epoch - 1ms/step
# Epoch 79/200
# 511/511 - 1s - loss: 0.1753 - accuracy: 0.9277 - 587ms/epoch - 1ms/step
# Epoch 80/200
# 511/511 - 1s - loss: 0.1815 - accuracy: 0.9260 - 583ms/epoch - 1ms/step
# Epoch 81/200
# 511/511 - 1s - loss: 0.1793 - accuracy: 0.9260 - 570ms/epoch - 1ms/step
# Epoch 82/200
# 511/511 - 1s - loss: 0.1755 - accuracy: 0.9272 - 580ms/epoch - 1ms/step
# Epoch 83/200
# 511/511 - 1s - loss: 0.1807 - accuracy: 0.9252 - 586ms/epoch - 1ms/step
# Epoch 84/200
# 511/511 - 1s - loss: 0.1744 - accuracy: 0.9262 - 575ms/epoch - 1ms/step
# Epoch 85/200
# 511/511 - 1s - loss: 0.1794 - accuracy: 0.9265 - 578ms/epoch - 1ms/step
# Epoch 86/200
# 511/511 - 1s - loss: 0.1733 - accuracy: 0.9283 - 575ms/epoch - 1ms/step
# Epoch 87/200
# 511/511 - 1s - loss: 0.1771 - accuracy: 0.9276 - 618ms/epoch - 1ms/step
# Epoch 88/200
# 511/511 - 1s - loss: 0.1727 - accuracy: 0.9287 - 587ms/epoch - 1ms/step
# Epoch 89/200
# 511/511 - 1s - loss: 0.1768 - accuracy: 0.9262 - 582ms/epoch - 1ms/step
# Epoch 90/200
# 511/511 - 1s - loss: 0.1750 - accuracy: 0.9271 - 578ms/epoch - 1ms/step
# Epoch 91/200
# 511/511 - 1s - loss: 0.1655 - accuracy: 0.9298 - 566ms/epoch - 1ms/step
# Epoch 92/200
# 511/511 - 1s - loss: 0.1756 - accuracy: 0.9273 - 562ms/epoch - 1ms/step
# Epoch 93/200
# 511/511 - 1s - loss: 0.1789 - accuracy: 0.9257 - 573ms/epoch - 1ms/step
# Epoch 94/200
# 511/511 - 1s - loss: 0.1747 - accuracy: 0.9282 - 579ms/epoch - 1ms/step
# Epoch 95/200
# 511/511 - 1s - loss: 0.1693 - accuracy: 0.9284 - 566ms/epoch - 1ms/step
# Epoch 96/200
# 511/511 - 1s - loss: 0.1730 - accuracy: 0.9263 - 584ms/epoch - 1ms/step
# Epoch 97/200
# 511/511 - 1s - loss: 0.1718 - accuracy: 0.9275 - 580ms/epoch - 1ms/step
# Epoch 98/200
# 511/511 - 1s - loss: 0.1683 - accuracy: 0.9283 - 578ms/epoch - 1ms/step
# Epoch 99/200
# 511/511 - 1s - loss: 0.1721 - accuracy: 0.9295 - 582ms/epoch - 1ms/step
# Epoch 100/200
# 511/511 - 1s - loss: 0.1727 - accuracy: 0.9268 - 579ms/epoch - 1ms/step
# Epoch 101/200
# 511/511 - 1s - loss: 0.1715 - accuracy: 0.9280 - 572ms/epoch - 1ms/step
# Epoch 102/200
# 511/511 - 1s - loss: 0.1711 - accuracy: 0.9288 - 575ms/epoch - 1ms/step
# Epoch 103/200
# 511/511 - 1s - loss: 0.1713 - accuracy: 0.9283 - 562ms/epoch - 1ms/step
# Epoch 104/200
# 511/511 - 1s - loss: 0.1690 - accuracy: 0.9285 - 559ms/epoch - 1ms/step
# Epoch 105/200
# 511/511 - 1s - loss: 0.1711 - accuracy: 0.9301 - 576ms/epoch - 1ms/step
# Epoch 106/200
# 511/511 - 1s - loss: 0.1716 - accuracy: 0.9293 - 561ms/epoch - 1ms/step
# Epoch 107/200
# 511/511 - 1s - loss: 0.1671 - accuracy: 0.9282 - 566ms/epoch - 1ms/step
# Epoch 108/200
# 511/511 - 1s - loss: 0.1681 - accuracy: 0.9304 - 575ms/epoch - 1ms/step
# Epoch 109/200
# 511/511 - 1s - loss: 0.1685 - accuracy: 0.9288 - 597ms/epoch - 1ms/step
# Epoch 110/200
# 511/511 - 1s - loss: 0.1725 - accuracy: 0.9282 - 617ms/epoch - 1ms/step
# Epoch 111/200
# 511/511 - 1s - loss: 0.1636 - accuracy: 0.9315 - 618ms/epoch - 1ms/step
# Epoch 112/200
# 511/511 - 1s - loss: 0.1636 - accuracy: 0.9329 - 618ms/epoch - 1ms/step
# Epoch 113/200
# 511/511 - 1s - loss: 0.1679 - accuracy: 0.9304 - 623ms/epoch - 1ms/step
# Epoch 114/200
# 511/511 - 1s - loss: 0.1662 - accuracy: 0.9302 - 617ms/epoch - 1ms/step
# Epoch 115/200
# 511/511 - 1s - loss: 0.1655 - accuracy: 0.9310 - 587ms/epoch - 1ms/step
# Epoch 116/200
# 511/511 - 1s - loss: 0.1644 - accuracy: 0.9309 - 587ms/epoch - 1ms/step
# Epoch 117/200
# 511/511 - 1s - loss: 0.1649 - accuracy: 0.9327 - 563ms/epoch - 1ms/step
# Epoch 118/200
# 511/511 - 1s - loss: 0.1627 - accuracy: 0.9320 - 568ms/epoch - 1ms/step
# Epoch 119/200
# 511/511 - 1s - loss: 0.1661 - accuracy: 0.9316 - 586ms/epoch - 1ms/step
# Epoch 120/200
# 511/511 - 1s - loss: 0.1647 - accuracy: 0.9323 - 574ms/epoch - 1ms/step
# Epoch 121/200
# 511/511 - 1s - loss: 0.1632 - accuracy: 0.9310 - 578ms/epoch - 1ms/step
# Epoch 122/200
# 511/511 - 1s - loss: 0.1657 - accuracy: 0.9308 - 572ms/epoch - 1ms/step
# Epoch 123/200
# 511/511 - 1s - loss: 0.1666 - accuracy: 0.9323 - 589ms/epoch - 1ms/step
# Epoch 124/200
# 511/511 - 1s - loss: 0.1620 - accuracy: 0.9331 - 569ms/epoch - 1ms/step
# Epoch 125/200
# 511/511 - 1s - loss: 0.1634 - accuracy: 0.9333 - 608ms/epoch - 1ms/step
# Epoch 126/200
# 511/511 - 1s - loss: 0.1641 - accuracy: 0.9325 - 575ms/epoch - 1ms/step
# Epoch 127/200
# 511/511 - 1s - loss: 0.1625 - accuracy: 0.9310 - 578ms/epoch - 1ms/step
# Epoch 128/200
# 511/511 - 1s - loss: 0.1611 - accuracy: 0.9334 - 591ms/epoch - 1ms/step
# Epoch 129/200
# 511/511 - 1s - loss: 0.1709 - accuracy: 0.9287 - 592ms/epoch - 1ms/step
# Epoch 130/200
# 511/511 - 1s - loss: 0.1629 - accuracy: 0.9311 - 576ms/epoch - 1ms/step
# Epoch 131/200
# 511/511 - 1s - loss: 0.1671 - accuracy: 0.9307 - 582ms/epoch - 1ms/step
# Epoch 132/200
# 511/511 - 1s - loss: 0.1594 - accuracy: 0.9326 - 576ms/epoch - 1ms/step
# Epoch 133/200
# 511/511 - 1s - loss: 0.1631 - accuracy: 0.9325 - 570ms/epoch - 1ms/step
# Epoch 134/200
# 511/511 - 1s - loss: 0.1573 - accuracy: 0.9333 - 573ms/epoch - 1ms/step
# Epoch 135/200
# 511/511 - 1s - loss: 0.1631 - accuracy: 0.9321 - 584ms/epoch - 1ms/step
# Epoch 136/200
# 511/511 - 1s - loss: 0.1634 - accuracy: 0.9303 - 583ms/epoch - 1ms/step
# Epoch 137/200
# 511/511 - 1s - loss: 0.1616 - accuracy: 0.9334 - 568ms/epoch - 1ms/step
# Epoch 138/200
# 511/511 - 1s - loss: 0.1595 - accuracy: 0.9316 - 573ms/epoch - 1ms/step
# Epoch 139/200
# 511/511 - 1s - loss: 0.1533 - accuracy: 0.9348 - 578ms/epoch - 1ms/step
# Epoch 140/200
# 511/511 - 1s - loss: 0.1540 - accuracy: 0.9341 - 582ms/epoch - 1ms/step
# Epoch 141/200
# 511/511 - 1s - loss: 0.1612 - accuracy: 0.9332 - 558ms/epoch - 1ms/step
# Epoch 142/200
# 511/511 - 1s - loss: 0.1568 - accuracy: 0.9342 - 587ms/epoch - 1ms/step
# Epoch 143/200
# 511/511 - 1s - loss: 0.1575 - accuracy: 0.9349 - 583ms/epoch - 1ms/step
# Epoch 144/200
# 511/511 - 1s - loss: 0.1629 - accuracy: 0.9313 - 574ms/epoch - 1ms/step
# Epoch 145/200
# 511/511 - 1s - loss: 0.1595 - accuracy: 0.9339 - 571ms/epoch - 1ms/step
# Epoch 146/200
# 511/511 - 1s - loss: 0.1583 - accuracy: 0.9338 - 571ms/epoch - 1ms/step
# Epoch 147/200
# 511/511 - 1s - loss: 0.1561 - accuracy: 0.9357 - 576ms/epoch - 1ms/step
# Epoch 148/200
# 511/511 - 1s - loss: 0.1579 - accuracy: 0.9352 - 576ms/epoch - 1ms/step
# Epoch 149/200
# 511/511 - 1s - loss: 0.1609 - accuracy: 0.9369 - 580ms/epoch - 1ms/step
# Epoch 150/200
# 511/511 - 1s - loss: 0.1558 - accuracy: 0.9355 - 580ms/epoch - 1ms/step
# Epoch 151/200
# 511/511 - 1s - loss: 0.1551 - accuracy: 0.9348 - 571ms/epoch - 1ms/step
# Epoch 152/200
# 511/511 - 1s - loss: 0.1581 - accuracy: 0.9344 - 560ms/epoch - 1ms/step
# Epoch 153/200
# 511/511 - 1s - loss: 0.1575 - accuracy: 0.9356 - 541ms/epoch - 1ms/step
# Epoch 154/200
# 511/511 - 1s - loss: 0.1573 - accuracy: 0.9347 - 526ms/epoch - 1ms/step
# Epoch 155/200
# 511/511 - 1s - loss: 0.1505 - accuracy: 0.9337 - 535ms/epoch - 1ms/step
# Epoch 156/200
# 511/511 - 1s - loss: 0.1549 - accuracy: 0.9365 - 521ms/epoch - 1ms/step
# Epoch 157/200
# 511/511 - 1s - loss: 0.1524 - accuracy: 0.9356 - 524ms/epoch - 1ms/step
# Epoch 158/200
# 511/511 - 1s - loss: 0.1558 - accuracy: 0.9355 - 564ms/epoch - 1ms/step
# Epoch 159/200
# 511/511 - 1s - loss: 0.1555 - accuracy: 0.9367 - 590ms/epoch - 1ms/step
# Epoch 160/200
# 511/511 - 1s - loss: 0.1505 - accuracy: 0.9394 - 572ms/epoch - 1ms/step
# Epoch 161/200
# 511/511 - 1s - loss: 0.1521 - accuracy: 0.9356 - 570ms/epoch - 1ms/step
# Epoch 162/200
# 511/511 - 1s - loss: 0.1592 - accuracy: 0.9328 - 583ms/epoch - 1ms/step
# Epoch 163/200
# 511/511 - 1s - loss: 0.1540 - accuracy: 0.9367 - 570ms/epoch - 1ms/step
# Epoch 164/200
# 511/511 - 1s - loss: 0.1533 - accuracy: 0.9361 - 580ms/epoch - 1ms/step
# Epoch 165/200
# 511/511 - 1s - loss: 0.1503 - accuracy: 0.9379 - 602ms/epoch - 1ms/step
# Epoch 166/200
# 511/511 - 1s - loss: 0.1481 - accuracy: 0.9399 - 565ms/epoch - 1ms/step
# Epoch 167/200
# 511/511 - 1s - loss: 0.1513 - accuracy: 0.9393 - 594ms/epoch - 1ms/step
# Epoch 168/200
# 511/511 - 1s - loss: 0.1563 - accuracy: 0.9360 - 601ms/epoch - 1ms/step
# Epoch 169/200
# 511/511 - 1s - loss: 0.1489 - accuracy: 0.9361 - 585ms/epoch - 1ms/step
# Epoch 170/200
# 511/511 - 1s - loss: 0.1509 - accuracy: 0.9377 - 580ms/epoch - 1ms/step
# Epoch 171/200
# 511/511 - 1s - loss: 0.1519 - accuracy: 0.9359 - 555ms/epoch - 1ms/step
# Epoch 172/200
# 511/511 - 1s - loss: 0.1507 - accuracy: 0.9380 - 581ms/epoch - 1ms/step
# Epoch 173/200
# 511/511 - 1s - loss: 0.1520 - accuracy: 0.9385 - 586ms/epoch - 1ms/step
# Epoch 174/200
# 511/511 - 1s - loss: 0.1565 - accuracy: 0.9377 - 591ms/epoch - 1ms/step
# Epoch 175/200
# 511/511 - 1s - loss: 0.1514 - accuracy: 0.9375 - 579ms/epoch - 1ms/step
# Epoch 176/200
# 511/511 - 1s - loss: 0.1614 - accuracy: 0.9363 - 564ms/epoch - 1ms/step
# Epoch 177/200
# 511/511 - 1s - loss: 0.1515 - accuracy: 0.9381 - 580ms/epoch - 1ms/step
# Epoch 178/200
# 511/511 - 1s - loss: 0.1575 - accuracy: 0.9340 - 586ms/epoch - 1ms/step
# Epoch 179/200
# 511/511 - 1s - loss: 0.1477 - accuracy: 0.9394 - 556ms/epoch - 1ms/step
# Epoch 180/200
# 511/511 - 1s - loss: 0.1524 - accuracy: 0.9376 - 581ms/epoch - 1ms/step
# Epoch 181/200
# 511/511 - 1s - loss: 0.1536 - accuracy: 0.9361 - 568ms/epoch - 1ms/step
# Epoch 182/200
# 511/511 - 1s - loss: 0.1488 - accuracy: 0.9377 - 581ms/epoch - 1ms/step
# Epoch 183/200
# 511/511 - 1s - loss: 0.1565 - accuracy: 0.9362 - 581ms/epoch - 1ms/step
# Epoch 184/200
# 511/511 - 1s - loss: 0.1507 - accuracy: 0.9386 - 582ms/epoch - 1ms/step
# Epoch 185/200
# 511/511 - 1s - loss: 0.1551 - accuracy: 0.9352 - 570ms/epoch - 1ms/step
# Epoch 186/200
# 511/511 - 1s - loss: 0.1514 - accuracy: 0.9370 - 549ms/epoch - 1ms/step
# Epoch 187/200
# 511/511 - 1s - loss: 0.1499 - accuracy: 0.9367 - 534ms/epoch - 1ms/step
# Epoch 188/200
# 511/511 - 1s - loss: 0.1510 - accuracy: 0.9371 - 537ms/epoch - 1ms/step
# Epoch 189/200
# 511/511 - 1s - loss: 0.1444 - accuracy: 0.9386 - 583ms/epoch - 1ms/step
# Epoch 190/200
# 511/511 - 1s - loss: 0.1491 - accuracy: 0.9390 - 581ms/epoch - 1ms/step
# Epoch 191/200
# 511/511 - 1s - loss: 0.1544 - accuracy: 0.9345 - 587ms/epoch - 1ms/step
# Epoch 192/200
# 511/511 - 1s - loss: 0.1501 - accuracy: 0.9388 - 568ms/epoch - 1ms/step
# Epoch 193/200
# 511/511 - 1s - loss: 0.1405 - accuracy: 0.9419 - 577ms/epoch - 1ms/step
# Epoch 194/200
# 511/511 - 1s - loss: 0.1485 - accuracy: 0.9401 - 568ms/epoch - 1ms/step
# Epoch 195/200
# 511/511 - 1s - loss: 0.1503 - accuracy: 0.9383 - 563ms/epoch - 1ms/step
# Epoch 196/200
# 511/511 - 1s - loss: 0.1527 - accuracy: 0.9372 - 590ms/epoch - 1ms/step
# Epoch 197/200
# 511/511 - 1s - loss: 0.1474 - accuracy: 0.9382 - 577ms/epoch - 1ms/step
# Epoch 198/200
# 511/511 - 1s - loss: 0.1459 - accuracy: 0.9408 - 575ms/epoch - 1ms/step
# Epoch 199/200
# 511/511 - 1s - loss: 0.1513 - accuracy: 0.9358 - 586ms/epoch - 1ms/step
# Epoch 200/200
# 511/511 - 1s - loss: 0.1498 - accuracy: 0.9402 - 588ms/epoch - 1ms/step

# %%
#Saving model
model.save("main4classif", save_format='h5')
#saved and labeled my current model at 96% accuracy

# %%
print("--Evaluate model--")
model_loss1, model_acc1 = model.evaluate(x_train,  y_train, verbose=2)
model_loss2, model_acc2 = model.evaluate(x_test,  y_test, verbose=2)
print(f"Train / Test Accuracy: {model_acc1*100:.1f}% / {model_acc2*100:.1f}%")
# Out:
# --Evaluate model--
# 511/511 - 0s - loss: 0.1048 - accuracy: 0.9601 - 437ms/epoch - 856us/step
# 128/128 - 0s - loss: 0.1403 - accuracy: 0.9423 - 102ms/epoch - 795us/step
# Train / Test Accuracy: 96.0% / 94.2%

# %% [markdown]
# Report for Main part 2:
#
# Before I start I want to point out that for this part of the assignment, I converted my median_income from a numerical income to a categorical one by using pandas.
# ```py
# data['median_income']=pd.cut(data['median_income'],bins=[0, 1.5, 2.5, 4, 6, 8, 10, 1000],
# include_lowest=True,
# labels=['poverty','below average','average','above average','well off','wealthy','rich'])
# ```
# I did this for two reasons, the major reason was due to the fact that I wanted to use ocean_proximity as an output, which would leave me with no categorical inputs for my model. The second and important reason was, that I felt that these income values made no sense, and were just random floats, essentially diving areas into wealth classes, which I felt would be better represented as categories. So thats what I did, since the values had a wide range, I used a pandas function to map each of the values in the column to an appropriate tag, based on how high the median_income was in that neighborhood.
#
# Columns used as input and output
# Input: longitude	latitude	housing_median_age	total_rooms	total_bedrooms	population	households	median_house_value
# Output: ocean_proximity
#
# For my input, I chose every column except median_income as that was categorical, and ocean_proximity as that was my output.
# The reason for this was because that I was hoping my model would be able to make a connection between the richer and higher demand areas in california, would have houses with more rooms/bedrooms, and the house would be worth more in general. That way when the model see's a house thats worth a lot and has a lot of rooms, it might have a baseline assumption that x house is in y rich area, and the same goes for the houses worth less.
#
# I split my training and testing data in a 80/20 split. This was because after randomizing my data, I decided that it would be much more worthwhile to give my data a significantly larger variety to train on than test on. This is because testing is used to see the accuracy of the model, and to get higher accuracy, the model needs to train on a much larger variety, so that if the test has a strange input, it can still make a decision based on the experience that it has, but if I make my training input smaller, it becomes more and more likely that the test will have an input that the model has little to no experience for.
#
# Two decisions that I made for my model design was to process my input. One thing that I did that I felt had a big impact on the accuracy was that I scaled the numerical inputs with the RobustScaler from sklearn (Based on Joweria's process), the second thing that I felt had a big impact was that I normalized the inputs, as the inputs were all numbers that were very different from each other. Normalizing them was important for the model to be able to make sense of things with less difficulty.
#
# In terms of hyper parameters, I had my normalizer, and then I just attempted to make a relatively dense model with lots of layers with the relu activation. Meaning i added lots of the Dense layers. I found that I haven't needed to mess with the units in the softmax layer yet, but I will probably begin experimenting with it during part 3 or 4 of main.
#
# Currently my model is quite accurate, getting 97.2% accuracy on the training, and 94.4% accuracy on the test. Despite this being a pretty acceptable number, I think this discrepency between the two shows that my model is over-fitted to the training data, and the test shouldnt have a signficicant amount of outliers in comparison to the training data, so for the next iterations I will try to fix this discrepency between training and test data. But I also believe that overall accuracy will rise with the introduction of the income column (categorical) column later on.

# %%
#Visualization of for main part three
scatplot = sns.scatterplot(data=data, x = "median_house_value", y = "population")
fig = scatplot.get_figure()
fig.savefig("../main3/visualization.png")

# %% [markdown]
# Part 3 Report
# --
# From the notMNIST model that I built I learned a few things to help with over-fitting,
# one thing that I noticed was that too many epochs, would cause over-fitting quite fast once the model started to become confident. To fix this over-fitting issue, what I found helped was to increase the density of a specific layer and then to reduce the number of epochs.
# So thats exactly what I did. I experimented with how many layers to increase the density of, and decided to settle on my first Dense layer increasing from 64 to 128, then I lowered the training epochs from 200 to 120.
#
# This increased my models accuracy from ~94% to 96%, which is a solid improvement, and shows that the over-fitting issue was slightly reduced.
#
# I believe that one of the reason for the over-fitting issue is that there is quite a few outliers, which makes it harder for my model to predict. As seen in the visualization below. (also in the code block above)
#
# ![vis](visualization.png)
#
# From the scatter plot, we can tell that overall, there seems to be a even distribution of population to house value, with areas with smaller populations tend to have more expensive houses.
#
# But there is also a signficant number of outliers, especially in the upper and lower end of the data, which could explain the reason that the model is unable to predict accurately when it comes across one of these outliers.
