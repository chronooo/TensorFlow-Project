# %%
#Main Project Stage 1: Data Science and Machine Learning
# Import the required libraries

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn
import tensorflow as tf

# Set sns theme to your preferred color palette
sns.set_theme(palette = "mako")

data = pd.read_csv('../data/data-input.csv')  # read csv file
data.to_csv("../data/data.csv",index=False)
#data input is the data that I had previously cleaned before starting the assignment
data = pd.read_csv("../data/data.csv") #pretty confused as to why the instructions ask for this, but I guess its not a big deal
data['median_income']=pd.cut(data['median_income'],bins=[0, 1.5, 2.5, 4, 6, 8, 10, 1000], 
include_lowest=True, 
labels=['poverty','below average','average','above average','well off','wealthy','rich'])
df = data.copy()  # create a copy to use for future reference, so I have a copy of my original dataset when needed

data.head()
#Cleaned data (now called data-input.csv) by hand beforehand before reading instructions, so my data is already good.
#Will be skipping the pandas clean data step
# Out:
# 2022-11-12 20:04:06.719737: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-12 20:04:18.509285: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-11-12 20:04:18.509335: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-11-12 20:04:19.830418: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-11-12 20:04:32.552220: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2022-11-12 20:04:32.554989: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2022-11-12 20:04:32.555032: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0        wealthy            452600.0        NEAR BAY
# 1      2401.0      1138.0        wealthy            358500.0        NEAR BAY
# 2       496.0       177.0       well off            352100.0        NEAR BAY
# 3       558.0       219.0  above average            341300.0        NEAR BAY
# 4       565.0       259.0        average            342200.0        NEAR BAY

# %%
#Histogram showing distribution of housing age in the market
agehist = sns.histplot(data=df, x = "housing_median_age")
fig = agehist.get_figure()
fig.savefig("../plots/plot1.png")

# %%
#Visualization of relationship (and variation) in housing price based on its age
age_value_lineplot = sns.lineplot(data=df, x = "housing_median_age", y = "median_house_value")
fig = age_value_lineplot.get_figure()
fig.savefig("../plots/plot2.png")

# %%
#Visualization of price distribution of houses in california
house_value_histplot = sns.histplot(data=df, x = "median_house_value")
fig = house_value_histplot.get_figure()
fig.savefig("../plots/plot3.png") 
#Can see from output that a majority of the houses are from 150k to 250k

# %% [markdown]
# Where the data came from.:
#
# https://www.kaggle.com/datasets/kathuman/housing
# I will be using the dataset on Housing Prices in California found on Kaggle with a creative Commons Public Domain License
# Description of data from creator:
# "This dataset is based on data from the 1990 California Census, and incluides metrics such as the population, median income, and median housing proice for each block group in California.
# Block groups are the smallest geographical unit for which the US Census Bureau publishes sample data., and each block typically has between 600 to 3000 people."
#
# The goal I have with this dataset is to be able to get my model to guess the price of houses given all the other information.
#
#
# Challenges cleaning:
#
# One of the challenges I had cleaning was that the dataset was humongous (22k rows) so I worried that I missed some stuff while cleaning but overall it was pretty straightforward. I cleaned it by hand before starting the assignment, and the biggest issue was that there was a lot of data to delete by hand. There was a lot of cells that just had nothing inside it, so I had to delete the entire line, which meant I couldnt automate it with find and replace. But other than that, the data seems pretty clean, and there are some spots in the data that I might need to go back and change, but for now I think the data looks reliable, based on the distribution I've seen from my graphs.
#
# Three visualizations:
#
# plot1 is a distribution of the age of the house. We can see that california has a wide range of ages for their houses. But their seems to be a spike in houses that are around 20, 30, and 50+ years old. Overall I think the distribution in that column is pretty good, and should pose no issues in training my model.
#
# plot2 is a visualization of relationship (and variation) in housing price based on its age. One thing that bothered me in this, is that from the graph, the house prices seem to very a lot for some age groups, specifically ~10 years old and ~50 years old. I worry that this will have negative effects in the model, but at the same time, logically speaking this is a realistic scenario. As old houses that are still standing are likely to be very nice to begin with, and new houses that are being built are being built for many different types of people with different incomes, especially in california where there is a large amount of wealthy and average people concentrated in one area.
#
# plot3 is a visualization of price distribution of houses in california. I wanted to see where the price of houses was concentrated, this graph allowed me to see that a majority of the houses in california in the dataset are around $150k-250k. But there is also a sizeable amount of houses below and above that number. Which should pose as good variation to give model a wide range of information to make accurate estimates.
#
# Part 2 code begins after this report
# --

# %%
df.shape  # Will return the number of rows and columns
# Out:
# (20433, 10)

# %%
df.info()  # Will inform you of the datatype of each variable, as well as if there are any null or missing values in each column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20433 entries, 0 to 20432
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  category
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: category(1), float64(8), object(1)
# memory usage: 1.4+ MB

# %%
df.describe().T # Describe the data-frame (transposed) - defaults to describing only numerical
# If you want to describe all, run the following command:
# data.describe(include = "all").T
# Out:
#                       count           mean            std       min  \
# longitude           20433.0    -119.570689       2.003578   -124.35
# latitude            20433.0      35.633221       2.136348     32.54
# housing_median_age  20433.0      28.633094      12.591805      1.00
# total_rooms         20433.0    2636.504233    2185.269567      2.00
# total_bedrooms      20433.0     537.870553     421.385070      1.00
# population          20433.0    1424.946949    1133.208490      3.00
# households          20433.0     499.433465     382.299226      1.00
# median_house_value  20433.0  206864.413155  115435.667099  14999.00
#
#                           25%        50%        75%        max
# longitude             -121.80    -118.49    -118.01    -114.31
# latitude                33.93      34.26      37.72      41.95
# housing_median_age      18.00      29.00      37.00      52.00
# total_rooms           1450.00    2127.00    3143.00   39320.00
# total_bedrooms         296.00     435.00     647.00    6445.00
# population             787.00    1166.00    1722.00   35682.00
# households             280.00     409.00     604.00    6082.00
# median_house_value  119500.00  179700.00  264700.00  500001.00

# %%
df.isnull().sum()  # Checking for null values
# In this case there are no null values. If there are some, you can use a heatmap to visualize them if you want.
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
#Organizing categorical data
#Citation is from Joweria's heartdisease tutorial notebook
from pandas.core.arrays import categorical 
categorical_data = ["ocean_proximity","median_income"]

codes = {}  # Create a dictionary to store the codes of the conversion
for i in df:  # For each variable in the data frame 
  if i in categorical_data:  # For each variable that was classified as categorical
    specific_codes = {}  # Create a dictionary for that variable's code conversion 
    df[i] = df[i].astype("category")  # Convert that variable from 'object' datatype to category
    df[i] = df[i].cat.codes  # Create codes for the categories and replace in the dataset 
    coded = df[i].unique()  # Get the unique values (the codes) from the variable
    count = 0  # Count initialized. Later used for accessing specific indexes
    for j in data[i].unique():  # For each unique value
      specific_codes[j] = coded[count]  # Create an item in the dictionary with the value, and tell it which code correlates
      count += 1  # Count incremented
    codes[i] = specific_codes  # Create a new item in the overall dictionary with the dictionary created for this specific variable's codes


# View our created dictionary:
for i in codes:
  print("{} -".format(i))
  for j in codes[i]:
    print("{}: {}".format(j, codes[i][j]))
  print()
# Out:
# median_income -
# wealthy: 5
# well off: 4
# above average: 3
# average: 2
# below average: 1
# poverty: 0
# rich: 6
#
# ocean_proximity -
# NEAR BAY: 3
# <1H OCEAN: 0
# INLAND: 1
# NEAR OCEAN: 4
# ISLAND: 2

# %%
df.head()
#Checking that data is no longer categorical and now an integer at the end
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value  ocean_proximity
# 0       322.0       126.0              5            452600.0                3
# 1      2401.0      1138.0              5            358500.0                3
# 2       496.0       177.0              4            352100.0                3
# 3       558.0       219.0              3            341300.0                3
# 4       565.0       259.0              2            342200.0                3

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler
fs_data = df.copy() # copy of dataset for feature selection
x = fs_data.iloc[:,[0,1,2,3,4,5,6,7,8]]  # independent variables
y = fs_data.iloc[:,[9]]    # target column / what we're trying to predict


#https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html
#Found this easy way to split training data in the scikit documentation
#Shuffles data, and allocated 80% of it to be used for training, and 20% of it to be used for testing
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2) # splitting up dataset to training and testing

scl = RobustScaler() # Preprocess numerical data 
x_train = scl.fit_transform(x_train) 
x_test = scl.transform(x_test)

# %%
#x_train.head()

# %%
normalizer = tf.keras.layers.Normalization(axis=-1)
normalizer.adapt(x_train)
print(normalizer.mean.numpy())
# Out:
# [[-0.28418154  0.3627324  -0.01725192  0.2989843   0.2953465   0.27249256
#    0.27917844  0.28453416  0.18837123]]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Flatten


print("--Make model--")
model = tf.keras.models.Sequential([
  normalizer,
  tf.keras.layers.Dense(256, activation='relu'),
  tf.keras.layers.Dense(256, activation='relu'),
  tf.keras.layers.Dropout(0.4),
  tf.keras.layers.Dense(256, activation='relu'),
  tf.keras.layers.Dropout(0.4),
  tf.keras.layers.Dense(10, activation='softmax'),
])
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

print("--Fit model--")
model.fit(x_train, y_train, epochs=200, verbose=2)
# Out:
# --Make model--
# --Fit model--
# Epoch 1/200
# 511/511 - 1s - loss: 0.6556 - accuracy: 0.7549 - 1s/epoch - 2ms/step
# Epoch 2/200
# 511/511 - 1s - loss: 0.3929 - accuracy: 0.8412 - 659ms/epoch - 1ms/step
# Epoch 3/200
# 511/511 - 1s - loss: 0.3394 - accuracy: 0.8591 - 656ms/epoch - 1ms/step
# Epoch 4/200
# 511/511 - 1s - loss: 0.2992 - accuracy: 0.8773 - 664ms/epoch - 1ms/step
# Epoch 5/200
# 511/511 - 1s - loss: 0.2728 - accuracy: 0.8898 - 666ms/epoch - 1ms/step
# Epoch 6/200
# 511/511 - 1s - loss: 0.2579 - accuracy: 0.8940 - 662ms/epoch - 1ms/step
# Epoch 7/200
# 511/511 - 1s - loss: 0.2496 - accuracy: 0.8999 - 670ms/epoch - 1ms/step
# Epoch 8/200
# 511/511 - 1s - loss: 0.2350 - accuracy: 0.9047 - 670ms/epoch - 1ms/step
# Epoch 9/200
# 511/511 - 1s - loss: 0.2311 - accuracy: 0.9049 - 661ms/epoch - 1ms/step
# Epoch 10/200
# 511/511 - 1s - loss: 0.2176 - accuracy: 0.9109 - 658ms/epoch - 1ms/step
# Epoch 11/200
# 511/511 - 1s - loss: 0.2143 - accuracy: 0.9118 - 657ms/epoch - 1ms/step
# Epoch 12/200
# 511/511 - 1s - loss: 0.2086 - accuracy: 0.9158 - 662ms/epoch - 1ms/step
# Epoch 13/200
# 511/511 - 1s - loss: 0.2068 - accuracy: 0.9145 - 659ms/epoch - 1ms/step
# Epoch 14/200
# 511/511 - 1s - loss: 0.2042 - accuracy: 0.9166 - 686ms/epoch - 1ms/step
# Epoch 15/200
# 511/511 - 1s - loss: 0.1989 - accuracy: 0.9159 - 660ms/epoch - 1ms/step
# Epoch 16/200
# 511/511 - 1s - loss: 0.2006 - accuracy: 0.9164 - 664ms/epoch - 1ms/step
# Epoch 17/200
# 511/511 - 1s - loss: 0.1914 - accuracy: 0.9184 - 653ms/epoch - 1ms/step
# Epoch 18/200
# 511/511 - 1s - loss: 0.1851 - accuracy: 0.9265 - 667ms/epoch - 1ms/step
# Epoch 19/200
# 511/511 - 1s - loss: 0.1881 - accuracy: 0.9207 - 657ms/epoch - 1ms/step
# Epoch 20/200
# 511/511 - 1s - loss: 0.1862 - accuracy: 0.9223 - 650ms/epoch - 1ms/step
# Epoch 21/200
# 511/511 - 1s - loss: 0.1788 - accuracy: 0.9248 - 647ms/epoch - 1ms/step
# Epoch 22/200
# 511/511 - 1s - loss: 0.1772 - accuracy: 0.9238 - 645ms/epoch - 1ms/step
# Epoch 23/200
# 511/511 - 1s - loss: 0.1774 - accuracy: 0.9252 - 648ms/epoch - 1ms/step
# Epoch 24/200
# 511/511 - 1s - loss: 0.1735 - accuracy: 0.9273 - 648ms/epoch - 1ms/step
# Epoch 25/200
# 511/511 - 1s - loss: 0.1722 - accuracy: 0.9266 - 655ms/epoch - 1ms/step
# Epoch 26/200
# 511/511 - 1s - loss: 0.1709 - accuracy: 0.9289 - 659ms/epoch - 1ms/step
# Epoch 27/200
# 511/511 - 1s - loss: 0.1730 - accuracy: 0.9279 - 658ms/epoch - 1ms/step
# Epoch 28/200
# 511/511 - 1s - loss: 0.1636 - accuracy: 0.9298 - 661ms/epoch - 1ms/step
# Epoch 29/200
# 511/511 - 1s - loss: 0.1614 - accuracy: 0.9309 - 657ms/epoch - 1ms/step
# Epoch 30/200
# 511/511 - 1s - loss: 0.1644 - accuracy: 0.9323 - 653ms/epoch - 1ms/step
# Epoch 31/200
# 511/511 - 1s - loss: 0.1674 - accuracy: 0.9296 - 653ms/epoch - 1ms/step
# Epoch 32/200
# 511/511 - 1s - loss: 0.1587 - accuracy: 0.9324 - 658ms/epoch - 1ms/step
# Epoch 33/200
# 511/511 - 1s - loss: 0.1544 - accuracy: 0.9345 - 662ms/epoch - 1ms/step
# Epoch 34/200
# 511/511 - 1s - loss: 0.1579 - accuracy: 0.9350 - 659ms/epoch - 1ms/step
# Epoch 35/200
# 511/511 - 1s - loss: 0.1520 - accuracy: 0.9362 - 655ms/epoch - 1ms/step
# Epoch 36/200
# 511/511 - 1s - loss: 0.1537 - accuracy: 0.9359 - 656ms/epoch - 1ms/step
# Epoch 37/200
# 511/511 - 1s - loss: 0.1588 - accuracy: 0.9346 - 650ms/epoch - 1ms/step
# Epoch 38/200
# 511/511 - 1s - loss: 0.1527 - accuracy: 0.9354 - 652ms/epoch - 1ms/step
# Epoch 39/200
# 511/511 - 1s - loss: 0.1537 - accuracy: 0.9338 - 650ms/epoch - 1ms/step
# Epoch 40/200
# 511/511 - 1s - loss: 0.1504 - accuracy: 0.9373 - 656ms/epoch - 1ms/step
# Epoch 41/200
# 511/511 - 1s - loss: 0.1516 - accuracy: 0.9352 - 657ms/epoch - 1ms/step
# Epoch 42/200
# 511/511 - 1s - loss: 0.1480 - accuracy: 0.9370 - 655ms/epoch - 1ms/step
# Epoch 43/200
# 511/511 - 1s - loss: 0.1456 - accuracy: 0.9394 - 655ms/epoch - 1ms/step
# Epoch 44/200
# 511/511 - 1s - loss: 0.1428 - accuracy: 0.9381 - 658ms/epoch - 1ms/step
# Epoch 45/200
# 511/511 - 1s - loss: 0.1476 - accuracy: 0.9381 - 657ms/epoch - 1ms/step
# Epoch 46/200
# 511/511 - 1s - loss: 0.1383 - accuracy: 0.9426 - 659ms/epoch - 1ms/step
# Epoch 47/200
# 511/511 - 1s - loss: 0.1427 - accuracy: 0.9408 - 661ms/epoch - 1ms/step
# Epoch 48/200
# 511/511 - 1s - loss: 0.1433 - accuracy: 0.9394 - 677ms/epoch - 1ms/step
# Epoch 49/200
# 511/511 - 1s - loss: 0.1405 - accuracy: 0.9405 - 647ms/epoch - 1ms/step
# Epoch 50/200
# 511/511 - 1s - loss: 0.1343 - accuracy: 0.9439 - 659ms/epoch - 1ms/step
# Epoch 51/200
# 511/511 - 1s - loss: 0.1390 - accuracy: 0.9413 - 651ms/epoch - 1ms/step
# Epoch 52/200
# 511/511 - 1s - loss: 0.1418 - accuracy: 0.9426 - 661ms/epoch - 1ms/step
# Epoch 53/200
# 511/511 - 1s - loss: 0.1404 - accuracy: 0.9413 - 651ms/epoch - 1ms/step
# Epoch 54/200
# 511/511 - 1s - loss: 0.1402 - accuracy: 0.9409 - 664ms/epoch - 1ms/step
# Epoch 55/200
# 511/511 - 1s - loss: 0.1368 - accuracy: 0.9430 - 659ms/epoch - 1ms/step
# Epoch 56/200
# 511/511 - 1s - loss: 0.1306 - accuracy: 0.9437 - 653ms/epoch - 1ms/step
# Epoch 57/200
# 511/511 - 1s - loss: 0.1295 - accuracy: 0.9443 - 663ms/epoch - 1ms/step
# Epoch 58/200
# 511/511 - 1s - loss: 0.1327 - accuracy: 0.9449 - 654ms/epoch - 1ms/step
# Epoch 59/200
# 511/511 - 1s - loss: 0.1352 - accuracy: 0.9434 - 663ms/epoch - 1ms/step
# Epoch 60/200
# 511/511 - 1s - loss: 0.1371 - accuracy: 0.9421 - 663ms/epoch - 1ms/step
# Epoch 61/200
# 511/511 - 1s - loss: 0.1456 - accuracy: 0.9396 - 659ms/epoch - 1ms/step
# Epoch 62/200
# 511/511 - 1s - loss: 0.1275 - accuracy: 0.9467 - 663ms/epoch - 1ms/step
# Epoch 63/200
# 511/511 - 1s - loss: 0.1286 - accuracy: 0.9467 - 662ms/epoch - 1ms/step
# Epoch 64/200
# 511/511 - 1s - loss: 0.1272 - accuracy: 0.9466 - 661ms/epoch - 1ms/step
# Epoch 65/200
# 511/511 - 1s - loss: 0.1292 - accuracy: 0.9456 - 651ms/epoch - 1ms/step
# Epoch 66/200
# 511/511 - 1s - loss: 0.1321 - accuracy: 0.9435 - 657ms/epoch - 1ms/step
# Epoch 67/200
# 511/511 - 1s - loss: 0.1246 - accuracy: 0.9481 - 663ms/epoch - 1ms/step
# Epoch 68/200
# 511/511 - 1s - loss: 0.1272 - accuracy: 0.9457 - 660ms/epoch - 1ms/step
# Epoch 69/200
# 511/511 - 1s - loss: 0.1302 - accuracy: 0.9459 - 664ms/epoch - 1ms/step
# Epoch 70/200
# 511/511 - 1s - loss: 0.1271 - accuracy: 0.9451 - 661ms/epoch - 1ms/step
# Epoch 71/200
# 511/511 - 1s - loss: 0.1268 - accuracy: 0.9477 - 662ms/epoch - 1ms/step
# Epoch 72/200
# 511/511 - 1s - loss: 0.1260 - accuracy: 0.9472 - 661ms/epoch - 1ms/step
# Epoch 73/200
# 511/511 - 1s - loss: 0.1210 - accuracy: 0.9498 - 661ms/epoch - 1ms/step
# Epoch 74/200
# 511/511 - 1s - loss: 0.1198 - accuracy: 0.9482 - 661ms/epoch - 1ms/step
# Epoch 75/200
# 511/511 - 1s - loss: 0.1184 - accuracy: 0.9503 - 655ms/epoch - 1ms/step
# Epoch 76/200
# 511/511 - 1s - loss: 0.1302 - accuracy: 0.9466 - 661ms/epoch - 1ms/step
# Epoch 77/200
# 511/511 - 1s - loss: 0.1193 - accuracy: 0.9476 - 660ms/epoch - 1ms/step
# Epoch 78/200
# 511/511 - 1s - loss: 0.1190 - accuracy: 0.9517 - 657ms/epoch - 1ms/step
# Epoch 79/200
# 511/511 - 1s - loss: 0.1191 - accuracy: 0.9498 - 656ms/epoch - 1ms/step
# Epoch 80/200
# 511/511 - 1s - loss: 0.1277 - accuracy: 0.9478 - 656ms/epoch - 1ms/step
# Epoch 81/200
# 511/511 - 1s - loss: 0.1220 - accuracy: 0.9482 - 655ms/epoch - 1ms/step
# Epoch 82/200
# 511/511 - 1s - loss: 0.1180 - accuracy: 0.9503 - 683ms/epoch - 1ms/step
# Epoch 83/200
# 511/511 - 1s - loss: 0.1170 - accuracy: 0.9503 - 656ms/epoch - 1ms/step
# Epoch 84/200
# 511/511 - 1s - loss: 0.1174 - accuracy: 0.9516 - 654ms/epoch - 1ms/step
# Epoch 85/200
# 511/511 - 1s - loss: 0.1190 - accuracy: 0.9517 - 660ms/epoch - 1ms/step
# Epoch 86/200
# 511/511 - 1s - loss: 0.1128 - accuracy: 0.9517 - 660ms/epoch - 1ms/step
# Epoch 87/200
# 511/511 - 1s - loss: 0.1278 - accuracy: 0.9484 - 652ms/epoch - 1ms/step
# Epoch 88/200
# 511/511 - 1s - loss: 0.1164 - accuracy: 0.9506 - 657ms/epoch - 1ms/step
# Epoch 89/200
# 511/511 - 1s - loss: 0.1104 - accuracy: 0.9542 - 651ms/epoch - 1ms/step
# Epoch 90/200
# 511/511 - 1s - loss: 0.1178 - accuracy: 0.9512 - 654ms/epoch - 1ms/step
# Epoch 91/200
# 511/511 - 1s - loss: 0.1191 - accuracy: 0.9532 - 653ms/epoch - 1ms/step
# Epoch 92/200
# 511/511 - 1s - loss: 0.1140 - accuracy: 0.9524 - 656ms/epoch - 1ms/step
# Epoch 93/200
# 511/511 - 1s - loss: 0.1128 - accuracy: 0.9516 - 653ms/epoch - 1ms/step
# Epoch 94/200
# 511/511 - 1s - loss: 0.1155 - accuracy: 0.9508 - 653ms/epoch - 1ms/step
# Epoch 95/200
# 511/511 - 1s - loss: 0.1155 - accuracy: 0.9523 - 653ms/epoch - 1ms/step
# Epoch 96/200
# 511/511 - 1s - loss: 0.1150 - accuracy: 0.9536 - 658ms/epoch - 1ms/step
# Epoch 97/200
# 511/511 - 1s - loss: 0.1161 - accuracy: 0.9517 - 664ms/epoch - 1ms/step
# Epoch 98/200
# 511/511 - 1s - loss: 0.1198 - accuracy: 0.9520 - 658ms/epoch - 1ms/step
# Epoch 99/200
# 511/511 - 1s - loss: 0.1098 - accuracy: 0.9552 - 660ms/epoch - 1ms/step
# Epoch 100/200
# 511/511 - 1s - loss: 0.1060 - accuracy: 0.9561 - 662ms/epoch - 1ms/step
# Epoch 101/200
# 511/511 - 1s - loss: 0.1209 - accuracy: 0.9496 - 659ms/epoch - 1ms/step
# Epoch 102/200
# 511/511 - 1s - loss: 0.1096 - accuracy: 0.9541 - 656ms/epoch - 1ms/step
# Epoch 103/200
# 511/511 - 1s - loss: 0.1111 - accuracy: 0.9540 - 662ms/epoch - 1ms/step
# Epoch 104/200
# 511/511 - 1s - loss: 0.1111 - accuracy: 0.9555 - 663ms/epoch - 1ms/step
# Epoch 105/200
# 511/511 - 1s - loss: 0.1093 - accuracy: 0.9543 - 661ms/epoch - 1ms/step
# Epoch 106/200
# 511/511 - 1s - loss: 0.1175 - accuracy: 0.9523 - 657ms/epoch - 1ms/step
# Epoch 107/200
# 511/511 - 1s - loss: 0.1013 - accuracy: 0.9551 - 660ms/epoch - 1ms/step
# Epoch 108/200
# 511/511 - 1s - loss: 0.1042 - accuracy: 0.9567 - 655ms/epoch - 1ms/step
# Epoch 109/200
# 511/511 - 1s - loss: 0.1067 - accuracy: 0.9580 - 659ms/epoch - 1ms/step
# Epoch 110/200
# 511/511 - 1s - loss: 0.1073 - accuracy: 0.9532 - 667ms/epoch - 1ms/step
# Epoch 111/200
# 511/511 - 1s - loss: 0.1029 - accuracy: 0.9574 - 659ms/epoch - 1ms/step
# Epoch 112/200
# 511/511 - 1s - loss: 0.1093 - accuracy: 0.9541 - 646ms/epoch - 1ms/step
# Epoch 113/200
# 511/511 - 1s - loss: 0.1081 - accuracy: 0.9552 - 644ms/epoch - 1ms/step
# Epoch 114/200
# 511/511 - 1s - loss: 0.1063 - accuracy: 0.9553 - 642ms/epoch - 1ms/step
# Epoch 115/200
# 511/511 - 1s - loss: 0.1060 - accuracy: 0.9577 - 651ms/epoch - 1ms/step
# Epoch 116/200
# 511/511 - 1s - loss: 0.0974 - accuracy: 0.9595 - 677ms/epoch - 1ms/step
# Epoch 117/200
# 511/511 - 1s - loss: 0.1048 - accuracy: 0.9564 - 654ms/epoch - 1ms/step
# Epoch 118/200
# 511/511 - 1s - loss: 0.1078 - accuracy: 0.9562 - 653ms/epoch - 1ms/step
# Epoch 119/200
# 511/511 - 1s - loss: 0.0988 - accuracy: 0.9582 - 657ms/epoch - 1ms/step
# Epoch 120/200
# 511/511 - 1s - loss: 0.1052 - accuracy: 0.9555 - 654ms/epoch - 1ms/step
# Epoch 121/200
# 511/511 - 1s - loss: 0.1012 - accuracy: 0.9581 - 658ms/epoch - 1ms/step
# Epoch 122/200
# 511/511 - 1s - loss: 0.1022 - accuracy: 0.9579 - 662ms/epoch - 1ms/step
# Epoch 123/200
# 511/511 - 1s - loss: 0.1021 - accuracy: 0.9590 - 656ms/epoch - 1ms/step
# Epoch 124/200
# 511/511 - 1s - loss: 0.1047 - accuracy: 0.9574 - 657ms/epoch - 1ms/step
# Epoch 125/200
# 511/511 - 1s - loss: 0.1070 - accuracy: 0.9580 - 659ms/epoch - 1ms/step
# Epoch 126/200
# 511/511 - 1s - loss: 0.1076 - accuracy: 0.9547 - 665ms/epoch - 1ms/step
# Epoch 127/200
# 511/511 - 1s - loss: 0.1028 - accuracy: 0.9579 - 656ms/epoch - 1ms/step
# Epoch 128/200
# 511/511 - 1s - loss: 0.1080 - accuracy: 0.9580 - 657ms/epoch - 1ms/step
# Epoch 129/200
# 511/511 - 1s - loss: 0.0968 - accuracy: 0.9606 - 661ms/epoch - 1ms/step
# Epoch 130/200
# 511/511 - 1s - loss: 0.1019 - accuracy: 0.9576 - 658ms/epoch - 1ms/step
# Epoch 131/200
# 511/511 - 1s - loss: 0.0996 - accuracy: 0.9602 - 662ms/epoch - 1ms/step
# Epoch 132/200
# 511/511 - 1s - loss: 0.1013 - accuracy: 0.9581 - 658ms/epoch - 1ms/step
# Epoch 133/200
# 511/511 - 1s - loss: 0.0987 - accuracy: 0.9608 - 662ms/epoch - 1ms/step
# Epoch 134/200
# 511/511 - 1s - loss: 0.0964 - accuracy: 0.9618 - 661ms/epoch - 1ms/step
# Epoch 135/200
# 511/511 - 1s - loss: 0.1050 - accuracy: 0.9564 - 659ms/epoch - 1ms/step
# Epoch 136/200
# 511/511 - 1s - loss: 0.0940 - accuracy: 0.9624 - 653ms/epoch - 1ms/step
# Epoch 137/200
# 511/511 - 1s - loss: 0.0954 - accuracy: 0.9601 - 657ms/epoch - 1ms/step
# Epoch 138/200
# 511/511 - 1s - loss: 0.0979 - accuracy: 0.9598 - 657ms/epoch - 1ms/step
# Epoch 139/200
# 511/511 - 1s - loss: 0.0992 - accuracy: 0.9586 - 662ms/epoch - 1ms/step
# Epoch 140/200
# 511/511 - 1s - loss: 0.1024 - accuracy: 0.9588 - 665ms/epoch - 1ms/step
# Epoch 141/200
# 511/511 - 1s - loss: 0.0981 - accuracy: 0.9578 - 660ms/epoch - 1ms/step
# Epoch 142/200
# 511/511 - 1s - loss: 0.1049 - accuracy: 0.9585 - 659ms/epoch - 1ms/step
# Epoch 143/200
# 511/511 - 1s - loss: 0.0935 - accuracy: 0.9627 - 655ms/epoch - 1ms/step
# Epoch 144/200
# 511/511 - 1s - loss: 0.0962 - accuracy: 0.9593 - 660ms/epoch - 1ms/step
# Epoch 145/200
# 511/511 - 1s - loss: 0.0991 - accuracy: 0.9591 - 662ms/epoch - 1ms/step
# Epoch 146/200
# 511/511 - 1s - loss: 0.0998 - accuracy: 0.9599 - 662ms/epoch - 1ms/step
# Epoch 147/200
# 511/511 - 1s - loss: 0.0963 - accuracy: 0.9618 - 665ms/epoch - 1ms/step
# Epoch 148/200
# 511/511 - 1s - loss: 0.0989 - accuracy: 0.9591 - 661ms/epoch - 1ms/step
# Epoch 149/200
# 511/511 - 1s - loss: 0.1291 - accuracy: 0.9595 - 658ms/epoch - 1ms/step
# Epoch 150/200
# 511/511 - 1s - loss: 0.0878 - accuracy: 0.9630 - 675ms/epoch - 1ms/step
# Epoch 151/200
# 511/511 - 1s - loss: 0.0909 - accuracy: 0.9635 - 654ms/epoch - 1ms/step
# Epoch 152/200
# 511/511 - 1s - loss: 0.0946 - accuracy: 0.9618 - 660ms/epoch - 1ms/step
# Epoch 153/200
# 511/511 - 1s - loss: 0.0896 - accuracy: 0.9627 - 666ms/epoch - 1ms/step
# Epoch 154/200
# 511/511 - 1s - loss: 0.0898 - accuracy: 0.9629 - 657ms/epoch - 1ms/step
# Epoch 155/200
# 511/511 - 1s - loss: 0.0970 - accuracy: 0.9604 - 661ms/epoch - 1ms/step
# Epoch 156/200
# 511/511 - 1s - loss: 0.0894 - accuracy: 0.9631 - 667ms/epoch - 1ms/step
# Epoch 157/200
# 511/511 - 1s - loss: 0.0934 - accuracy: 0.9629 - 658ms/epoch - 1ms/step
# Epoch 158/200
# 511/511 - 1s - loss: 0.0980 - accuracy: 0.9610 - 662ms/epoch - 1ms/step
# Epoch 159/200
# 511/511 - 1s - loss: 0.0891 - accuracy: 0.9634 - 645ms/epoch - 1ms/step
# Epoch 160/200
# 511/511 - 1s - loss: 0.0924 - accuracy: 0.9619 - 664ms/epoch - 1ms/step
# Epoch 161/200
# 511/511 - 1s - loss: 0.0970 - accuracy: 0.9609 - 658ms/epoch - 1ms/step
# Epoch 162/200
# 511/511 - 1s - loss: 0.0985 - accuracy: 0.9599 - 660ms/epoch - 1ms/step
# Epoch 163/200
# 511/511 - 1s - loss: 0.0889 - accuracy: 0.9639 - 659ms/epoch - 1ms/step
# Epoch 164/200
# 511/511 - 1s - loss: 0.0985 - accuracy: 0.9616 - 659ms/epoch - 1ms/step
# Epoch 165/200
# 511/511 - 1s - loss: 0.0933 - accuracy: 0.9629 - 657ms/epoch - 1ms/step
# Epoch 166/200
# 511/511 - 1s - loss: 0.0978 - accuracy: 0.9610 - 667ms/epoch - 1ms/step
# Epoch 167/200
# 511/511 - 1s - loss: 0.0890 - accuracy: 0.9634 - 694ms/epoch - 1ms/step
# Epoch 168/200
# 511/511 - 1s - loss: 0.0887 - accuracy: 0.9638 - 699ms/epoch - 1ms/step
# Epoch 169/200
# 511/511 - 1s - loss: 0.0939 - accuracy: 0.9648 - 656ms/epoch - 1ms/step
# Epoch 170/200
# 511/511 - 1s - loss: 0.0865 - accuracy: 0.9641 - 651ms/epoch - 1ms/step
# Epoch 171/200
# 511/511 - 1s - loss: 0.0890 - accuracy: 0.9643 - 661ms/epoch - 1ms/step
# Epoch 172/200
# 511/511 - 1s - loss: 0.0847 - accuracy: 0.9644 - 651ms/epoch - 1ms/step
# Epoch 173/200
# 511/511 - 1s - loss: 0.0912 - accuracy: 0.9633 - 653ms/epoch - 1ms/step
# Epoch 174/200
# 511/511 - 1s - loss: 0.0853 - accuracy: 0.9651 - 655ms/epoch - 1ms/step
# Epoch 175/200
# 511/511 - 1s - loss: 0.0892 - accuracy: 0.9638 - 652ms/epoch - 1ms/step
# Epoch 176/200
# 511/511 - 1s - loss: 0.0841 - accuracy: 0.9657 - 657ms/epoch - 1ms/step
# Epoch 177/200
# 511/511 - 1s - loss: 0.0913 - accuracy: 0.9651 - 657ms/epoch - 1ms/step
# Epoch 178/200
# 511/511 - 1s - loss: 0.0929 - accuracy: 0.9620 - 651ms/epoch - 1ms/step
# Epoch 179/200
# 511/511 - 1s - loss: 0.0835 - accuracy: 0.9656 - 662ms/epoch - 1ms/step
# Epoch 180/200
# 511/511 - 1s - loss: 0.0885 - accuracy: 0.9630 - 660ms/epoch - 1ms/step
# Epoch 181/200
# 511/511 - 1s - loss: 0.0910 - accuracy: 0.9618 - 652ms/epoch - 1ms/step
# Epoch 182/200
# 511/511 - 1s - loss: 0.0855 - accuracy: 0.9657 - 656ms/epoch - 1ms/step
# Epoch 183/200
# 511/511 - 1s - loss: 0.0929 - accuracy: 0.9632 - 648ms/epoch - 1ms/step
# Epoch 184/200
# 511/511 - 1s - loss: 0.0851 - accuracy: 0.9663 - 677ms/epoch - 1ms/step
# Epoch 185/200
# 511/511 - 1s - loss: 0.0866 - accuracy: 0.9649 - 654ms/epoch - 1ms/step
# Epoch 186/200
# 511/511 - 1s - loss: 0.0827 - accuracy: 0.9662 - 656ms/epoch - 1ms/step
# Epoch 187/200
# 511/511 - 1s - loss: 0.0902 - accuracy: 0.9647 - 662ms/epoch - 1ms/step
# Epoch 188/200
# 511/511 - 1s - loss: 0.0875 - accuracy: 0.9660 - 657ms/epoch - 1ms/step
# Epoch 189/200
# 511/511 - 1s - loss: 0.0838 - accuracy: 0.9669 - 658ms/epoch - 1ms/step
# Epoch 190/200
# 511/511 - 1s - loss: 0.0876 - accuracy: 0.9645 - 658ms/epoch - 1ms/step
# Epoch 191/200
# 511/511 - 1s - loss: 0.0843 - accuracy: 0.9674 - 661ms/epoch - 1ms/step
# Epoch 192/200
# 511/511 - 1s - loss: 0.0860 - accuracy: 0.9660 - 663ms/epoch - 1ms/step
# Epoch 193/200
# 511/511 - 1s - loss: 0.0893 - accuracy: 0.9648 - 662ms/epoch - 1ms/step
# Epoch 194/200
# 511/511 - 1s - loss: 0.0894 - accuracy: 0.9648 - 662ms/epoch - 1ms/step
# Epoch 195/200
# 511/511 - 1s - loss: 0.0847 - accuracy: 0.9654 - 664ms/epoch - 1ms/step
# Epoch 196/200
# 511/511 - 1s - loss: 0.0850 - accuracy: 0.9646 - 648ms/epoch - 1ms/step
# Epoch 197/200
# 511/511 - 1s - loss: 0.0840 - accuracy: 0.9658 - 664ms/epoch - 1ms/step
# Epoch 198/200
# 511/511 - 1s - loss: 0.0859 - accuracy: 0.9652 - 657ms/epoch - 1ms/step
# Epoch 199/200
# 511/511 - 1s - loss: 0.0880 - accuracy: 0.9649 - 663ms/epoch - 1ms/step
# Epoch 200/200
# 511/511 - 1s - loss: 0.0884 - accuracy: 0.9656 - 663ms/epoch - 1ms/step

# %%
print("--Evaluate model--")
model_loss1, model_acc1 = model.evaluate(x_train,  y_train, verbose=2)
model_loss2, model_acc2 = model.evaluate(x_test,  y_test, verbose=2)
print(f"Train / Test Accuracy: {model_acc1*100:.1f}% / {model_acc2*100:.1f}%")
# Out:
# --Evaluate model--
# 511/511 - 0s - loss: 0.0575 - accuracy: 0.9788 - 453ms/epoch - 887us/step
# 128/128 - 0s - loss: 0.1170 - accuracy: 0.9579 - 112ms/epoch - 872us/step
# Train / Test Accuracy: 97.9% / 95.8%

# %%
#Saving model
model.save("main4classif97.9_95.8", save_format='h5')
#saved and labeled my current model at Train / Test Accuracy: 97.9% / 95.8%

# %% [markdown]
# Report for Main part 2:
#
# Before I start I want to point out that for this part of the assignment, I converted my median_income from a numerical income to a categorical one by using pandas.
# ```py
# data['median_income']=pd.cut(data['median_income'],bins=[0, 1.5, 2.5, 4, 6, 8, 10, 1000],
# include_lowest=True,
# labels=['poverty','below average','average','above average','well off','wealthy','rich'])
# ```
# I did this for two reasons, the major reason was due to the fact that I wanted to use ocean_proximity as an output, which would leave me with no categorical inputs for my model. The second and important reason was, that I felt that these income values made no sense, and were just random floats, essentially diving areas into wealth classes, which I felt would be better represented as categories. So thats what I did, since the values had a wide range, I used a pandas function to map each of the values in the column to an appropriate tag, based on how high the median_income was in that neighborhood.
#
# Columns used as input and output
# Input: longitude	latitude	housing_median_age	total_rooms	total_bedrooms	population	households	median_house_value
# Output: ocean_proximity
#
# For my input, I chose every column except median_income as that was categorical, and ocean_proximity as that was my output.
# The reason for this was because that I was hoping my model would be able to make a connection between the richer and higher demand areas in california, would have houses with more rooms/bedrooms, and the house would be worth more in general. That way when the model see's a house thats worth a lot and has a lot of rooms, it might have a baseline assumption that x house is in y rich area, and the same goes for the houses worth less.
#
# I split my training and testing data in a 80/20 split. This was because after randomizing my data, I decided that it would be much more worthwhile to give my data a significantly larger variety to train on than test on. This is because testing is used to see the accuracy of the model, and to get higher accuracy, the model needs to train on a much larger variety, so that if the test has a strange input, it can still make a decision based on the experience that it has, but if I make my training input smaller, it becomes more and more likely that the test will have an input that the model has little to no experience for.
#
# Two decisions that I made for my model design was to process my input. One thing that I did that I felt had a big impact on the accuracy was that I scaled the numerical inputs with the RobustScaler from sklearn (Based on Joweria's process), the second thing that I felt had a big impact was that I normalized the inputs, as the inputs were all numbers that were very different from each other. Normalizing them was important for the model to be able to make sense of things with less difficulty.
#
# In terms of hyper parameters, I had my normalizer, and then I just attempted to make a relatively dense model with lots of layers with the relu activation. Meaning i added lots of the Dense layers. I found that I haven't needed to mess with the units in the softmax layer yet, but I will probably begin experimenting with it during part 3 or 4 of main.
#
# Currently my model is quite accurate, getting 97.2% accuracy on the training, and 94.4% accuracy on the test. Despite this being a pretty acceptable number, I think this discrepency between the two shows that my model is over-fitted to the training data, and the test shouldnt have a signficicant amount of outliers in comparison to the training data, so for the next iterations I will try to fix this discrepency between training and test data. But I also believe that overall accuracy will rise with the introduction of the income column (categorical) column later on.

# %%
#Visualization of for main part three
scatplot = sns.scatterplot(data=data, x = "median_house_value", y = "population")
fig = scatplot.get_figure()
fig.savefig("../main3/visualization.png")

# %% [markdown]
# Part 3 Report
# --
# From the notMNIST model that I built I learned a few things to help with over-fitting,
# one thing that I noticed was that too many epochs, would cause over-fitting quite fast once the model started to become confident. To fix this over-fitting issue, what I found helped was to increase the density of a specific layer and then to reduce the number of epochs.
# So thats exactly what I did. I experimented with how many layers to increase the density of, and decided to settle on my first Dense layer increasing from 64 to 128, then I lowered the training epochs from 200 to 120.
#
# This increased my models accuracy from ~94% to 96%, which is a solid improvement, and shows that the over-fitting issue was slightly reduced.
#
# I believe that one of the reason for the over-fitting issue is that there is quite a few outliers, which makes it harder for my model to predict. As seen in the visualization below. (also in the code block above)
#
# ![vis](../main3/visualization.png)
#
# From the scatter plot, we can tell that overall, there seems to be a even distribution of population to house value, with areas with smaller populations tend to have more expensive houses.
#
# But there is also a signficant number of outliers, especially in the upper and lower end of the data, which could explain the reason that the model is unable to predict accurately when it comes across one of these outliers.

# %%
scatplot = sns.scatterplot(data=data, x = "median_house_value", y = "median_income")
fig = scatplot.get_figure()
