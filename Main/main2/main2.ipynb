# %%
#Main Project Stage 1: Data Science and Machine Learning
# Import the required libraries

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn
import tensorflow as tf

# Set sns theme to your preferred color palette
sns.set_theme(palette = "mako")

data = pd.read_csv('../data/data-input.csv')  # read csv file
data.to_csv("../data/data.csv",index=False)
#data input is the data that I had previously cleaned before starting the assignment
data = pd.read_csv("../data/data.csv") #pretty confused as to why the instructions ask for this, but I guess its not a big deal
data['median_income']=pd.cut(data['median_income'],bins=[0, 1.5, 2.5, 4, 6, 8, 10, 1000], 
include_lowest=True, 
labels=['poverty','below average','average','above average','well off','wealthy','rich'])
df = data.copy()  # create a copy to use for future reference, so I have a copy of my original dataset when needed

data.head()
#Cleaned data (now called data-input.csv) by hand beforehand before reading instructions, so my data is already good.
#Will be skipping the pandas clean data step
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0        wealthy            452600.0        NEAR BAY
# 1      2401.0      1138.0        wealthy            358500.0        NEAR BAY
# 2       496.0       177.0       well off            352100.0        NEAR BAY
# 3       558.0       219.0  above average            341300.0        NEAR BAY
# 4       565.0       259.0        average            342200.0        NEAR BAY

# %%
#Histogram showing distribution of housing age in the market
agehist = sns.histplot(data=df, x = "housing_median_age")
fig = agehist.get_figure()
fig.savefig("../plots/plot1.png")

# %%
#Visualization of relationship (and variation) in housing price based on its age
age_value_lineplot = sns.lineplot(data=df, x = "housing_median_age", y = "median_house_value")
fig = age_value_lineplot.get_figure()
fig.savefig("../plots/plot2.png")

# %%
#Visualization of price distribution of houses in california
house_value_histplot = sns.histplot(data=df, x = "median_house_value")
fig = house_value_histplot.get_figure()
fig.savefig("../plots/plot3.png") 
#Can see from output that a majority of the houses are from 150k to 250k

# %% [markdown]
# Where the data came from.:
#
# https://www.kaggle.com/datasets/kathuman/housing
# I will be using the dataset on Housing Prices in California found on Kaggle with a creative Commons Public Domain License
# Description of data from creator:
# "This dataset is based on data from the 1990 California Census, and incluides metrics such as the population, median income, and median housing proice for each block group in California.
# Block groups are the smallest geographical unit for which the US Census Bureau publishes sample data., and each block typically has between 600 to 3000 people."
#
# The goal I have with this dataset is to be able to get my model to guess the price of houses given all the other information.
#
#
# Challenges cleaning:
#
# One of the challenges I had cleaning was that the dataset was humongous (22k rows) so I worried that I missed some stuff while cleaning but overall it was pretty straightforward. I cleaned it by hand before starting the assignment, and the biggest issue was that there was a lot of data to delete by hand. There was a lot of cells that just had nothing inside it, so I had to delete the entire line, which meant I couldnt automate it with find and replace. But other than that, the data seems pretty clean, and there are some spots in the data that I might need to go back and change, but for now I think the data looks reliable, based on the distribution I've seen from my graphs.
#
# Three visualizations:
#
# plot1 is a distribution of the age of the house. We can see that california has a wide range of ages for their houses. But their seems to be a spike in houses that are around 20, 30, and 50+ years old. Overall I think the distribution in that column is pretty good, and should pose no issues in training my model.
#
# plot2 is a visualization of relationship (and variation) in housing price based on its age. One thing that bothered me in this, is that from the graph, the house prices seem to very a lot for some age groups, specifically ~10 years old and ~50 years old. I worry that this will have negative effects in the model, but at the same time, logically speaking this is a realistic scenario. As old houses that are still standing are likely to be very nice to begin with, and new houses that are being built are being built for many different types of people with different incomes, especially in california where there is a large amount of wealthy and average people concentrated in one area.
#
# plot3 is a visualization of price distribution of houses in california. I wanted to see where the price of houses was concentrated, this graph allowed me to see that a majority of the houses in california in the dataset are around $150k-250k. But there is also a sizeable amount of houses below and above that number. Which should pose as good variation to give model a wide range of information to make accurate estimates.
#
# Part 2 code begins after this report
# --

# %%
df.shape  # Will return the number of rows and columns
# Out:
# (20433, 10)

# %%
df.info()  # Will inform you of the datatype of each variable, as well as if there are any null or missing values in each column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20433 entries, 0 to 20432
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  category
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: category(1), float64(8), object(1)
# memory usage: 1.4+ MB

# %%
df.describe().T # Describe the data-frame (transposed) - defaults to describing only numerical
# If you want to describe all, run the following command:
# data.describe(include = "all").T
# Out:
#                       count           mean            std       min  \
# longitude           20433.0    -119.570689       2.003578   -124.35
# latitude            20433.0      35.633221       2.136348     32.54
# housing_median_age  20433.0      28.633094      12.591805      1.00
# total_rooms         20433.0    2636.504233    2185.269567      2.00
# total_bedrooms      20433.0     537.870553     421.385070      1.00
# population          20433.0    1424.946949    1133.208490      3.00
# households          20433.0     499.433465     382.299226      1.00
# median_house_value  20433.0  206864.413155  115435.667099  14999.00
#
#                           25%        50%        75%        max
# longitude             -121.80    -118.49    -118.01    -114.31
# latitude                33.93      34.26      37.72      41.95
# housing_median_age      18.00      29.00      37.00      52.00
# total_rooms           1450.00    2127.00    3143.00   39320.00
# total_bedrooms         296.00     435.00     647.00    6445.00
# population             787.00    1166.00    1722.00   35682.00
# households             280.00     409.00     604.00    6082.00
# median_house_value  119500.00  179700.00  264700.00  500001.00

# %%
df.isnull().sum()  # Checking for null values
# In this case there are no null values. If there are some, you can use a heatmap to visualize them if you want.
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
#Organizing categorical data
#Citation is from Joweria's heartdisease tutorial notebook
from pandas.core.arrays import categorical 
categorical_data = ["ocean_proximity","median_income"]

codes = {}  # Create a dictionary to store the codes of the conversion
for i in df:  # For each variable in the data frame 
  if i in categorical_data:  # For each variable that was classified as categorical
    specific_codes = {}  # Create a dictionary for that variable's code conversion 
    df[i] = df[i].astype("category")  # Convert that variable from 'object' datatype to category
    df[i] = df[i].cat.codes  # Create codes for the categories and replace in the dataset 
    coded = df[i].unique()  # Get the unique values (the codes) from the variable
    count = 0  # Count initialized. Later used for accessing specific indexes
    for j in data[i].unique():  # For each unique value
      specific_codes[j] = coded[count]  # Create an item in the dictionary with the value, and tell it which code correlates
      count += 1  # Count incremented
    codes[i] = specific_codes  # Create a new item in the overall dictionary with the dictionary created for this specific variable's codes


# View our created dictionary:
for i in codes:
  print("{} -".format(i))
  for j in codes[i]:
    print("{}: {}".format(j, codes[i][j]))
  print()
# Out:
# median_income -
# wealthy: 5
# well off: 4
# above average: 3
# average: 2
# below average: 1
# poverty: 0
# rich: 6
#
# ocean_proximity -
# NEAR BAY: 3
# <1H OCEAN: 0
# INLAND: 1
# NEAR OCEAN: 4
# ISLAND: 2

# %%
df.head()
#Checking that data is no longer categorical and now an integer at the end
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value  ocean_proximity
# 0       322.0       126.0              5            452600.0                3
# 1      2401.0      1138.0              5            358500.0                3
# 2       496.0       177.0              4            352100.0                3
# 3       558.0       219.0              3            341300.0                3
# 4       565.0       259.0              2            342200.0                3

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler
fs_data = df.copy() # copy of dataset for feature selection
x = fs_data.iloc[:,[0,1,2,3,4,5,6,8]]  # independent variables
y = fs_data.iloc[:,[9]]    # target column / what we're trying to predict


#https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html
#Found this easy way to split training data in the scikit documentation
#Shuffles data, and allocated 80% of it to be used for training, and 20% of it to be used for testing
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2) # splitting up dataset to training and testing

scl = RobustScaler() # Preprocess numerical data 
x_train = scl.fit_transform(x_train) 
x_test = scl.transform(x_test)

# %%
#x_train.head()

# %%
normalizer = tf.keras.layers.Normalization(axis=-1)
normalizer.adapt(x_train)
print(normalizer.mean.numpy())
# Out:
# 2022-11-11 19:57:24.675919: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-11 19:57:24.677245: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-11-11 19:57:24.677833: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory
# 2022-11-11 19:57:24.678485: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory
# 2022-11-11 19:57:24.679028: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory
# 2022-11-11 19:57:24.679540: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcurand.so.10'; dlerror: libcurand.so.10: cannot open shared object file: No such file or directory
# 2022-11-11 19:57:24.680062: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory
# 2022-11-11 19:57:24.680520: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory
# 2022-11-11 19:57:24.681039: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2022-11-11 19:57:24.681052: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2022-11-11 19:57:24.683634: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [[-0.28400686  0.3644015  -0.0213508   0.3053021   0.29553616  0.2783684
#    0.2798846   0.18593268]]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Flatten


print("--Make model--")
model = tf.keras.models.Sequential([
  normalizer,
  tf.keras.layers.Dense(64, activation='relu'),
  tf.keras.layers.Dense(64, activation='relu'),
  tf.keras.layers.Dense(64, activation='relu'),
  tf.keras.layers.Dense(64, activation='relu'),
  tf.keras.layers.Dense(10, activation='softmax'),
])
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

print("--Fit model--")
model.fit(x_train, y_train, epochs=200, verbose=2)
# Out:
# --Make model--
# --Fit model--
# Epoch 1/200
# 511/511 - 1s - loss: 0.6711 - accuracy: 0.7598 - 891ms/epoch - 2ms/step
# Epoch 2/200
# 511/511 - 0s - loss: 0.3754 - accuracy: 0.8483 - 435ms/epoch - 851us/step
# Epoch 3/200
# 511/511 - 0s - loss: 0.3225 - accuracy: 0.8682 - 433ms/epoch - 848us/step
# Epoch 4/200
# 511/511 - 0s - loss: 0.2826 - accuracy: 0.8803 - 474ms/epoch - 927us/step
# Epoch 5/200
# 511/511 - 0s - loss: 0.2649 - accuracy: 0.8928 - 441ms/epoch - 863us/step
# Epoch 6/200
# 511/511 - 0s - loss: 0.2408 - accuracy: 0.9000 - 447ms/epoch - 874us/step
# Epoch 7/200
# 511/511 - 0s - loss: 0.2248 - accuracy: 0.9041 - 445ms/epoch - 870us/step
# Epoch 8/200
# 511/511 - 0s - loss: 0.2141 - accuracy: 0.9101 - 436ms/epoch - 854us/step
# Epoch 9/200
# 511/511 - 0s - loss: 0.2036 - accuracy: 0.9127 - 442ms/epoch - 865us/step
# Epoch 10/200
# 511/511 - 0s - loss: 0.1938 - accuracy: 0.9191 - 440ms/epoch - 861us/step
# Epoch 11/200
# 511/511 - 0s - loss: 0.1968 - accuracy: 0.9176 - 438ms/epoch - 857us/step
# Epoch 12/200
# 511/511 - 0s - loss: 0.1809 - accuracy: 0.9226 - 441ms/epoch - 863us/step
# Epoch 13/200
# 511/511 - 0s - loss: 0.1851 - accuracy: 0.9202 - 428ms/epoch - 838us/step
# Epoch 14/200
# 511/511 - 0s - loss: 0.1754 - accuracy: 0.9269 - 436ms/epoch - 852us/step
# Epoch 15/200
# 511/511 - 0s - loss: 0.1729 - accuracy: 0.9281 - 442ms/epoch - 866us/step
# Epoch 16/200
# 511/511 - 0s - loss: 0.1643 - accuracy: 0.9311 - 450ms/epoch - 881us/step
# Epoch 17/200
# 511/511 - 0s - loss: 0.1677 - accuracy: 0.9293 - 442ms/epoch - 866us/step
# Epoch 18/200
# 511/511 - 0s - loss: 0.1618 - accuracy: 0.9315 - 434ms/epoch - 848us/step
# Epoch 19/200
# 511/511 - 0s - loss: 0.1724 - accuracy: 0.9294 - 445ms/epoch - 871us/step
# Epoch 20/200
# 511/511 - 0s - loss: 0.1533 - accuracy: 0.9361 - 438ms/epoch - 857us/step
# Epoch 21/200
# 511/511 - 0s - loss: 0.1629 - accuracy: 0.9303 - 443ms/epoch - 867us/step
# Epoch 22/200
# 511/511 - 0s - loss: 0.1533 - accuracy: 0.9367 - 444ms/epoch - 869us/step
# Epoch 23/200
# 511/511 - 0s - loss: 0.1540 - accuracy: 0.9347 - 445ms/epoch - 870us/step
# Epoch 24/200
# 511/511 - 0s - loss: 0.1531 - accuracy: 0.9359 - 440ms/epoch - 861us/step
# Epoch 25/200
# 511/511 - 0s - loss: 0.1510 - accuracy: 0.9370 - 449ms/epoch - 878us/step
# Epoch 26/200
# 511/511 - 0s - loss: 0.1464 - accuracy: 0.9389 - 440ms/epoch - 861us/step
# Epoch 27/200
# 511/511 - 0s - loss: 0.1427 - accuracy: 0.9393 - 449ms/epoch - 878us/step
# Epoch 28/200
# 511/511 - 0s - loss: 0.1407 - accuracy: 0.9400 - 448ms/epoch - 876us/step
# Epoch 29/200
# 511/511 - 0s - loss: 0.1412 - accuracy: 0.9405 - 443ms/epoch - 867us/step
# Epoch 30/200
# 511/511 - 0s - loss: 0.1403 - accuracy: 0.9416 - 441ms/epoch - 862us/step
# Epoch 31/200
# 511/511 - 0s - loss: 0.1357 - accuracy: 0.9423 - 445ms/epoch - 870us/step
# Epoch 32/200
# 511/511 - 0s - loss: 0.1323 - accuracy: 0.9443 - 440ms/epoch - 860us/step
# Epoch 33/200
# 511/511 - 0s - loss: 0.1321 - accuracy: 0.9450 - 437ms/epoch - 855us/step
# Epoch 34/200
# 511/511 - 0s - loss: 0.1351 - accuracy: 0.9424 - 438ms/epoch - 858us/step
# Epoch 35/200
# 511/511 - 0s - loss: 0.1336 - accuracy: 0.9436 - 436ms/epoch - 854us/step
# Epoch 36/200
# 511/511 - 0s - loss: 0.1329 - accuracy: 0.9442 - 441ms/epoch - 863us/step
# Epoch 37/200
# 511/511 - 0s - loss: 0.1357 - accuracy: 0.9420 - 442ms/epoch - 865us/step
# Epoch 38/200
# 511/511 - 0s - loss: 0.1275 - accuracy: 0.9468 - 439ms/epoch - 860us/step
# Epoch 39/200
# 511/511 - 0s - loss: 0.1217 - accuracy: 0.9498 - 452ms/epoch - 885us/step
# Epoch 40/200
# 511/511 - 0s - loss: 0.1176 - accuracy: 0.9510 - 451ms/epoch - 883us/step
# Epoch 41/200
# 511/511 - 0s - loss: 0.1231 - accuracy: 0.9482 - 445ms/epoch - 871us/step
# Epoch 42/200
# 511/511 - 0s - loss: 0.1258 - accuracy: 0.9490 - 453ms/epoch - 886us/step
# Epoch 43/200
# 511/511 - 0s - loss: 0.1251 - accuracy: 0.9473 - 446ms/epoch - 873us/step
# Epoch 44/200
# 511/511 - 0s - loss: 0.1194 - accuracy: 0.9501 - 448ms/epoch - 876us/step
# Epoch 45/200
# 511/511 - 0s - loss: 0.1160 - accuracy: 0.9499 - 439ms/epoch - 858us/step
# Epoch 46/200
# 511/511 - 0s - loss: 0.1188 - accuracy: 0.9514 - 437ms/epoch - 855us/step
# Epoch 47/200
# 511/511 - 0s - loss: 0.1196 - accuracy: 0.9501 - 437ms/epoch - 856us/step
# Epoch 48/200
# 511/511 - 0s - loss: 0.1203 - accuracy: 0.9503 - 443ms/epoch - 867us/step
# Epoch 49/200
# 511/511 - 0s - loss: 0.1124 - accuracy: 0.9544 - 440ms/epoch - 861us/step
# Epoch 50/200
# 511/511 - 0s - loss: 0.1127 - accuracy: 0.9513 - 442ms/epoch - 866us/step
# Epoch 51/200
# 511/511 - 0s - loss: 0.1118 - accuracy: 0.9534 - 440ms/epoch - 862us/step
# Epoch 52/200
# 511/511 - 0s - loss: 0.1095 - accuracy: 0.9534 - 432ms/epoch - 846us/step
# Epoch 53/200
# 511/511 - 0s - loss: 0.1063 - accuracy: 0.9549 - 443ms/epoch - 866us/step
# Epoch 54/200
# 511/511 - 0s - loss: 0.1059 - accuracy: 0.9564 - 454ms/epoch - 889us/step
# Epoch 55/200
# 511/511 - 0s - loss: 0.1072 - accuracy: 0.9560 - 462ms/epoch - 905us/step
# Epoch 56/200
# 511/511 - 0s - loss: 0.1054 - accuracy: 0.9560 - 439ms/epoch - 860us/step
# Epoch 57/200
# 511/511 - 0s - loss: 0.1090 - accuracy: 0.9552 - 443ms/epoch - 867us/step
# Epoch 58/200
# 511/511 - 0s - loss: 0.1028 - accuracy: 0.9583 - 442ms/epoch - 865us/step
# Epoch 59/200
# 511/511 - 0s - loss: 0.1109 - accuracy: 0.9544 - 439ms/epoch - 859us/step
# Epoch 60/200
# 511/511 - 0s - loss: 0.1044 - accuracy: 0.9560 - 447ms/epoch - 875us/step
# Epoch 61/200
# 511/511 - 0s - loss: 0.1013 - accuracy: 0.9579 - 442ms/epoch - 866us/step
# Epoch 62/200
# 511/511 - 0s - loss: 0.1042 - accuracy: 0.9567 - 442ms/epoch - 866us/step
# Epoch 63/200
# 511/511 - 0s - loss: 0.1052 - accuracy: 0.9566 - 447ms/epoch - 874us/step
# Epoch 64/200
# 511/511 - 0s - loss: 0.0992 - accuracy: 0.9584 - 440ms/epoch - 861us/step
# Epoch 65/200
# 511/511 - 0s - loss: 0.1018 - accuracy: 0.9574 - 438ms/epoch - 857us/step
# Epoch 66/200
# 511/511 - 0s - loss: 0.1038 - accuracy: 0.9563 - 451ms/epoch - 883us/step
# Epoch 67/200
# 511/511 - 0s - loss: 0.0978 - accuracy: 0.9592 - 445ms/epoch - 871us/step
# Epoch 68/200
# 511/511 - 0s - loss: 0.0997 - accuracy: 0.9580 - 451ms/epoch - 883us/step
# Epoch 69/200
# 511/511 - 0s - loss: 0.0986 - accuracy: 0.9586 - 456ms/epoch - 893us/step
# Epoch 70/200
# 511/511 - 0s - loss: 0.0942 - accuracy: 0.9612 - 458ms/epoch - 896us/step
# Epoch 71/200
# 511/511 - 0s - loss: 0.1010 - accuracy: 0.9580 - 445ms/epoch - 872us/step
# Epoch 72/200
# 511/511 - 0s - loss: 0.0951 - accuracy: 0.9608 - 450ms/epoch - 881us/step
# Epoch 73/200
# 511/511 - 0s - loss: 0.0931 - accuracy: 0.9607 - 451ms/epoch - 882us/step
# Epoch 74/200
# 511/511 - 0s - loss: 0.0928 - accuracy: 0.9623 - 448ms/epoch - 877us/step
# Epoch 75/200
# 511/511 - 0s - loss: 0.0890 - accuracy: 0.9621 - 440ms/epoch - 861us/step
# Epoch 76/200
# 511/511 - 0s - loss: 0.0901 - accuracy: 0.9623 - 458ms/epoch - 897us/step
# Epoch 77/200
# 511/511 - 0s - loss: 0.0916 - accuracy: 0.9631 - 441ms/epoch - 862us/step
# Epoch 78/200
# 511/511 - 0s - loss: 0.0891 - accuracy: 0.9636 - 450ms/epoch - 880us/step
# Epoch 79/200
# 511/511 - 0s - loss: 0.0975 - accuracy: 0.9602 - 440ms/epoch - 861us/step
# Epoch 80/200
# 511/511 - 0s - loss: 0.0864 - accuracy: 0.9650 - 437ms/epoch - 856us/step
# Epoch 81/200
# 511/511 - 0s - loss: 0.0886 - accuracy: 0.9623 - 447ms/epoch - 874us/step
# Epoch 82/200
# 511/511 - 0s - loss: 0.0880 - accuracy: 0.9658 - 435ms/epoch - 852us/step
# Epoch 83/200
# 511/511 - 0s - loss: 0.0917 - accuracy: 0.9614 - 443ms/epoch - 867us/step
# Epoch 84/200
# 511/511 - 0s - loss: 0.0821 - accuracy: 0.9657 - 448ms/epoch - 876us/step
# Epoch 85/200
# 511/511 - 0s - loss: 0.0876 - accuracy: 0.9645 - 443ms/epoch - 868us/step
# Epoch 86/200
# 511/511 - 0s - loss: 0.0833 - accuracy: 0.9651 - 439ms/epoch - 858us/step
# Epoch 87/200
# 511/511 - 0s - loss: 0.0864 - accuracy: 0.9652 - 440ms/epoch - 861us/step
# Epoch 88/200
# 511/511 - 0s - loss: 0.0832 - accuracy: 0.9656 - 452ms/epoch - 884us/step
# Epoch 89/200
# 511/511 - 0s - loss: 0.0868 - accuracy: 0.9640 - 441ms/epoch - 863us/step
# Epoch 90/200
# 511/511 - 0s - loss: 0.0887 - accuracy: 0.9629 - 440ms/epoch - 862us/step
# Epoch 91/200
# 511/511 - 0s - loss: 0.0817 - accuracy: 0.9665 - 447ms/epoch - 875us/step
# Epoch 92/200
# 511/511 - 0s - loss: 0.0800 - accuracy: 0.9676 - 446ms/epoch - 874us/step
# Epoch 93/200
# 511/511 - 0s - loss: 0.0817 - accuracy: 0.9656 - 456ms/epoch - 892us/step
# Epoch 94/200
# 511/511 - 0s - loss: 0.0862 - accuracy: 0.9640 - 438ms/epoch - 857us/step
# Epoch 95/200
# 511/511 - 0s - loss: 0.0826 - accuracy: 0.9663 - 454ms/epoch - 888us/step
# Epoch 96/200
# 511/511 - 0s - loss: 0.0773 - accuracy: 0.9689 - 453ms/epoch - 886us/step
# Epoch 97/200
# 511/511 - 0s - loss: 0.0833 - accuracy: 0.9659 - 450ms/epoch - 880us/step
# Epoch 98/200
# 511/511 - 0s - loss: 0.0827 - accuracy: 0.9679 - 451ms/epoch - 884us/step
# Epoch 99/200
# 511/511 - 0s - loss: 0.0784 - accuracy: 0.9676 - 439ms/epoch - 860us/step
# Epoch 100/200
# 511/511 - 0s - loss: 0.0782 - accuracy: 0.9670 - 437ms/epoch - 855us/step
# Epoch 101/200
# 511/511 - 0s - loss: 0.0789 - accuracy: 0.9678 - 450ms/epoch - 881us/step
# Epoch 102/200
# 511/511 - 0s - loss: 0.0787 - accuracy: 0.9678 - 449ms/epoch - 879us/step
# Epoch 103/200
# 511/511 - 0s - loss: 0.0727 - accuracy: 0.9698 - 449ms/epoch - 879us/step
# Epoch 104/200
# 511/511 - 0s - loss: 0.0819 - accuracy: 0.9673 - 445ms/epoch - 871us/step
# Epoch 105/200
# 511/511 - 0s - loss: 0.0773 - accuracy: 0.9696 - 470ms/epoch - 920us/step
# Epoch 106/200
# 511/511 - 0s - loss: 0.0773 - accuracy: 0.9678 - 450ms/epoch - 880us/step
# Epoch 107/200
# 511/511 - 0s - loss: 0.0869 - accuracy: 0.9659 - 450ms/epoch - 880us/step
# Epoch 108/200
# 511/511 - 0s - loss: 0.0770 - accuracy: 0.9690 - 449ms/epoch - 878us/step
# Epoch 109/200
# 511/511 - 0s - loss: 0.0806 - accuracy: 0.9676 - 456ms/epoch - 892us/step
# Epoch 110/200
# 511/511 - 0s - loss: 0.0774 - accuracy: 0.9688 - 445ms/epoch - 872us/step
# Epoch 111/200
# 511/511 - 0s - loss: 0.0774 - accuracy: 0.9682 - 444ms/epoch - 869us/step
# Epoch 112/200
# 511/511 - 0s - loss: 0.0760 - accuracy: 0.9690 - 449ms/epoch - 879us/step
# Epoch 113/200
# 511/511 - 0s - loss: 0.0747 - accuracy: 0.9687 - 451ms/epoch - 883us/step
# Epoch 114/200
# 511/511 - 0s - loss: 0.0715 - accuracy: 0.9716 - 438ms/epoch - 857us/step
# Epoch 115/200
# 511/511 - 0s - loss: 0.0713 - accuracy: 0.9706 - 440ms/epoch - 861us/step
# Epoch 116/200
# 511/511 - 0s - loss: 0.0730 - accuracy: 0.9697 - 441ms/epoch - 864us/step
# Epoch 117/200
# 511/511 - 0s - loss: 0.0807 - accuracy: 0.9668 - 444ms/epoch - 870us/step
# Epoch 118/200
# 511/511 - 0s - loss: 0.0706 - accuracy: 0.9703 - 447ms/epoch - 874us/step
# Epoch 119/200
# 511/511 - 0s - loss: 0.0726 - accuracy: 0.9711 - 445ms/epoch - 871us/step
# Epoch 120/200
# 511/511 - 0s - loss: 0.0732 - accuracy: 0.9706 - 446ms/epoch - 872us/step
# Epoch 121/200
# 511/511 - 0s - loss: 0.0717 - accuracy: 0.9706 - 436ms/epoch - 853us/step
# Epoch 122/200
# 511/511 - 0s - loss: 0.0695 - accuracy: 0.9712 - 447ms/epoch - 875us/step
# Epoch 123/200
# 511/511 - 0s - loss: 0.0731 - accuracy: 0.9700 - 439ms/epoch - 860us/step
# Epoch 124/200
# 511/511 - 0s - loss: 0.0702 - accuracy: 0.9714 - 448ms/epoch - 876us/step
# Epoch 125/200
# 511/511 - 0s - loss: 0.0717 - accuracy: 0.9714 - 451ms/epoch - 883us/step
# Epoch 126/200
# 511/511 - 0s - loss: 0.0731 - accuracy: 0.9697 - 451ms/epoch - 883us/step
# Epoch 127/200
# 511/511 - 0s - loss: 0.0697 - accuracy: 0.9722 - 444ms/epoch - 869us/step
# Epoch 128/200
# 511/511 - 0s - loss: 0.0671 - accuracy: 0.9733 - 455ms/epoch - 891us/step
# Epoch 129/200
# 511/511 - 0s - loss: 0.0662 - accuracy: 0.9720 - 454ms/epoch - 888us/step
# Epoch 130/200
# 511/511 - 0s - loss: 0.0823 - accuracy: 0.9682 - 449ms/epoch - 878us/step
# Epoch 131/200
# 511/511 - 0s - loss: 0.0639 - accuracy: 0.9739 - 451ms/epoch - 883us/step
# Epoch 132/200
# 511/511 - 0s - loss: 0.0639 - accuracy: 0.9740 - 450ms/epoch - 880us/step
# Epoch 133/200
# 511/511 - 0s - loss: 0.0669 - accuracy: 0.9733 - 453ms/epoch - 887us/step
# Epoch 134/200
# 511/511 - 0s - loss: 0.0707 - accuracy: 0.9701 - 444ms/epoch - 870us/step
# Epoch 135/200
# 511/511 - 0s - loss: 0.0636 - accuracy: 0.9744 - 447ms/epoch - 876us/step
# Epoch 136/200
# 511/511 - 0s - loss: 0.0686 - accuracy: 0.9727 - 442ms/epoch - 865us/step
# Epoch 137/200
# 511/511 - 0s - loss: 0.0626 - accuracy: 0.9747 - 435ms/epoch - 851us/step
# Epoch 138/200
# 511/511 - 0s - loss: 0.0638 - accuracy: 0.9738 - 448ms/epoch - 877us/step
# Epoch 139/200
# 511/511 - 0s - loss: 0.0643 - accuracy: 0.9734 - 458ms/epoch - 897us/step
# Epoch 140/200
# 511/511 - 0s - loss: 0.0668 - accuracy: 0.9741 - 443ms/epoch - 867us/step
# Epoch 141/200
# 511/511 - 0s - loss: 0.0623 - accuracy: 0.9750 - 449ms/epoch - 878us/step
# Epoch 142/200
# 511/511 - 0s - loss: 0.0680 - accuracy: 0.9735 - 442ms/epoch - 865us/step
# Epoch 143/200
# 511/511 - 0s - loss: 0.0617 - accuracy: 0.9749 - 453ms/epoch - 886us/step
# Epoch 144/200
# 511/511 - 0s - loss: 0.0663 - accuracy: 0.9728 - 447ms/epoch - 876us/step
# Epoch 145/200
# 511/511 - 0s - loss: 0.0645 - accuracy: 0.9744 - 457ms/epoch - 894us/step
# Epoch 146/200
# 511/511 - 0s - loss: 0.0588 - accuracy: 0.9760 - 455ms/epoch - 891us/step
# Epoch 147/200
# 511/511 - 0s - loss: 0.0701 - accuracy: 0.9725 - 446ms/epoch - 872us/step
# Epoch 148/200
# 511/511 - 0s - loss: 0.0620 - accuracy: 0.9757 - 447ms/epoch - 875us/step
# Epoch 149/200
# 511/511 - 0s - loss: 0.0593 - accuracy: 0.9756 - 443ms/epoch - 867us/step
# Epoch 150/200
# 511/511 - 0s - loss: 0.0620 - accuracy: 0.9753 - 447ms/epoch - 874us/step
# Epoch 151/200
# 511/511 - 0s - loss: 0.0633 - accuracy: 0.9752 - 438ms/epoch - 857us/step
# Epoch 152/200
# 511/511 - 0s - loss: 0.0619 - accuracy: 0.9741 - 444ms/epoch - 868us/step
# Epoch 153/200
# 511/511 - 0s - loss: 0.0609 - accuracy: 0.9760 - 448ms/epoch - 877us/step
# Epoch 154/200
# 511/511 - 0s - loss: 0.0641 - accuracy: 0.9748 - 444ms/epoch - 868us/step
# Epoch 155/200
# 511/511 - 0s - loss: 0.0555 - accuracy: 0.9783 - 446ms/epoch - 872us/step
# Epoch 156/200
# 511/511 - 0s - loss: 0.0598 - accuracy: 0.9765 - 461ms/epoch - 902us/step
# Epoch 157/200
# 511/511 - 0s - loss: 0.0574 - accuracy: 0.9756 - 445ms/epoch - 871us/step
# Epoch 158/200
# 511/511 - 0s - loss: 0.0633 - accuracy: 0.9749 - 453ms/epoch - 886us/step
# Epoch 159/200
# 511/511 - 0s - loss: 0.0603 - accuracy: 0.9747 - 446ms/epoch - 873us/step
# Epoch 160/200
# 511/511 - 0s - loss: 0.0599 - accuracy: 0.9759 - 436ms/epoch - 853us/step
# Epoch 161/200
# 511/511 - 0s - loss: 0.0564 - accuracy: 0.9768 - 440ms/epoch - 861us/step
# Epoch 162/200
# 511/511 - 0s - loss: 0.0538 - accuracy: 0.9771 - 437ms/epoch - 856us/step
# Epoch 163/200
# 511/511 - 0s - loss: 0.0589 - accuracy: 0.9752 - 446ms/epoch - 872us/step
# Epoch 164/200
# 511/511 - 0s - loss: 0.0633 - accuracy: 0.9755 - 441ms/epoch - 863us/step
# Epoch 165/200
# 511/511 - 0s - loss: 0.0510 - accuracy: 0.9788 - 441ms/epoch - 863us/step
# Epoch 166/200
# 511/511 - 0s - loss: 0.0579 - accuracy: 0.9768 - 448ms/epoch - 876us/step
# Epoch 167/200
# 511/511 - 0s - loss: 0.0605 - accuracy: 0.9755 - 450ms/epoch - 880us/step
# Epoch 168/200
# 511/511 - 0s - loss: 0.0556 - accuracy: 0.9771 - 453ms/epoch - 886us/step
# Epoch 169/200
# 511/511 - 0s - loss: 0.0541 - accuracy: 0.9776 - 444ms/epoch - 869us/step
# Epoch 170/200
# 511/511 - 0s - loss: 0.0527 - accuracy: 0.9796 - 435ms/epoch - 851us/step
# Epoch 171/200
# 511/511 - 0s - loss: 0.0583 - accuracy: 0.9765 - 445ms/epoch - 871us/step
# Epoch 172/200
# 511/511 - 0s - loss: 0.0560 - accuracy: 0.9775 - 440ms/epoch - 862us/step
# Epoch 173/200
# 511/511 - 0s - loss: 0.0561 - accuracy: 0.9767 - 455ms/epoch - 891us/step
# Epoch 174/200
# 511/511 - 0s - loss: 0.0538 - accuracy: 0.9786 - 441ms/epoch - 862us/step
# Epoch 175/200
# 511/511 - 0s - loss: 0.0535 - accuracy: 0.9795 - 442ms/epoch - 866us/step
# Epoch 176/200
# 511/511 - 0s - loss: 0.0473 - accuracy: 0.9809 - 445ms/epoch - 871us/step
# Epoch 177/200
# 511/511 - 0s - loss: 0.0638 - accuracy: 0.9733 - 441ms/epoch - 862us/step
# Epoch 178/200
# 511/511 - 0s - loss: 0.0496 - accuracy: 0.9818 - 438ms/epoch - 858us/step
# Epoch 179/200
# 511/511 - 0s - loss: 0.0531 - accuracy: 0.9795 - 433ms/epoch - 848us/step
# Epoch 180/200
# 511/511 - 0s - loss: 0.0616 - accuracy: 0.9760 - 445ms/epoch - 870us/step
# Epoch 181/200
# 511/511 - 0s - loss: 0.0573 - accuracy: 0.9763 - 435ms/epoch - 851us/step
# Epoch 182/200
# 511/511 - 0s - loss: 0.0489 - accuracy: 0.9794 - 447ms/epoch - 875us/step
# Epoch 183/200
# 511/511 - 0s - loss: 0.0487 - accuracy: 0.9808 - 446ms/epoch - 872us/step
# Epoch 184/200
# 511/511 - 0s - loss: 0.0548 - accuracy: 0.9782 - 448ms/epoch - 877us/step
# Epoch 185/200
# 511/511 - 0s - loss: 0.0472 - accuracy: 0.9813 - 441ms/epoch - 863us/step
# Epoch 186/200
# 511/511 - 0s - loss: 0.0527 - accuracy: 0.9788 - 438ms/epoch - 858us/step
# Epoch 187/200
# 511/511 - 0s - loss: 0.0519 - accuracy: 0.9798 - 444ms/epoch - 869us/step
# Epoch 188/200
# 511/511 - 0s - loss: 0.0562 - accuracy: 0.9775 - 441ms/epoch - 864us/step
# Epoch 189/200
# 511/511 - 0s - loss: 0.0485 - accuracy: 0.9797 - 441ms/epoch - 863us/step
# Epoch 190/200
# 511/511 - 0s - loss: 0.0563 - accuracy: 0.9783 - 448ms/epoch - 877us/step
# Epoch 191/200
# 511/511 - 0s - loss: 0.0468 - accuracy: 0.9816 - 446ms/epoch - 873us/step
# Epoch 192/200
# 511/511 - 0s - loss: 0.0457 - accuracy: 0.9812 - 447ms/epoch - 874us/step
# Epoch 193/200
# 511/511 - 0s - loss: 0.0554 - accuracy: 0.9779 - 440ms/epoch - 862us/step
# Epoch 194/200
# 511/511 - 0s - loss: 0.0513 - accuracy: 0.9796 - 442ms/epoch - 865us/step
# Epoch 195/200
# 511/511 - 0s - loss: 0.0485 - accuracy: 0.9802 - 446ms/epoch - 873us/step
# Epoch 196/200
# 511/511 - 0s - loss: 0.0508 - accuracy: 0.9802 - 444ms/epoch - 869us/step
# Epoch 197/200
# 511/511 - 0s - loss: 0.0533 - accuracy: 0.9779 - 433ms/epoch - 848us/step
# Epoch 198/200
# 511/511 - 0s - loss: 0.0396 - accuracy: 0.9840 - 439ms/epoch - 859us/step
# Epoch 199/200
# 511/511 - 0s - loss: 0.0479 - accuracy: 0.9809 - 446ms/epoch - 872us/step
# Epoch 200/200
# 511/511 - 0s - loss: 0.0462 - accuracy: 0.9817 - 435ms/epoch - 851us/step

# %%
#Saving model
model.save("main2classif", save_format='h5')

# %%
print("--Evaluate model--")
model_loss1, model_acc1 = model.evaluate(x_train,  y_train, verbose=2)
model_loss2, model_acc2 = model.evaluate(x_test,  y_test, verbose=2)
print(f"Train / Test Accuracy: {model_acc1*100:.1f}% / {model_acc2*100:.1f}%")
# Out:
# --Evaluate model--
# 511/511 - 0s - loss: 0.0702 - accuracy: 0.9717 - 421ms/epoch - 823us/step
# 128/128 - 0s - loss: 0.1885 - accuracy: 0.9440 - 92ms/epoch - 718us/step
# Train / Test Accuracy: 97.2% / 94.4%

# %% [markdown]
# Report for Main part 2:
#
# Before I start I want to point out that for this part of the assignment, I converted my median_income from a numerical income to a categorical one by using pandas.
# ```py
# data['median_income']=pd.cut(data['median_income'],bins=[0, 1.5, 2.5, 4, 6, 8, 10, 1000],
# include_lowest=True,
# labels=['poverty','below average','average','above average','well off','wealthy','rich'])
# ```
# I did this for two reasons, the major reason was due to the fact that I wanted to use ocean_proximity as an output, which would leave me with no categorical inputs for my model. The second and important reason was, that I felt that these income values made no sense, and were just random floats, essentially diving areas into wealth classes, which I felt would be better represented as categories. So thats what I did, since the values had a wide range, I used a pandas function to map each of the values in the column to an appropriate tag, based on how high the median_income was in that neighborhood.
#
# Columns used as input and output
# Input: longitude	latitude	housing_median_age	total_rooms	total_bedrooms	population	households	median_house_value
# Output: ocean_proximity
#
# For my input, I chose every column except median_income as that was categorical, and ocean_proximity as that was my output.
# The reason for this was because that I was hoping my model would be able to make a connection between the richer and higher demand areas in california, would have houses with more rooms/bedrooms, and the house would be worth more in general. That way when the model see's a house thats worth a lot and has a lot of rooms, it might have a baseline assumption that x house is in y rich area, and the same goes for the houses worth less.
#
# I split my training and testing data in a 80/20 split. This was because after randomizing my data, I decided that it would be much more worthwhile to give my data a significantly larger variety to train on than test on. This is because testing is used to see the accuracy of the model, and to get higher accuracy, the model needs to train on a much larger variety, so that if the test has a strange input, it can still make a decision based on the experience that it has, but if I make my training input smaller, it becomes more and more likely that the test will have an input that the model has little to no experience for.
#
# Two decisions that I made for my model design was to process my input. One thing that I did that I felt had a big impact on the accuracy was that I scaled the numerical inputs with the RobustScaler from sklearn (Based on Joweria's process), the second thing that I felt had a big impact was that I normalized the inputs, as the inputs were all numbers that were very different from each other. Normalizing them was important for the model to be able to make sense of things with less difficulty.
#
# In terms of hyper parameters, I had my normalizer, and then I just attempted to make a relatively dense model with lots of layers with the relu activation. Meaning i added lots of the Dense layers. I found that I haven't needed to mess with the units in the softmax layer yet, but I will probably begin experimenting with it during part 3 or 4 of main.
#
# Currently my model is quite accurate, getting 97.2% accuracy on the training, and 94.4% accuracy on the test. Despite this being a pretty acceptable number, I think this discrepency between the two shows that my model is over-fitted to the training data, and the test shouldnt have a signficicant amount of outliers in comparison to the training data, so for the next iterations I will try to fix this discrepency between training and test data. But I also believe that overall accuracy will rise with the introduction of the income column (categorical) column later on.
