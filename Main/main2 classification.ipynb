# %%
#Main Project Stage 1: Data Science and Machine Learning
# Import the required libraries

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn
import tensorflow as tf

# Set sns theme to your preferred color palette
sns.set_theme(palette = "mako")

data = pd.read_csv('data/data-input.csv')  # read csv file
data.to_csv("data/data.csv",index=False)
#data input is the data that I had previously cleaned before starting the assignment
data = pd.read_csv("data/data.csv") #pretty confused as to why the instructions ask for this, but I guess its not a big deal
data['median_income']=pd.cut(data['median_income'],bins=[0, 1.5, 2.5, 4, 6, 8, 10, 1000], 
include_lowest=True, 
labels=['poverty','below average','average','above average','well off','wealthy','rich'])
df = data.copy()  # create a copy to use for future reference, so I have a copy of my original dataset when needed

data.head()
#Cleaned data (now called data-input.csv) by hand beforehand before reading instructions, so my data is already good.
#Will be skipping the pandas clean data step
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0        wealthy            452600.0        NEAR BAY
# 1      2401.0      1138.0        wealthy            358500.0        NEAR BAY
# 2       496.0       177.0       well off            352100.0        NEAR BAY
# 3       558.0       219.0  above average            341300.0        NEAR BAY
# 4       565.0       259.0        average            342200.0        NEAR BAY

# %%
#Histogram showing distribution of housing age in the market
agehist = sns.histplot(data=df, x = "housing_median_age")
fig = agehist.get_figure()
fig.savefig("plots/plot1.png")

# %%
#Visualization of relationship (and variation) in housing price based on its age
age_value_lineplot = sns.lineplot(data=df, x = "housing_median_age", y = "median_house_value")
fig = age_value_lineplot.get_figure()
fig.savefig("plots/plot2.png")

# %%
#Visualization of price distribution of houses in california
house_value_histplot = sns.histplot(data=df, x = "median_house_value")
fig = house_value_histplot.get_figure()
fig.savefig("plots/plot3.png") 
#Can see from output that a majority of the houses are from 150k to 250k

# %% [markdown]
# Where the data came from.:
#
# https://www.kaggle.com/datasets/kathuman/housing
# I will be using the dataset on Housing Prices in California found on Kaggle with a creative Commons Public Domain License
# Description of data from creator:
# "This dataset is based on data from the 1990 California Census, and incluides metrics such as the population, median income, and median housing proice for each block group in California.
# Block groups are the smallest geographical unit for which the US Census Bureau publishes sample data., and each block typically has between 600 to 3000 people."
#
# The goal I have with this dataset is to be able to get my model to guess the price of houses given all the other information.
#
#
# Challenges cleaning:
#
# One of the challenges I had cleaning was that the dataset was humongous (22k rows) so I worried that I missed some stuff while cleaning but overall it was pretty straightforward. I cleaned it by hand before starting the assignment, and the biggest issue was that there was a lot of data to delete by hand. There was a lot of cells that just had nothing inside it, so I had to delete the entire line, which meant I couldnt automate it with find and replace. But other than that, the data seems pretty clean, and there are some spots in the data that I might need to go back and change, but for now I think the data looks reliable, based on the distribution I've seen from my graphs.
#
# Three visualizations:
#
# plot1 is a distribution of the age of the house. We can see that california has a wide range of ages for their houses. But their seems to be a spike in houses that are around 20, 30, and 50+ years old. Overall I think the distribution in that column is pretty good, and should pose no issues in training my model.
#
# plot2 is a visualization of relationship (and variation) in housing price based on its age. One thing that bothered me in this, is that from the graph, the house prices seem to very a lot for some age groups, specifically ~10 years old and ~50 years old. I worry that this will have negative effects in the model, but at the same time, logically speaking this is a realistic scenario. As old houses that are still standing are likely to be very nice to begin with, and new houses that are being built are being built for many different types of people with different incomes, especially in california where there is a large amount of wealthy and average people concentrated in one area.
#
# plot3 is a visualization of price distribution of houses in california. I wanted to see where the price of houses was concentrated, this graph allowed me to see that a majority of the houses in california in the dataset are around $150k-250k. But there is also a sizeable amount of houses below and above that number. Which should pose as good variation to give model a wide range of information to make accurate estimates.
#
# Part 2 code begins after this report
# --

# %%
df.shape  # Will return the number of rows and columns
# Out:
# (20433, 10)

# %%
df.info()  # Will inform you of the datatype of each variable, as well as if there are any null or missing values in each column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20433 entries, 0 to 20432
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  category
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: category(1), float64(8), object(1)
# memory usage: 1.4+ MB

# %%
df.describe().T # Describe the data-frame (transposed) - defaults to describing only numerical
# If you want to describe all, run the following command:
# data.describe(include = "all").T
# Out:
#                       count           mean            std       min  \
# longitude           20433.0    -119.570689       2.003578   -124.35
# latitude            20433.0      35.633221       2.136348     32.54
# housing_median_age  20433.0      28.633094      12.591805      1.00
# total_rooms         20433.0    2636.504233    2185.269567      2.00
# total_bedrooms      20433.0     537.870553     421.385070      1.00
# population          20433.0    1424.946949    1133.208490      3.00
# households          20433.0     499.433465     382.299226      1.00
# median_house_value  20433.0  206864.413155  115435.667099  14999.00
#
#                           25%        50%        75%        max
# longitude             -121.80    -118.49    -118.01    -114.31
# latitude                33.93      34.26      37.72      41.95
# housing_median_age      18.00      29.00      37.00      52.00
# total_rooms           1450.00    2127.00    3143.00   39320.00
# total_bedrooms         296.00     435.00     647.00    6445.00
# population             787.00    1166.00    1722.00   35682.00
# households             280.00     409.00     604.00    6082.00
# median_house_value  119500.00  179700.00  264700.00  500001.00

# %%
df.isnull().sum()  # Checking for null values
# In this case there are no null values. If there are some, you can use a heatmap to visualize them if you want.
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
#Organizing categorical data
#Citation is from Joweria's heartdisease tutorial notebook
from pandas.core.arrays import categorical 
#my df is joweria data, my df is joweria data
categorical_data = ["ocean_proximity","median_income"]

codes = {}  # Create a dictionary to store the codes of the conversion
for i in df:  # For each variable in the data frame 
  if i in categorical_data:  # For each variable that was classified as categorical
    specific_codes = {}  # Create a dictionary for that variable's code conversion 
    df[i] = df[i].astype("category")  # Convert that variable from 'object' datatype to category
    df[i] = df[i].cat.codes  # Create codes for the categories and replace in the dataset 
    coded = df[i].unique()  # Get the unique values (the codes) from the variable
    count = 0  # Count initialized. Later used for accessing specific indexes
    for j in data[i].unique():  # For each unique value
      specific_codes[j] = coded[count]  # Create an item in the dictionary with the value, and tell it which code correlates
      count += 1  # Count incremented
    codes[i] = specific_codes  # Create a new item in the overall dictionary with the dictionary created for this specific variable's codes


# View our created dictionary:
for i in codes:
  print("{} -".format(i))
  for j in codes[i]:
    print("{}: {}".format(j, codes[i][j]))
  print()
# Out:
# median_income -
# wealthy: 5
# well off: 4
# above average: 3
# average: 2
# below average: 1
# poverty: 0
# rich: 6
#
# ocean_proximity -
# NEAR BAY: 3
# <1H OCEAN: 0
# INLAND: 1
# NEAR OCEAN: 4
# ISLAND: 2

# %%
df.head()
#Checking that data is no longer categorical and now an integer at the end
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value  ocean_proximity
# 0       322.0       126.0              5            452600.0                3
# 1      2401.0      1138.0              5            358500.0                3
# 2       496.0       177.0              4            352100.0                3
# 3       558.0       219.0              3            341300.0                3
# 4       565.0       259.0              2            342200.0                3

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler
fs_data = df.copy() # copy of dataset for feature selection
x = fs_data.iloc[:,[0,1,2,3,4,5,6,7,8]]  # independent variables
y = fs_data.iloc[:,[9]]    # target column / what we're trying to predict


#https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html
#Found this easy way to split training data in the scikit documentation
#Shuffles data, and allocated 80% of it to be used for training, and 20% of it to be used for testing
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2) # splitting up dataset to training and testing

scl = RobustScaler() # Preprocess numerical data 
x_train = scl.fit_transform(x_train) 
x_test = scl.transform(x_test)

# %%
#x_train.head()

# %%
normalizer = tf.keras.layers.Normalization(axis=-1)
normalizer.adapt(x_train)
print(normalizer.mean.numpy())
# Out:
# [[-0.28286847  0.36352098 -0.02113185  0.30338335  0.29487276  0.27455467
#    0.27898753  0.28349462  0.18710104]]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Flatten


print("--Make model--")
model = tf.keras.models.Sequential([
  normalizer,
  tf.keras.layers.Dense(64, activation='relu'),
  tf.keras.layers.Dense(64, activation='relu'),
  tf.keras.layers.Dense(64, activation='relu'),
  tf.keras.layers.Dense(64, activation='relu'),
  tf.keras.layers.Dense(10, activation='softmax'),
])
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

print("--Fit model--")
model.fit(x_train, y_train, epochs=200, verbose=2)
# Out:
# --Make model--
# --Fit model--
# Epoch 1/200
# 511/511 - 1s - loss: 0.6822 - accuracy: 0.7375 - 724ms/epoch - 1ms/step
# Epoch 2/200
# 511/511 - 0s - loss: 0.3757 - accuracy: 0.8480 - 439ms/epoch - 858us/step
# Epoch 3/200
# 511/511 - 0s - loss: 0.3293 - accuracy: 0.8638 - 434ms/epoch - 849us/step
# Epoch 4/200
# 511/511 - 0s - loss: 0.2910 - accuracy: 0.8791 - 444ms/epoch - 869us/step
# Epoch 5/200
# 511/511 - 0s - loss: 0.2672 - accuracy: 0.8896 - 439ms/epoch - 858us/step
# Epoch 6/200
# 511/511 - 0s - loss: 0.2482 - accuracy: 0.8976 - 434ms/epoch - 849us/step
# Epoch 7/200
# 511/511 - 0s - loss: 0.2307 - accuracy: 0.9042 - 442ms/epoch - 865us/step
# Epoch 8/200
# 511/511 - 0s - loss: 0.2168 - accuracy: 0.9099 - 442ms/epoch - 866us/step
# Epoch 9/200
# 511/511 - 0s - loss: 0.2071 - accuracy: 0.9125 - 441ms/epoch - 864us/step
# Epoch 10/200
# 511/511 - 0s - loss: 0.2033 - accuracy: 0.9159 - 446ms/epoch - 874us/step
# Epoch 11/200
# 511/511 - 0s - loss: 0.1902 - accuracy: 0.9209 - 446ms/epoch - 874us/step
# Epoch 12/200
# 511/511 - 0s - loss: 0.1872 - accuracy: 0.9219 - 437ms/epoch - 856us/step
# Epoch 13/200
# 511/511 - 0s - loss: 0.1817 - accuracy: 0.9232 - 436ms/epoch - 853us/step
# Epoch 14/200
# 511/511 - 0s - loss: 0.1777 - accuracy: 0.9226 - 440ms/epoch - 860us/step
# Epoch 15/200
# 511/511 - 0s - loss: 0.1689 - accuracy: 0.9285 - 449ms/epoch - 878us/step
# Epoch 16/200
# 511/511 - 0s - loss: 0.1665 - accuracy: 0.9289 - 430ms/epoch - 841us/step
# Epoch 17/200
# 511/511 - 0s - loss: 0.1659 - accuracy: 0.9302 - 431ms/epoch - 843us/step
# Epoch 18/200
# 511/511 - 0s - loss: 0.1644 - accuracy: 0.9320 - 440ms/epoch - 861us/step
# Epoch 19/200
# 511/511 - 0s - loss: 0.1517 - accuracy: 0.9342 - 435ms/epoch - 851us/step
# Epoch 20/200
# 511/511 - 0s - loss: 0.1541 - accuracy: 0.9342 - 442ms/epoch - 866us/step
# Epoch 21/200
# 511/511 - 0s - loss: 0.1543 - accuracy: 0.9337 - 443ms/epoch - 867us/step
# Epoch 22/200
# 511/511 - 0s - loss: 0.1489 - accuracy: 0.9356 - 445ms/epoch - 870us/step
# Epoch 23/200
# 511/511 - 0s - loss: 0.1452 - accuracy: 0.9385 - 439ms/epoch - 859us/step
# Epoch 24/200
# 511/511 - 0s - loss: 0.1428 - accuracy: 0.9380 - 442ms/epoch - 865us/step
# Epoch 25/200
# 511/511 - 0s - loss: 0.1395 - accuracy: 0.9403 - 433ms/epoch - 848us/step
# Epoch 26/200
# 511/511 - 0s - loss: 0.1431 - accuracy: 0.9391 - 424ms/epoch - 831us/step
# Epoch 27/200
# 511/511 - 0s - loss: 0.1333 - accuracy: 0.9421 - 431ms/epoch - 844us/step
# Epoch 28/200
# 511/511 - 0s - loss: 0.1385 - accuracy: 0.9407 - 440ms/epoch - 862us/step
# Epoch 29/200
# 511/511 - 0s - loss: 0.1394 - accuracy: 0.9409 - 455ms/epoch - 891us/step
# Epoch 30/200
# 511/511 - 0s - loss: 0.1306 - accuracy: 0.9434 - 437ms/epoch - 856us/step
# Epoch 31/200
# 511/511 - 0s - loss: 0.1321 - accuracy: 0.9414 - 439ms/epoch - 859us/step
# Epoch 32/200
# 511/511 - 0s - loss: 0.1280 - accuracy: 0.9437 - 442ms/epoch - 866us/step
# Epoch 33/200
# 511/511 - 0s - loss: 0.1282 - accuracy: 0.9441 - 436ms/epoch - 853us/step
# Epoch 34/200
# 511/511 - 0s - loss: 0.1252 - accuracy: 0.9452 - 448ms/epoch - 878us/step
# Epoch 35/200
# 511/511 - 0s - loss: 0.1214 - accuracy: 0.9493 - 440ms/epoch - 860us/step
# Epoch 36/200
# 511/511 - 0s - loss: 0.1176 - accuracy: 0.9506 - 438ms/epoch - 856us/step
# Epoch 37/200
# 511/511 - 0s - loss: 0.1258 - accuracy: 0.9460 - 445ms/epoch - 870us/step
# Epoch 38/200
# 511/511 - 0s - loss: 0.1248 - accuracy: 0.9473 - 443ms/epoch - 866us/step
# Epoch 39/200
# 511/511 - 0s - loss: 0.1238 - accuracy: 0.9475 - 447ms/epoch - 874us/step
# Epoch 40/200
# 511/511 - 0s - loss: 0.1206 - accuracy: 0.9500 - 440ms/epoch - 862us/step
# Epoch 41/200
# 511/511 - 0s - loss: 0.1151 - accuracy: 0.9512 - 442ms/epoch - 866us/step
# Epoch 42/200
# 511/511 - 0s - loss: 0.1133 - accuracy: 0.9506 - 426ms/epoch - 833us/step
# Epoch 43/200
# 511/511 - 0s - loss: 0.1160 - accuracy: 0.9529 - 439ms/epoch - 860us/step
# Epoch 44/200
# 511/511 - 0s - loss: 0.1099 - accuracy: 0.9526 - 439ms/epoch - 859us/step
# Epoch 45/200
# 511/511 - 0s - loss: 0.1173 - accuracy: 0.9497 - 450ms/epoch - 880us/step
# Epoch 46/200
# 511/511 - 0s - loss: 0.1124 - accuracy: 0.9523 - 469ms/epoch - 918us/step
# Epoch 47/200
# 511/511 - 0s - loss: 0.1084 - accuracy: 0.9531 - 439ms/epoch - 860us/step
# Epoch 48/200
# 511/511 - 0s - loss: 0.1098 - accuracy: 0.9538 - 428ms/epoch - 838us/step
# Epoch 49/200
# 511/511 - 0s - loss: 0.1094 - accuracy: 0.9543 - 432ms/epoch - 846us/step
# Epoch 50/200
# 511/511 - 0s - loss: 0.1054 - accuracy: 0.9550 - 439ms/epoch - 858us/step
# Epoch 51/200
# 511/511 - 0s - loss: 0.1051 - accuracy: 0.9572 - 435ms/epoch - 851us/step
# Epoch 52/200
# 511/511 - 0s - loss: 0.1050 - accuracy: 0.9551 - 440ms/epoch - 861us/step
# Epoch 53/200
# 511/511 - 0s - loss: 0.1023 - accuracy: 0.9581 - 428ms/epoch - 837us/step
# Epoch 54/200
# 511/511 - 0s - loss: 0.1026 - accuracy: 0.9587 - 442ms/epoch - 865us/step
# Epoch 55/200
# 511/511 - 0s - loss: 0.1008 - accuracy: 0.9572 - 447ms/epoch - 875us/step
# Epoch 56/200
# 511/511 - 0s - loss: 0.0977 - accuracy: 0.9587 - 439ms/epoch - 859us/step
# Epoch 57/200
# 511/511 - 0s - loss: 0.1043 - accuracy: 0.9569 - 436ms/epoch - 853us/step
# Epoch 58/200
# 511/511 - 0s - loss: 0.1014 - accuracy: 0.9586 - 428ms/epoch - 837us/step
# Epoch 59/200
# 511/511 - 0s - loss: 0.0959 - accuracy: 0.9604 - 435ms/epoch - 852us/step
# Epoch 60/200
# 511/511 - 0s - loss: 0.0924 - accuracy: 0.9613 - 437ms/epoch - 855us/step
# Epoch 61/200
# 511/511 - 0s - loss: 0.0987 - accuracy: 0.9589 - 440ms/epoch - 861us/step
# Epoch 62/200
# 511/511 - 0s - loss: 0.0932 - accuracy: 0.9602 - 436ms/epoch - 853us/step
# Epoch 63/200
# 511/511 - 0s - loss: 0.0944 - accuracy: 0.9605 - 442ms/epoch - 865us/step
# Epoch 64/200
# 511/511 - 0s - loss: 0.0973 - accuracy: 0.9602 - 446ms/epoch - 873us/step
# Epoch 65/200
# 511/511 - 0s - loss: 0.0916 - accuracy: 0.9623 - 438ms/epoch - 857us/step
# Epoch 66/200
# 511/511 - 0s - loss: 0.0943 - accuracy: 0.9616 - 435ms/epoch - 852us/step
# Epoch 67/200
# 511/511 - 0s - loss: 0.0954 - accuracy: 0.9616 - 430ms/epoch - 842us/step
# Epoch 68/200
# 511/511 - 0s - loss: 0.0874 - accuracy: 0.9629 - 441ms/epoch - 864us/step
# Epoch 69/200
# 511/511 - 0s - loss: 0.0892 - accuracy: 0.9619 - 443ms/epoch - 866us/step
# Epoch 70/200
# 511/511 - 0s - loss: 0.0918 - accuracy: 0.9624 - 443ms/epoch - 867us/step
# Epoch 71/200
# 511/511 - 0s - loss: 0.0797 - accuracy: 0.9667 - 441ms/epoch - 864us/step
# Epoch 72/200
# 511/511 - 0s - loss: 0.0879 - accuracy: 0.9648 - 441ms/epoch - 863us/step
# Epoch 73/200
# 511/511 - 0s - loss: 0.0849 - accuracy: 0.9649 - 441ms/epoch - 863us/step
# Epoch 74/200
# 511/511 - 0s - loss: 0.0872 - accuracy: 0.9640 - 438ms/epoch - 858us/step
# Epoch 75/200
# 511/511 - 0s - loss: 0.0872 - accuracy: 0.9643 - 443ms/epoch - 866us/step
# Epoch 76/200
# 511/511 - 0s - loss: 0.0924 - accuracy: 0.9617 - 438ms/epoch - 858us/step
# Epoch 77/200
# 511/511 - 0s - loss: 0.0862 - accuracy: 0.9646 - 435ms/epoch - 851us/step
# Epoch 78/200
# 511/511 - 0s - loss: 0.0842 - accuracy: 0.9648 - 442ms/epoch - 865us/step
# Epoch 79/200
# 511/511 - 0s - loss: 0.0838 - accuracy: 0.9651 - 439ms/epoch - 860us/step
# Epoch 80/200
# 511/511 - 0s - loss: 0.0831 - accuracy: 0.9655 - 444ms/epoch - 869us/step
# Epoch 81/200
# 511/511 - 0s - loss: 0.0823 - accuracy: 0.9649 - 437ms/epoch - 854us/step
# Epoch 82/200
# 511/511 - 0s - loss: 0.0781 - accuracy: 0.9686 - 441ms/epoch - 863us/step
# Epoch 83/200
# 511/511 - 0s - loss: 0.0787 - accuracy: 0.9680 - 431ms/epoch - 843us/step
# Epoch 84/200
# 511/511 - 0s - loss: 0.0850 - accuracy: 0.9647 - 430ms/epoch - 842us/step
# Epoch 85/200
# 511/511 - 0s - loss: 0.0752 - accuracy: 0.9692 - 450ms/epoch - 880us/step
# Epoch 86/200
# 511/511 - 0s - loss: 0.0809 - accuracy: 0.9662 - 437ms/epoch - 855us/step
# Epoch 87/200
# 511/511 - 0s - loss: 0.0842 - accuracy: 0.9660 - 435ms/epoch - 850us/step
# Epoch 88/200
# 511/511 - 0s - loss: 0.0773 - accuracy: 0.9676 - 431ms/epoch - 844us/step
# Epoch 89/200
# 511/511 - 0s - loss: 0.0877 - accuracy: 0.9643 - 426ms/epoch - 834us/step
# Epoch 90/200
# 511/511 - 0s - loss: 0.0797 - accuracy: 0.9674 - 437ms/epoch - 856us/step
# Epoch 91/200
# 511/511 - 0s - loss: 0.0709 - accuracy: 0.9698 - 435ms/epoch - 851us/step
# Epoch 92/200
# 511/511 - 0s - loss: 0.0732 - accuracy: 0.9710 - 431ms/epoch - 843us/step
# Epoch 93/200
# 511/511 - 0s - loss: 0.0734 - accuracy: 0.9708 - 432ms/epoch - 846us/step
# Epoch 94/200
# 511/511 - 0s - loss: 0.0826 - accuracy: 0.9651 - 478ms/epoch - 936us/step
# Epoch 95/200
# 511/511 - 0s - loss: 0.0726 - accuracy: 0.9706 - 440ms/epoch - 861us/step
# Epoch 96/200
# 511/511 - 0s - loss: 0.0766 - accuracy: 0.9686 - 445ms/epoch - 870us/step
# Epoch 97/200
# 511/511 - 0s - loss: 0.0739 - accuracy: 0.9697 - 449ms/epoch - 880us/step
# Epoch 98/200
# 511/511 - 0s - loss: 0.0730 - accuracy: 0.9694 - 455ms/epoch - 891us/step
# Epoch 99/200
# 511/511 - 0s - loss: 0.0739 - accuracy: 0.9692 - 436ms/epoch - 853us/step
# Epoch 100/200
# 511/511 - 0s - loss: 0.0690 - accuracy: 0.9722 - 444ms/epoch - 869us/step
# Epoch 101/200
# 511/511 - 0s - loss: 0.0761 - accuracy: 0.9675 - 444ms/epoch - 869us/step
# Epoch 102/200
# 511/511 - 0s - loss: 0.0713 - accuracy: 0.9706 - 423ms/epoch - 828us/step
# Epoch 103/200
# 511/511 - 0s - loss: 0.0778 - accuracy: 0.9673 - 435ms/epoch - 850us/step
# Epoch 104/200
# 511/511 - 0s - loss: 0.0660 - accuracy: 0.9723 - 435ms/epoch - 851us/step
# Epoch 105/200
# 511/511 - 0s - loss: 0.0671 - accuracy: 0.9720 - 441ms/epoch - 864us/step
# Epoch 106/200
# 511/511 - 0s - loss: 0.0767 - accuracy: 0.9689 - 437ms/epoch - 855us/step
# Epoch 107/200
# 511/511 - 0s - loss: 0.0713 - accuracy: 0.9692 - 439ms/epoch - 859us/step
# Epoch 108/200
# 511/511 - 0s - loss: 0.0692 - accuracy: 0.9719 - 431ms/epoch - 844us/step
# Epoch 109/200
# 511/511 - 0s - loss: 0.0659 - accuracy: 0.9730 - 449ms/epoch - 878us/step
# Epoch 110/200
# 511/511 - 0s - loss: 0.0664 - accuracy: 0.9733 - 443ms/epoch - 868us/step
# Epoch 111/200
# 511/511 - 0s - loss: 0.0623 - accuracy: 0.9728 - 439ms/epoch - 859us/step
# Epoch 112/200
# 511/511 - 0s - loss: 0.0765 - accuracy: 0.9684 - 437ms/epoch - 855us/step
# Epoch 113/200
# 511/511 - 0s - loss: 0.0623 - accuracy: 0.9744 - 444ms/epoch - 870us/step
# Epoch 114/200
# 511/511 - 0s - loss: 0.0673 - accuracy: 0.9730 - 439ms/epoch - 858us/step
# Epoch 115/200
# 511/511 - 0s - loss: 0.0687 - accuracy: 0.9718 - 441ms/epoch - 863us/step
# Epoch 116/200
# 511/511 - 0s - loss: 0.0631 - accuracy: 0.9747 - 433ms/epoch - 848us/step
# Epoch 117/200
# 511/511 - 0s - loss: 0.0660 - accuracy: 0.9744 - 427ms/epoch - 836us/step
# Epoch 118/200
# 511/511 - 0s - loss: 0.0608 - accuracy: 0.9749 - 442ms/epoch - 865us/step
# Epoch 119/200
# 511/511 - 0s - loss: 0.0613 - accuracy: 0.9752 - 441ms/epoch - 864us/step
# Epoch 120/200
# 511/511 - 0s - loss: 0.0686 - accuracy: 0.9728 - 443ms/epoch - 867us/step
# Epoch 121/200
# 511/511 - 0s - loss: 0.0648 - accuracy: 0.9731 - 440ms/epoch - 860us/step
# Epoch 122/200
# 511/511 - 0s - loss: 0.0639 - accuracy: 0.9750 - 439ms/epoch - 859us/step
# Epoch 123/200
# 511/511 - 0s - loss: 0.0668 - accuracy: 0.9723 - 440ms/epoch - 861us/step
# Epoch 124/200
# 511/511 - 0s - loss: 0.0596 - accuracy: 0.9755 - 438ms/epoch - 858us/step
# Epoch 125/200
# 511/511 - 0s - loss: 0.0640 - accuracy: 0.9736 - 439ms/epoch - 858us/step
# Epoch 126/200
# 511/511 - 0s - loss: 0.0580 - accuracy: 0.9771 - 440ms/epoch - 861us/step
# Epoch 127/200
# 511/511 - 0s - loss: 0.0600 - accuracy: 0.9765 - 434ms/epoch - 849us/step
# Epoch 128/200
# 511/511 - 0s - loss: 0.0609 - accuracy: 0.9752 - 442ms/epoch - 866us/step
# Epoch 129/200
# 511/511 - 0s - loss: 0.0664 - accuracy: 0.9725 - 427ms/epoch - 835us/step
# Epoch 130/200
# 511/511 - 0s - loss: 0.0579 - accuracy: 0.9761 - 441ms/epoch - 863us/step
# Epoch 131/200
# 511/511 - 0s - loss: 0.0683 - accuracy: 0.9725 - 439ms/epoch - 859us/step
# Epoch 132/200
# 511/511 - 0s - loss: 0.0683 - accuracy: 0.9723 - 421ms/epoch - 824us/step
# Epoch 133/200
# 511/511 - 0s - loss: 0.0562 - accuracy: 0.9769 - 437ms/epoch - 856us/step
# Epoch 134/200
# 511/511 - 0s - loss: 0.0560 - accuracy: 0.9781 - 442ms/epoch - 864us/step
# Epoch 135/200
# 511/511 - 0s - loss: 0.0611 - accuracy: 0.9741 - 431ms/epoch - 843us/step
# Epoch 136/200
# 511/511 - 0s - loss: 0.0554 - accuracy: 0.9784 - 442ms/epoch - 865us/step
# Epoch 137/200
# 511/511 - 0s - loss: 0.0597 - accuracy: 0.9761 - 440ms/epoch - 861us/step
# Epoch 138/200
# 511/511 - 0s - loss: 0.0617 - accuracy: 0.9761 - 427ms/epoch - 836us/step
# Epoch 139/200
# 511/511 - 0s - loss: 0.0541 - accuracy: 0.9793 - 430ms/epoch - 842us/step
# Epoch 140/200
# 511/511 - 0s - loss: 0.0607 - accuracy: 0.9749 - 449ms/epoch - 878us/step
# Epoch 141/200
# 511/511 - 0s - loss: 0.0557 - accuracy: 0.9776 - 444ms/epoch - 868us/step
# Epoch 142/200
# 511/511 - 0s - loss: 0.0531 - accuracy: 0.9766 - 432ms/epoch - 845us/step
# Epoch 143/200
# 511/511 - 0s - loss: 0.0547 - accuracy: 0.9776 - 466ms/epoch - 912us/step
# Epoch 144/200
# 511/511 - 0s - loss: 0.0615 - accuracy: 0.9746 - 438ms/epoch - 857us/step
# Epoch 145/200
# 511/511 - 0s - loss: 0.0540 - accuracy: 0.9786 - 446ms/epoch - 873us/step
# Epoch 146/200
# 511/511 - 0s - loss: 0.0567 - accuracy: 0.9773 - 440ms/epoch - 861us/step
# Epoch 147/200
# 511/511 - 0s - loss: 0.0532 - accuracy: 0.9799 - 447ms/epoch - 874us/step
# Epoch 148/200
# 511/511 - 0s - loss: 0.0604 - accuracy: 0.9753 - 443ms/epoch - 867us/step
# Epoch 149/200
# 511/511 - 0s - loss: 0.0518 - accuracy: 0.9787 - 434ms/epoch - 849us/step
# Epoch 150/200
# 511/511 - 0s - loss: 0.0603 - accuracy: 0.9774 - 440ms/epoch - 861us/step
# Epoch 151/200
# 511/511 - 0s - loss: 0.0534 - accuracy: 0.9791 - 437ms/epoch - 855us/step
# Epoch 152/200
# 511/511 - 0s - loss: 0.0506 - accuracy: 0.9795 - 443ms/epoch - 868us/step
# Epoch 153/200
# 511/511 - 0s - loss: 0.0500 - accuracy: 0.9798 - 445ms/epoch - 872us/step
# Epoch 154/200
# 511/511 - 0s - loss: 0.0573 - accuracy: 0.9763 - 444ms/epoch - 869us/step
# Epoch 155/200
# 511/511 - 0s - loss: 0.0476 - accuracy: 0.9804 - 447ms/epoch - 874us/step
# Epoch 156/200
# 511/511 - 0s - loss: 0.0500 - accuracy: 0.9805 - 439ms/epoch - 859us/step
# Epoch 157/200
# 511/511 - 0s - loss: 0.0571 - accuracy: 0.9783 - 443ms/epoch - 868us/step
# Epoch 158/200
# 511/511 - 0s - loss: 0.0493 - accuracy: 0.9796 - 441ms/epoch - 863us/step
# Epoch 159/200
# 511/511 - 0s - loss: 0.0485 - accuracy: 0.9800 - 443ms/epoch - 866us/step
# Epoch 160/200
# 511/511 - 0s - loss: 0.0492 - accuracy: 0.9802 - 431ms/epoch - 844us/step
# Epoch 161/200
# 511/511 - 0s - loss: 0.0515 - accuracy: 0.9793 - 448ms/epoch - 878us/step
# Epoch 162/200
# 511/511 - 0s - loss: 0.0505 - accuracy: 0.9803 - 421ms/epoch - 824us/step
# Epoch 163/200
# 511/511 - 0s - loss: 0.0482 - accuracy: 0.9803 - 437ms/epoch - 856us/step
# Epoch 164/200
# 511/511 - 0s - loss: 0.0598 - accuracy: 0.9782 - 434ms/epoch - 848us/step
# Epoch 165/200
# 511/511 - 0s - loss: 0.0487 - accuracy: 0.9807 - 446ms/epoch - 873us/step
# Epoch 166/200
# 511/511 - 0s - loss: 0.0505 - accuracy: 0.9794 - 443ms/epoch - 867us/step
# Epoch 167/200
# 511/511 - 0s - loss: 0.0481 - accuracy: 0.9804 - 439ms/epoch - 860us/step
# Epoch 168/200
# 511/511 - 0s - loss: 0.0407 - accuracy: 0.9834 - 449ms/epoch - 880us/step
# Epoch 169/200
# 511/511 - 0s - loss: 0.0430 - accuracy: 0.9834 - 438ms/epoch - 856us/step
# Epoch 170/200
# 511/511 - 0s - loss: 0.0527 - accuracy: 0.9796 - 443ms/epoch - 868us/step
# Epoch 171/200
# 511/511 - 0s - loss: 0.0599 - accuracy: 0.9764 - 448ms/epoch - 877us/step
# Epoch 172/200
# 511/511 - 0s - loss: 0.0409 - accuracy: 0.9834 - 445ms/epoch - 871us/step
# Epoch 173/200
# 511/511 - 0s - loss: 0.0458 - accuracy: 0.9815 - 444ms/epoch - 869us/step
# Epoch 174/200
# 511/511 - 0s - loss: 0.0447 - accuracy: 0.9829 - 440ms/epoch - 860us/step
# Epoch 175/200
# 511/511 - 0s - loss: 0.0497 - accuracy: 0.9807 - 433ms/epoch - 847us/step
# Epoch 176/200
# 511/511 - 0s - loss: 0.0438 - accuracy: 0.9834 - 441ms/epoch - 864us/step
# Epoch 177/200
# 511/511 - 0s - loss: 0.0438 - accuracy: 0.9823 - 439ms/epoch - 859us/step
# Epoch 178/200
# 511/511 - 0s - loss: 0.0474 - accuracy: 0.9800 - 441ms/epoch - 864us/step
# Epoch 179/200
# 511/511 - 0s - loss: 0.0431 - accuracy: 0.9826 - 440ms/epoch - 860us/step
# Epoch 180/200
# 511/511 - 0s - loss: 0.0543 - accuracy: 0.9785 - 427ms/epoch - 837us/step
# Epoch 181/200
# 511/511 - 0s - loss: 0.0476 - accuracy: 0.9809 - 440ms/epoch - 862us/step
# Epoch 182/200
# 511/511 - 0s - loss: 0.0485 - accuracy: 0.9815 - 436ms/epoch - 854us/step
# Epoch 183/200
# 511/511 - 0s - loss: 0.0437 - accuracy: 0.9829 - 451ms/epoch - 882us/step
# Epoch 184/200
# 511/511 - 0s - loss: 0.0454 - accuracy: 0.9825 - 437ms/epoch - 854us/step
# Epoch 185/200
# 511/511 - 0s - loss: 0.0455 - accuracy: 0.9821 - 442ms/epoch - 865us/step
# Epoch 186/200
# 511/511 - 0s - loss: 0.0498 - accuracy: 0.9800 - 440ms/epoch - 861us/step
# Epoch 187/200
# 511/511 - 0s - loss: 0.0471 - accuracy: 0.9818 - 429ms/epoch - 839us/step
# Epoch 188/200
# 511/511 - 0s - loss: 0.0413 - accuracy: 0.9834 - 440ms/epoch - 860us/step
# Epoch 189/200
# 511/511 - 0s - loss: 0.0400 - accuracy: 0.9850 - 444ms/epoch - 869us/step
# Epoch 190/200
# 511/511 - 0s - loss: 0.0399 - accuracy: 0.9848 - 445ms/epoch - 871us/step
# Epoch 191/200
# 511/511 - 0s - loss: 0.0428 - accuracy: 0.9828 - 444ms/epoch - 869us/step
# Epoch 192/200
# 511/511 - 0s - loss: 0.0515 - accuracy: 0.9801 - 448ms/epoch - 876us/step
# Epoch 193/200
# 511/511 - 0s - loss: 0.0390 - accuracy: 0.9848 - 449ms/epoch - 879us/step
# Epoch 194/200
# 511/511 - 0s - loss: 0.0344 - accuracy: 0.9870 - 476ms/epoch - 932us/step
# Epoch 195/200
# 511/511 - 0s - loss: 0.0502 - accuracy: 0.9804 - 436ms/epoch - 853us/step
# Epoch 196/200
# 511/511 - 0s - loss: 0.0345 - accuracy: 0.9867 - 444ms/epoch - 869us/step
# Epoch 197/200
# 511/511 - 0s - loss: 0.0581 - accuracy: 0.9776 - 448ms/epoch - 878us/step
# Epoch 198/200
# 511/511 - 0s - loss: 0.0351 - accuracy: 0.9854 - 442ms/epoch - 865us/step
# Epoch 199/200
# 511/511 - 0s - loss: 0.0370 - accuracy: 0.9854 - 431ms/epoch - 843us/step
# Epoch 200/200
# 511/511 - 0s - loss: 0.0455 - accuracy: 0.9824 - 434ms/epoch - 849us/step

# %%
#Saving model
model.save("main2classif", save_format='h5')

# %%
print("--Evaluate model--")
model_loss1, model_acc1 = model.evaluate(x_train,  y_train, verbose=2)
model_loss2, model_acc2 = model.evaluate(x_test,  y_test, verbose=2)
print(f"Train / Test Accuracy: {model_acc1*100:.1f}% / {model_acc2*100:.1f}%")
# Out:
# --Evaluate model--
# 511/511 - 0s - loss: 0.0388 - accuracy: 0.9850 - 398ms/epoch - 779us/step
# 128/128 - 0s - loss: 0.1961 - accuracy: 0.9513 - 86ms/epoch - 671us/step
# Train / Test Accuracy: 98.5% / 95.1%

# %% [markdown]
# Did more data cleaning to convert income to a categorical value at the top of the code.

# %%
# scatplot = sns.scatterplot(data=df, x = "median_income", y ="median_house_value")
# fig = scatplot.get_figure()
