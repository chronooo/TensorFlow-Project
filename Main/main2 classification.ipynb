# %%
#Main Project Stage 1: Data Science and Machine Learning
# Import the required libraries

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn
import tensorflow as tf

# Set sns theme to your preferred color palette
sns.set_theme(palette = "mako")

data = pd.read_csv('data/data-input.csv')  # read csv file
data.to_csv("data/data.csv",index=False)
#data input is the data that I had previously cleaned before starting the assignment
data = pd.read_csv("data/data.csv") #pretty confused as to why the instructions ask for this, but I guess its not a big deal

df = data.copy()  # create a copy to use for future reference, so I have a copy of my original dataset when needed

data.head()
#Cleaned data (now called data-input.csv) by hand beforehand before reading instructions, so my data is already good.
#Will be skipping the pandas clean data step
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
#Histogram showing distribution of housing age in the market
agehist = sns.histplot(data=df, x = "housing_median_age")
fig = agehist.get_figure()
fig.savefig("plots/plot1.png")

# %%
#Visualization of relationship (and variation) in housing price based on its age
age_value_lineplot = sns.lineplot(data=df, x = "housing_median_age", y = "median_house_value")
fig = age_value_lineplot.get_figure()
fig.savefig("plots/plot2.png")

# %%
#Visualization of price distribution of houses in california
house_value_histplot = sns.histplot(data=df, x = "median_house_value")
fig = house_value_histplot.get_figure()
fig.savefig("plots/plot3.png") 
#Can see from output that a majority of the houses are from 150k to 250k

# %% [markdown]
# Where the data came from.:
#
# https://www.kaggle.com/datasets/kathuman/housing
# I will be using the dataset on Housing Prices in California found on Kaggle with a creative Commons Public Domain License
# Description of data from creator:
# "This dataset is based on data from the 1990 California Census, and incluides metrics such as the population, median income, and median housing proice for each block group in California.
# Block groups are the smallest geographical unit for which the US Census Bureau publishes sample data., and each block typically has between 600 to 3000 people."
#
# The goal I have with this dataset is to be able to get my model to guess the price of houses given all the other information.
#
#
# Challenges cleaning:
#
# One of the challenges I had cleaning was that the dataset was humongous (22k rows) so I worried that I missed some stuff while cleaning but overall it was pretty straightforward. I cleaned it by hand before starting the assignment, and the biggest issue was that there was a lot of data to delete by hand. There was a lot of cells that just had nothing inside it, so I had to delete the entire line, which meant I couldnt automate it with find and replace. But other than that, the data seems pretty clean, and there are some spots in the data that I might need to go back and change, but for now I think the data looks reliable, based on the distribution I've seen from my graphs.
#
# Three visualizations:
#
# plot1 is a distribution of the age of the house. We can see that california has a wide range of ages for their houses. But their seems to be a spike in houses that are around 20, 30, and 50+ years old. Overall I think the distribution in that column is pretty good, and should pose no issues in training my model.
#
# plot2 is a visualization of relationship (and variation) in housing price based on its age. One thing that bothered me in this, is that from the graph, the house prices seem to very a lot for some age groups, specifically ~10 years old and ~50 years old. I worry that this will have negative effects in the model, but at the same time, logically speaking this is a realistic scenario. As old houses that are still standing are likely to be very nice to begin with, and new houses that are being built are being built for many different types of people with different incomes, especially in california where there is a large amount of wealthy and average people concentrated in one area.
#
# plot3 is a visualization of price distribution of houses in california. I wanted to see where the price of houses was concentrated, this graph allowed me to see that a majority of the houses in california in the dataset are around $150k-250k. But there is also a sizeable amount of houses below and above that number. Which should pose as good variation to give model a wide range of information to make accurate estimates.
#
# Part 2 code begins after this report
# --

# %%
df.shape  # Will return the number of rows and columns
# Out:
# (20433, 10)

# %%
df.info()  # Will inform you of the datatype of each variable, as well as if there are any null or missing values in each column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20433 entries, 0 to 20432
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
df.describe().T # Describe the data-frame (transposed) - defaults to describing only numerical
# If you want to describe all, run the following command:
# data.describe(include = "all").T
# Out:
#                       count           mean            std         min  \
# longitude           20433.0    -119.570689       2.003578   -124.3500
# latitude            20433.0      35.633221       2.136348     32.5400
# housing_median_age  20433.0      28.633094      12.591805      1.0000
# total_rooms         20433.0    2636.504233    2185.269567      2.0000
# total_bedrooms      20433.0     537.870553     421.385070      1.0000
# population          20433.0    1424.946949    1133.208490      3.0000
# households          20433.0     499.433465     382.299226      1.0000
# median_income       20433.0       3.871162       1.899291      0.4999
# median_house_value  20433.0  206864.413155  115435.667099  14999.0000
#
#                             25%          50%         75%          max
# longitude             -121.8000    -118.4900    -118.010    -114.3100
# latitude                33.9300      34.2600      37.720      41.9500
# housing_median_age      18.0000      29.0000      37.000      52.0000
# total_rooms           1450.0000    2127.0000    3143.000   39320.0000
# total_bedrooms         296.0000     435.0000     647.000    6445.0000
# population             787.0000    1166.0000    1722.000   35682.0000
# households             280.0000     409.0000     604.000    6082.0000
# median_income            2.5637       3.5365       4.744      15.0001
# median_house_value  119500.0000  179700.0000  264700.000  500001.0000

# %%
df.isnull().sum()  # Checking for null values
# In this case there are no null values. If there are some, you can use a heatmap to visualize them if you want.
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
#Organizing categorical data
#Citation is from Joweria's heartdisease tutorial notebook
from pandas.core.arrays import categorical 
#my df is joweria data, my df is joweria data
categorical_data = ["ocean_proximity"]

codes = {}  # Create a dictionary to store the codes of the conversion
for i in df:  # For each variable in the data frame 
  if i in categorical_data:  # For each variable that was classified as categorical
    specific_codes = {}  # Create a dictionary for that variable's code conversion 
    df[i] = df[i].astype("category")  # Convert that variable from 'object' datatype to category
    df[i] = df[i].cat.codes  # Create codes for the categories and replace in the dataset 
    coded = df[i].unique()  # Get the unique values (the codes) from the variable
    count = 0  # Count initialized. Later used for accessing specific indexes
    for j in data[i].unique():  # For each unique value
      specific_codes[j] = coded[count]  # Create an item in the dictionary with the value, and tell it which code correlates
      count += 1  # Count incremented
    codes[i] = specific_codes  # Create a new item in the overall dictionary with the dictionary created for this specific variable's codes


# View our created dictionary:
for i in codes:
  print("{} -".format(i))
  for j in codes[i]:
    print("{}: {}".format(j, codes[i][j]))
  print()
# Out:
# ocean_proximity -
# NEAR BAY: 3
# <1H OCEAN: 0
# INLAND: 1
# NEAR OCEAN: 4
# ISLAND: 2

# %%
df.head()
#Checking that data is no longer categorical and now an integer at the end
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value  ocean_proximity
# 0       322.0       126.0         8.3252            452600.0                3
# 1      2401.0      1138.0         8.3014            358500.0                3
# 2       496.0       177.0         7.2574            352100.0                3
# 3       558.0       219.0         5.6431            341300.0                3
# 4       565.0       259.0         3.8462            342200.0                3

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler
fs_data = df.copy() # copy of dataset for feature selection
x = fs_data.iloc[:,[0,1,2,3,4,5,6,7,8]]  # independent variables
y = fs_data.iloc[:,[9]]    # target column / what we're trying to predict


#https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html
#Found this easy way to split training data in the scikit documentation
#Shuffles data, and allocated 80% of it to be used for training, and 20% of it to be used for testing
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2) # splitting up dataset to training and testing

scl = RobustScaler() # Preprocess numerical data 
x_train = scl.fit_transform(x_train) 
x_test = scl.transform(x_test)

# %%
#x_train.head()

# %%
normalizer = tf.keras.layers.Normalization(axis=-1)
normalizer.adapt(x_train)
print(normalizer.mean.numpy())
# Out:
# [[-0.28310058  0.36206245 -0.02151823  0.29972208  0.29289487  0.27962747
#    0.27492422  0.15071051  0.19050756]]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Flatten


print("--Make model--")
model = tf.keras.models.Sequential([
  normalizer,
  tf.keras.layers.Dense(64, activation='relu'),
  tf.keras.layers.Dense(64, activation='relu'),
  tf.keras.layers.Dense(64, activation='relu'),
  tf.keras.layers.Dense(64, activation='relu'),
  tf.keras.layers.Dense(10, activation='softmax'),
])
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

print("--Fit model--")
model.fit(x_train, y_train, epochs=200, verbose=2)
# Out:
# --Make model--
# --Fit model--
# Epoch 1/200
# 511/511 - 1s - loss: 0.6705 - accuracy: 0.7524 - 687ms/epoch - 1ms/step
# Epoch 2/200
# 511/511 - 0s - loss: 0.3666 - accuracy: 0.8503 - 432ms/epoch - 846us/step
# Epoch 3/200
# 511/511 - 0s - loss: 0.3101 - accuracy: 0.8728 - 420ms/epoch - 823us/step
# Epoch 4/200
# 511/511 - 0s - loss: 0.2624 - accuracy: 0.8918 - 425ms/epoch - 832us/step
# Epoch 5/200
# 511/511 - 0s - loss: 0.2440 - accuracy: 0.8991 - 428ms/epoch - 838us/step
# Epoch 6/200
# 511/511 - 0s - loss: 0.2194 - accuracy: 0.9097 - 424ms/epoch - 831us/step
# Epoch 7/200
# 511/511 - 0s - loss: 0.2088 - accuracy: 0.9107 - 453ms/epoch - 886us/step
# Epoch 8/200
# 511/511 - 0s - loss: 0.2020 - accuracy: 0.9138 - 427ms/epoch - 835us/step
# Epoch 9/200
# 511/511 - 0s - loss: 0.1911 - accuracy: 0.9196 - 423ms/epoch - 827us/step
# Epoch 10/200
# 511/511 - 0s - loss: 0.1866 - accuracy: 0.9196 - 421ms/epoch - 824us/step
# Epoch 11/200
# 511/511 - 0s - loss: 0.1778 - accuracy: 0.9249 - 423ms/epoch - 829us/step
# Epoch 12/200
# 511/511 - 0s - loss: 0.1745 - accuracy: 0.9266 - 429ms/epoch - 839us/step
# Epoch 13/200
# 511/511 - 0s - loss: 0.1695 - accuracy: 0.9270 - 425ms/epoch - 831us/step
# Epoch 14/200
# 511/511 - 0s - loss: 0.1682 - accuracy: 0.9291 - 423ms/epoch - 828us/step
# Epoch 15/200
# 511/511 - 0s - loss: 0.1638 - accuracy: 0.9317 - 418ms/epoch - 818us/step
# Epoch 16/200
# 511/511 - 0s - loss: 0.1695 - accuracy: 0.9276 - 422ms/epoch - 827us/step
# Epoch 17/200
# 511/511 - 0s - loss: 0.1553 - accuracy: 0.9337 - 427ms/epoch - 835us/step
# Epoch 18/200
# 511/511 - 0s - loss: 0.1567 - accuracy: 0.9329 - 423ms/epoch - 827us/step
# Epoch 19/200
# 511/511 - 0s - loss: 0.1470 - accuracy: 0.9373 - 421ms/epoch - 824us/step
# Epoch 20/200
# 511/511 - 0s - loss: 0.1480 - accuracy: 0.9368 - 421ms/epoch - 823us/step
# Epoch 21/200
# 511/511 - 0s - loss: 0.1419 - accuracy: 0.9391 - 427ms/epoch - 837us/step
# Epoch 22/200
# 511/511 - 0s - loss: 0.1402 - accuracy: 0.9395 - 429ms/epoch - 840us/step
# Epoch 23/200
# 511/511 - 0s - loss: 0.1395 - accuracy: 0.9410 - 424ms/epoch - 829us/step
# Epoch 24/200
# 511/511 - 0s - loss: 0.1375 - accuracy: 0.9399 - 417ms/epoch - 817us/step
# Epoch 25/200
# 511/511 - 0s - loss: 0.1417 - accuracy: 0.9389 - 423ms/epoch - 828us/step
# Epoch 26/200
# 511/511 - 0s - loss: 0.1331 - accuracy: 0.9433 - 416ms/epoch - 815us/step
# Epoch 27/200
# 511/511 - 0s - loss: 0.1338 - accuracy: 0.9418 - 420ms/epoch - 822us/step
# Epoch 28/200
# 511/511 - 0s - loss: 0.1313 - accuracy: 0.9438 - 431ms/epoch - 843us/step
# Epoch 29/200
# 511/511 - 0s - loss: 0.1273 - accuracy: 0.9460 - 426ms/epoch - 833us/step
# Epoch 30/200
# 511/511 - 0s - loss: 0.1304 - accuracy: 0.9452 - 430ms/epoch - 841us/step
# Epoch 31/200
# 511/511 - 0s - loss: 0.1258 - accuracy: 0.9463 - 422ms/epoch - 825us/step
# Epoch 32/200
# 511/511 - 0s - loss: 0.1216 - accuracy: 0.9478 - 437ms/epoch - 855us/step
# Epoch 33/200
# 511/511 - 0s - loss: 0.1252 - accuracy: 0.9468 - 430ms/epoch - 841us/step
# Epoch 34/200
# 511/511 - 0s - loss: 0.1232 - accuracy: 0.9474 - 462ms/epoch - 904us/step
# Epoch 35/200
# 511/511 - 0s - loss: 0.1194 - accuracy: 0.9482 - 460ms/epoch - 900us/step
# Epoch 36/200
# 511/511 - 0s - loss: 0.1221 - accuracy: 0.9486 - 457ms/epoch - 895us/step
# Epoch 37/200
# 511/511 - 0s - loss: 0.1187 - accuracy: 0.9500 - 438ms/epoch - 858us/step
# Epoch 38/200
# 511/511 - 0s - loss: 0.1160 - accuracy: 0.9492 - 425ms/epoch - 832us/step
# Epoch 39/200
# 511/511 - 0s - loss: 0.1171 - accuracy: 0.9515 - 424ms/epoch - 829us/step
# Epoch 40/200
# 511/511 - 0s - loss: 0.1136 - accuracy: 0.9518 - 427ms/epoch - 835us/step
# Epoch 41/200
# 511/511 - 0s - loss: 0.1152 - accuracy: 0.9495 - 424ms/epoch - 830us/step
# Epoch 42/200
# 511/511 - 0s - loss: 0.1071 - accuracy: 0.9547 - 421ms/epoch - 824us/step
# Epoch 43/200
# 511/511 - 0s - loss: 0.1130 - accuracy: 0.9515 - 421ms/epoch - 825us/step
# Epoch 44/200
# 511/511 - 0s - loss: 0.1136 - accuracy: 0.9516 - 426ms/epoch - 834us/step
# Epoch 45/200
# 511/511 - 0s - loss: 0.1124 - accuracy: 0.9526 - 426ms/epoch - 833us/step
# Epoch 46/200
# 511/511 - 0s - loss: 0.1077 - accuracy: 0.9533 - 426ms/epoch - 833us/step
# Epoch 47/200
# 511/511 - 0s - loss: 0.1064 - accuracy: 0.9545 - 426ms/epoch - 834us/step
# Epoch 48/200
# 511/511 - 0s - loss: 0.1064 - accuracy: 0.9541 - 430ms/epoch - 841us/step
# Epoch 49/200
# 511/511 - 0s - loss: 0.1087 - accuracy: 0.9540 - 431ms/epoch - 843us/step
# Epoch 50/200
# 511/511 - 0s - loss: 0.1016 - accuracy: 0.9556 - 421ms/epoch - 823us/step
# Epoch 51/200
# 511/511 - 0s - loss: 0.1027 - accuracy: 0.9553 - 428ms/epoch - 837us/step
# Epoch 52/200
# 511/511 - 0s - loss: 0.0994 - accuracy: 0.9568 - 425ms/epoch - 831us/step
# Epoch 53/200
# 511/511 - 0s - loss: 0.1062 - accuracy: 0.9549 - 419ms/epoch - 820us/step
# Epoch 54/200
# 511/511 - 0s - loss: 0.0973 - accuracy: 0.9583 - 422ms/epoch - 826us/step
# Epoch 55/200
# 511/511 - 0s - loss: 0.1000 - accuracy: 0.9570 - 425ms/epoch - 832us/step
# Epoch 56/200
# 511/511 - 0s - loss: 0.0949 - accuracy: 0.9604 - 427ms/epoch - 835us/step
# Epoch 57/200
# 511/511 - 0s - loss: 0.1006 - accuracy: 0.9573 - 417ms/epoch - 816us/step
# Epoch 58/200
# 511/511 - 0s - loss: 0.0961 - accuracy: 0.9586 - 426ms/epoch - 834us/step
# Epoch 59/200
# 511/511 - 0s - loss: 0.0993 - accuracy: 0.9571 - 424ms/epoch - 830us/step
# Epoch 60/200
# 511/511 - 0s - loss: 0.0990 - accuracy: 0.9582 - 429ms/epoch - 839us/step
# Epoch 61/200
# 511/511 - 0s - loss: 0.0937 - accuracy: 0.9601 - 428ms/epoch - 838us/step
# Epoch 62/200
# 511/511 - 0s - loss: 0.0931 - accuracy: 0.9615 - 423ms/epoch - 827us/step
# Epoch 63/200
# 511/511 - 0s - loss: 0.0958 - accuracy: 0.9613 - 427ms/epoch - 835us/step
# Epoch 64/200
# 511/511 - 0s - loss: 0.0930 - accuracy: 0.9609 - 430ms/epoch - 841us/step
# Epoch 65/200
# 511/511 - 0s - loss: 0.0901 - accuracy: 0.9601 - 423ms/epoch - 828us/step
# Epoch 66/200
# 511/511 - 0s - loss: 0.0878 - accuracy: 0.9633 - 425ms/epoch - 832us/step
# Epoch 67/200
# 511/511 - 0s - loss: 0.0872 - accuracy: 0.9638 - 430ms/epoch - 841us/step
# Epoch 68/200
# 511/511 - 0s - loss: 0.0899 - accuracy: 0.9630 - 424ms/epoch - 830us/step
# Epoch 69/200
# 511/511 - 0s - loss: 0.0917 - accuracy: 0.9597 - 423ms/epoch - 828us/step
# Epoch 70/200
# 511/511 - 0s - loss: 0.0869 - accuracy: 0.9646 - 427ms/epoch - 835us/step
# Epoch 71/200
# 511/511 - 0s - loss: 0.0865 - accuracy: 0.9632 - 427ms/epoch - 836us/step
# Epoch 72/200
# 511/511 - 0s - loss: 0.0841 - accuracy: 0.9648 - 425ms/epoch - 831us/step
# Epoch 73/200
# 511/511 - 0s - loss: 0.0837 - accuracy: 0.9648 - 428ms/epoch - 837us/step
# Epoch 74/200
# 511/511 - 0s - loss: 0.0902 - accuracy: 0.9638 - 430ms/epoch - 842us/step
# Epoch 75/200
# 511/511 - 0s - loss: 0.0773 - accuracy: 0.9695 - 422ms/epoch - 826us/step
# Epoch 76/200
# 511/511 - 0s - loss: 0.0808 - accuracy: 0.9671 - 425ms/epoch - 831us/step
# Epoch 77/200
# 511/511 - 0s - loss: 0.0822 - accuracy: 0.9648 - 423ms/epoch - 827us/step
# Epoch 78/200
# 511/511 - 0s - loss: 0.0919 - accuracy: 0.9620 - 424ms/epoch - 829us/step
# Epoch 79/200
# 511/511 - 0s - loss: 0.0825 - accuracy: 0.9651 - 434ms/epoch - 849us/step
# Epoch 80/200
# 511/511 - 0s - loss: 0.0836 - accuracy: 0.9652 - 420ms/epoch - 823us/step
# Epoch 81/200
# 511/511 - 0s - loss: 0.0836 - accuracy: 0.9653 - 425ms/epoch - 832us/step
# Epoch 82/200
# 511/511 - 0s - loss: 0.0805 - accuracy: 0.9676 - 428ms/epoch - 837us/step
# Epoch 83/200
# 511/511 - 0s - loss: 0.0800 - accuracy: 0.9687 - 424ms/epoch - 830us/step
# Epoch 84/200
# 511/511 - 0s - loss: 0.0902 - accuracy: 0.9628 - 424ms/epoch - 830us/step
# Epoch 85/200
# 511/511 - 0s - loss: 0.0757 - accuracy: 0.9696 - 429ms/epoch - 839us/step
# Epoch 86/200
# 511/511 - 0s - loss: 0.0780 - accuracy: 0.9678 - 424ms/epoch - 829us/step
# Epoch 87/200
# 511/511 - 0s - loss: 0.0787 - accuracy: 0.9686 - 427ms/epoch - 835us/step
# Epoch 88/200
# 511/511 - 0s - loss: 0.0751 - accuracy: 0.9690 - 421ms/epoch - 824us/step
# Epoch 89/200
# 511/511 - 0s - loss: 0.0773 - accuracy: 0.9660 - 422ms/epoch - 826us/step
# Epoch 90/200
# 511/511 - 0s - loss: 0.0811 - accuracy: 0.9668 - 423ms/epoch - 828us/step
# Epoch 91/200
# 511/511 - 0s - loss: 0.0762 - accuracy: 0.9696 - 433ms/epoch - 847us/step
# Epoch 92/200
# 511/511 - 0s - loss: 0.0773 - accuracy: 0.9674 - 424ms/epoch - 829us/step
# Epoch 93/200
# 511/511 - 0s - loss: 0.0697 - accuracy: 0.9723 - 421ms/epoch - 824us/step
# Epoch 94/200
# 511/511 - 0s - loss: 0.0765 - accuracy: 0.9685 - 429ms/epoch - 839us/step
# Epoch 95/200
# 511/511 - 0s - loss: 0.0708 - accuracy: 0.9706 - 425ms/epoch - 831us/step
# Epoch 96/200
# 511/511 - 0s - loss: 0.0808 - accuracy: 0.9682 - 429ms/epoch - 839us/step
# Epoch 97/200
# 511/511 - 0s - loss: 0.0759 - accuracy: 0.9700 - 416ms/epoch - 815us/step
# Epoch 98/200
# 511/511 - 0s - loss: 0.0711 - accuracy: 0.9717 - 432ms/epoch - 846us/step
# Epoch 99/200
# 511/511 - 0s - loss: 0.0708 - accuracy: 0.9717 - 427ms/epoch - 836us/step
# Epoch 100/200
# 511/511 - 0s - loss: 0.0715 - accuracy: 0.9703 - 426ms/epoch - 833us/step
# Epoch 101/200
# 511/511 - 0s - loss: 0.0737 - accuracy: 0.9719 - 426ms/epoch - 834us/step
# Epoch 102/200
# 511/511 - 0s - loss: 0.0767 - accuracy: 0.9699 - 422ms/epoch - 825us/step
# Epoch 103/200
# 511/511 - 0s - loss: 0.0678 - accuracy: 0.9712 - 429ms/epoch - 839us/step
# Epoch 104/200
# 511/511 - 0s - loss: 0.0676 - accuracy: 0.9715 - 425ms/epoch - 832us/step
# Epoch 105/200
# 511/511 - 0s - loss: 0.0720 - accuracy: 0.9694 - 426ms/epoch - 834us/step
# Epoch 106/200
# 511/511 - 0s - loss: 0.0663 - accuracy: 0.9726 - 428ms/epoch - 837us/step
# Epoch 107/200
# 511/511 - 0s - loss: 0.0672 - accuracy: 0.9726 - 428ms/epoch - 837us/step
# Epoch 108/200
# 511/511 - 0s - loss: 0.0665 - accuracy: 0.9725 - 433ms/epoch - 847us/step
# Epoch 109/200
# 511/511 - 0s - loss: 0.0665 - accuracy: 0.9723 - 427ms/epoch - 836us/step
# Epoch 110/200
# 511/511 - 0s - loss: 0.0717 - accuracy: 0.9717 - 421ms/epoch - 824us/step
# Epoch 111/200
# 511/511 - 0s - loss: 0.0642 - accuracy: 0.9733 - 423ms/epoch - 827us/step
# Epoch 112/200
# 511/511 - 0s - loss: 0.0662 - accuracy: 0.9730 - 430ms/epoch - 842us/step
# Epoch 113/200
# 511/511 - 0s - loss: 0.0658 - accuracy: 0.9729 - 447ms/epoch - 874us/step
# Epoch 114/200
# 511/511 - 0s - loss: 0.0689 - accuracy: 0.9723 - 431ms/epoch - 843us/step
# Epoch 115/200
# 511/511 - 0s - loss: 0.0673 - accuracy: 0.9730 - 429ms/epoch - 839us/step
# Epoch 116/200
# 511/511 - 0s - loss: 0.0586 - accuracy: 0.9764 - 429ms/epoch - 840us/step
# Epoch 117/200
# 511/511 - 0s - loss: 0.0657 - accuracy: 0.9749 - 430ms/epoch - 841us/step
# Epoch 118/200
# 511/511 - 0s - loss: 0.0677 - accuracy: 0.9739 - 425ms/epoch - 831us/step
# Epoch 119/200
# 511/511 - 0s - loss: 0.0602 - accuracy: 0.9769 - 426ms/epoch - 833us/step
# Epoch 120/200
# 511/511 - 0s - loss: 0.0646 - accuracy: 0.9744 - 430ms/epoch - 841us/step
# Epoch 121/200
# 511/511 - 0s - loss: 0.0633 - accuracy: 0.9735 - 424ms/epoch - 830us/step
# Epoch 122/200
# 511/511 - 0s - loss: 0.0594 - accuracy: 0.9774 - 425ms/epoch - 831us/step
# Epoch 123/200
# 511/511 - 0s - loss: 0.0587 - accuracy: 0.9772 - 425ms/epoch - 831us/step
# Epoch 124/200
# 511/511 - 0s - loss: 0.0583 - accuracy: 0.9770 - 431ms/epoch - 843us/step
# Epoch 125/200
# 511/511 - 0s - loss: 0.0647 - accuracy: 0.9736 - 422ms/epoch - 826us/step
# Epoch 126/200
# 511/511 - 0s - loss: 0.0607 - accuracy: 0.9757 - 422ms/epoch - 826us/step
# Epoch 127/200
# 511/511 - 0s - loss: 0.0590 - accuracy: 0.9760 - 421ms/epoch - 823us/step
# Epoch 128/200
# 511/511 - 0s - loss: 0.0609 - accuracy: 0.9749 - 419ms/epoch - 819us/step
# Epoch 129/200
# 511/511 - 0s - loss: 0.0577 - accuracy: 0.9769 - 428ms/epoch - 838us/step
# Epoch 130/200
# 511/511 - 0s - loss: 0.0625 - accuracy: 0.9753 - 428ms/epoch - 838us/step
# Epoch 131/200
# 511/511 - 0s - loss: 0.0607 - accuracy: 0.9749 - 429ms/epoch - 839us/step
# Epoch 132/200
# 511/511 - 0s - loss: 0.0568 - accuracy: 0.9766 - 428ms/epoch - 837us/step
# Epoch 133/200
# 511/511 - 0s - loss: 0.0576 - accuracy: 0.9769 - 424ms/epoch - 829us/step
# Epoch 134/200
# 511/511 - 0s - loss: 0.0543 - accuracy: 0.9771 - 418ms/epoch - 819us/step
# Epoch 135/200
# 511/511 - 0s - loss: 0.0659 - accuracy: 0.9747 - 425ms/epoch - 833us/step
# Epoch 136/200
# 511/511 - 0s - loss: 0.0571 - accuracy: 0.9769 - 431ms/epoch - 843us/step
# Epoch 137/200
# 511/511 - 0s - loss: 0.0562 - accuracy: 0.9768 - 430ms/epoch - 842us/step
# Epoch 138/200
# 511/511 - 0s - loss: 0.0600 - accuracy: 0.9764 - 426ms/epoch - 834us/step
# Epoch 139/200
# 511/511 - 0s - loss: 0.0582 - accuracy: 0.9768 - 429ms/epoch - 839us/step
# Epoch 140/200
# 511/511 - 0s - loss: 0.0507 - accuracy: 0.9802 - 427ms/epoch - 836us/step
# Epoch 141/200
# 511/511 - 0s - loss: 0.0618 - accuracy: 0.9759 - 422ms/epoch - 825us/step
# Epoch 142/200
# 511/511 - 0s - loss: 0.0544 - accuracy: 0.9777 - 421ms/epoch - 823us/step
# Epoch 143/200
# 511/511 - 0s - loss: 0.0512 - accuracy: 0.9798 - 424ms/epoch - 830us/step
# Epoch 144/200
# 511/511 - 0s - loss: 0.0553 - accuracy: 0.9783 - 427ms/epoch - 835us/step
# Epoch 145/200
# 511/511 - 0s - loss: 0.0518 - accuracy: 0.9801 - 425ms/epoch - 831us/step
# Epoch 146/200
# 511/511 - 0s - loss: 0.0514 - accuracy: 0.9791 - 423ms/epoch - 827us/step
# Epoch 147/200
# 511/511 - 0s - loss: 0.0521 - accuracy: 0.9793 - 428ms/epoch - 837us/step
# Epoch 148/200
# 511/511 - 0s - loss: 0.0602 - accuracy: 0.9761 - 421ms/epoch - 823us/step
# Epoch 149/200
# 511/511 - 0s - loss: 0.0577 - accuracy: 0.9785 - 425ms/epoch - 831us/step
# Epoch 150/200
# 511/511 - 0s - loss: 0.0504 - accuracy: 0.9799 - 422ms/epoch - 825us/step
# Epoch 151/200
# 511/511 - 0s - loss: 0.0528 - accuracy: 0.9790 - 420ms/epoch - 823us/step
# Epoch 152/200
# 511/511 - 0s - loss: 0.0506 - accuracy: 0.9796 - 425ms/epoch - 832us/step
# Epoch 153/200
# 511/511 - 0s - loss: 0.0537 - accuracy: 0.9790 - 424ms/epoch - 830us/step
# Epoch 154/200
# 511/511 - 0s - loss: 0.0472 - accuracy: 0.9803 - 423ms/epoch - 827us/step
# Epoch 155/200
# 511/511 - 0s - loss: 0.0494 - accuracy: 0.9805 - 420ms/epoch - 822us/step
# Epoch 156/200
# 511/511 - 0s - loss: 0.0516 - accuracy: 0.9795 - 416ms/epoch - 815us/step
# Epoch 157/200
# 511/511 - 0s - loss: 0.0545 - accuracy: 0.9774 - 424ms/epoch - 829us/step
# Epoch 158/200
# 511/511 - 0s - loss: 0.0537 - accuracy: 0.9793 - 425ms/epoch - 832us/step
# Epoch 159/200
# 511/511 - 0s - loss: 0.0515 - accuracy: 0.9807 - 422ms/epoch - 827us/step
# Epoch 160/200
# 511/511 - 0s - loss: 0.0504 - accuracy: 0.9793 - 430ms/epoch - 841us/step
# Epoch 161/200
# 511/511 - 0s - loss: 0.0547 - accuracy: 0.9785 - 424ms/epoch - 830us/step
# Epoch 162/200
# 511/511 - 0s - loss: 0.0481 - accuracy: 0.9813 - 422ms/epoch - 827us/step
# Epoch 163/200
# 511/511 - 0s - loss: 0.0442 - accuracy: 0.9813 - 423ms/epoch - 828us/step
# Epoch 164/200
# 511/511 - 0s - loss: 0.0493 - accuracy: 0.9806 - 424ms/epoch - 830us/step
# Epoch 165/200
# 511/511 - 0s - loss: 0.0513 - accuracy: 0.9801 - 445ms/epoch - 871us/step
# Epoch 166/200
# 511/511 - 0s - loss: 0.0549 - accuracy: 0.9780 - 434ms/epoch - 848us/step
# Epoch 167/200
# 511/511 - 0s - loss: 0.0590 - accuracy: 0.9778 - 426ms/epoch - 833us/step
# Epoch 168/200
# 511/511 - 0s - loss: 0.0442 - accuracy: 0.9824 - 429ms/epoch - 840us/step
# Epoch 169/200
# 511/511 - 0s - loss: 0.0444 - accuracy: 0.9823 - 420ms/epoch - 822us/step
# Epoch 170/200
# 511/511 - 0s - loss: 0.0524 - accuracy: 0.9801 - 432ms/epoch - 846us/step
# Epoch 171/200
# 511/511 - 0s - loss: 0.0430 - accuracy: 0.9833 - 427ms/epoch - 836us/step
# Epoch 172/200
# 511/511 - 0s - loss: 0.0510 - accuracy: 0.9801 - 423ms/epoch - 828us/step
# Epoch 173/200
# 511/511 - 0s - loss: 0.0468 - accuracy: 0.9813 - 429ms/epoch - 840us/step
# Epoch 174/200
# 511/511 - 0s - loss: 0.0501 - accuracy: 0.9812 - 431ms/epoch - 844us/step
# Epoch 175/200
# 511/511 - 0s - loss: 0.0508 - accuracy: 0.9802 - 423ms/epoch - 829us/step
# Epoch 176/200
# 511/511 - 0s - loss: 0.0500 - accuracy: 0.9796 - 421ms/epoch - 823us/step
# Epoch 177/200
# 511/511 - 0s - loss: 0.0457 - accuracy: 0.9806 - 452ms/epoch - 885us/step
# Epoch 178/200
# 511/511 - 0s - loss: 0.0479 - accuracy: 0.9816 - 423ms/epoch - 829us/step
# Epoch 179/200
# 511/511 - 0s - loss: 0.0531 - accuracy: 0.9798 - 423ms/epoch - 827us/step
# Epoch 180/200
# 511/511 - 0s - loss: 0.0384 - accuracy: 0.9840 - 429ms/epoch - 840us/step
# Epoch 181/200
# 511/511 - 0s - loss: 0.0515 - accuracy: 0.9813 - 428ms/epoch - 837us/step
# Epoch 182/200
# 511/511 - 0s - loss: 0.0399 - accuracy: 0.9843 - 428ms/epoch - 837us/step
# Epoch 183/200
# 511/511 - 0s - loss: 0.0468 - accuracy: 0.9825 - 430ms/epoch - 841us/step
# Epoch 184/200
# 511/511 - 0s - loss: 0.0492 - accuracy: 0.9816 - 426ms/epoch - 833us/step
# Epoch 185/200
# 511/511 - 0s - loss: 0.0432 - accuracy: 0.9832 - 420ms/epoch - 821us/step
# Epoch 186/200
# 511/511 - 0s - loss: 0.0374 - accuracy: 0.9857 - 424ms/epoch - 831us/step
# Epoch 187/200
# 511/511 - 0s - loss: 0.0488 - accuracy: 0.9817 - 427ms/epoch - 835us/step
# Epoch 188/200
# 511/511 - 0s - loss: 0.0398 - accuracy: 0.9839 - 426ms/epoch - 833us/step
# Epoch 189/200
# 511/511 - 0s - loss: 0.0519 - accuracy: 0.9810 - 432ms/epoch - 846us/step
# Epoch 190/200
# 511/511 - 0s - loss: 0.0427 - accuracy: 0.9834 - 427ms/epoch - 836us/step
# Epoch 191/200
# 511/511 - 0s - loss: 0.0487 - accuracy: 0.9810 - 431ms/epoch - 843us/step
# Epoch 192/200
# 511/511 - 0s - loss: 0.0412 - accuracy: 0.9840 - 427ms/epoch - 835us/step
# Epoch 193/200
# 511/511 - 0s - loss: 0.0390 - accuracy: 0.9846 - 434ms/epoch - 849us/step
# Epoch 194/200
# 511/511 - 0s - loss: 0.0567 - accuracy: 0.9778 - 463ms/epoch - 906us/step
# Epoch 195/200
# 511/511 - 0s - loss: 0.0378 - accuracy: 0.9853 - 459ms/epoch - 899us/step
# Epoch 196/200
# 511/511 - 0s - loss: 0.0429 - accuracy: 0.9837 - 447ms/epoch - 875us/step
# Epoch 197/200
# 511/511 - 0s - loss: 0.0403 - accuracy: 0.9838 - 426ms/epoch - 833us/step
# Epoch 198/200
# 511/511 - 0s - loss: 0.0363 - accuracy: 0.9865 - 425ms/epoch - 831us/step
# Epoch 199/200
# 511/511 - 0s - loss: 0.0436 - accuracy: 0.9842 - 421ms/epoch - 824us/step
# Epoch 200/200
# 511/511 - 0s - loss: 0.0525 - accuracy: 0.9803 - 424ms/epoch - 829us/step

# %%
#Saving model
model.save("main2classif", save_format='h5')

# %%
print("--Evaluate model--")
model_loss1, model_acc1 = model.evaluate(x_train,  y_train, verbose=2)
model_loss2, model_acc2 = model.evaluate(x_test,  y_test, verbose=2)
print(f"Train / Test Accuracy: {model_acc1*100:.1f}% / {model_acc2*100:.1f}%")
# Out:
# --Evaluate model--
# 511/511 - 0s - loss: 0.0388 - accuracy: 0.9850 - 398ms/epoch - 779us/step
# 128/128 - 0s - loss: 0.1961 - accuracy: 0.9513 - 86ms/epoch - 671us/step
# Train / Test Accuracy: 98.5% / 95.1%

# %%
# scatplot = sns.scatterplot(data=df, x = "median_income", y ="median_house_value")
# fig = scatplot.get_figure()
