# %%
#Heart Data
# Import the required libraries

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn
import tensorflow as tf

# %%
#Basic setup
sns.set_theme(palette = "mako")

data = pd.read_csv('heart.csv')  # read csv file
data = data.drop(columns = ['row.names'], axis = 1)
df = data.copy()
data.head()
# Out:
#    sbp  tobacco   ldl  adiposity  famhist  typea  obesity  alcohol  age  chd
# 0  160    12.00  5.73      23.11  Present     49    25.30    97.20   52    1
# 1  144     0.01  4.41      28.61   Absent     55    28.87     2.06   63    1
# 2  118     0.08  3.48      32.28  Present     52    29.14     3.81   46    0
# 3  170     7.50  6.41      38.03  Present     51    31.99    24.26   58    1
# 4  134    13.60  3.50      27.78  Present     60    25.99    57.34   49    1

# %%
#Organizing categorical data
#Citation is from Joweria's heartdisease tutorial notebook
from pandas.core.arrays import categorical 
categorical_data = ["famhist"]

codes = {}  # Create a dictionary to store the codes of the conversion
for i in df:  # For each variable in the data frame 
  if i in categorical_data:  # For each variable that was classified as categorical
    specific_codes = {}  # Create a dictionary for that variable's code conversion 
    df[i] = df[i].astype("category")  # Convert that variable from 'object' datatype to category
    df[i] = df[i].cat.codes  # Create codes for the categories and replace in the dataset 
    coded = df[i].unique()  # Get the unique values (the codes) from the variable
    count = 0  # Count initialized. Later used for accessing specific indexes
    for j in data[i].unique():  # For each unique value
      specific_codes[j] = coded[count]  # Create an item in the dictionary with the value, and tell it which code correlates
      count += 1  # Count incremented
    codes[i] = specific_codes  # Create a new item in the overall dictionary with the dictionary created for this specific variable's codes


# View our created dictionary:
for i in codes:
  print("{} -".format(i))
  for j in codes[i]:
    print("{}: {}".format(j, codes[i][j]))
  print()
# Out:
# famhist -
# Present: 1
# Absent: 0

# %%
df.head() #checking that data is no longer text
# Out:
#    sbp  tobacco   ldl  adiposity  famhist  typea  obesity  alcohol  age  chd
# 0  160    12.00  5.73      23.11        1     49    25.30    97.20   52    1
# 1  144     0.01  4.41      28.61        0     55    28.87     2.06   63    1
# 2  118     0.08  3.48      32.28        1     52    29.14     3.81   46    0
# 3  170     7.50  6.41      38.03        1     51    31.99    24.26   58    1
# 4  134    13.60  3.50      27.78        1     60    25.99    57.34   49    1

# %%
df.isnull().sum()
# Out:
# sbp          0
# tobacco      0
# ldl          0
# adiposity    0
# famhist      0
# typea        0
# obesity      0
# alcohol      0
# age          0
# chd          0
# dtype: int64

# %%
from tensorflow.python.ops.gen_array_ops import prevent_gradient
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler
fs_data = df.copy() # copy of dataset for feature selection
x = fs_data.iloc[:,[0,1,2,3,4,5,6,7,8]]  # independent variables
y = fs_data.iloc[:,[9]]    # target column / what we're trying to predict


#https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html
#Found this easy way to split training data in the scikit documentation
#Shuffles data, and allocated 80% of it to be used for training, and 20% of it to be used for testing
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2) # splitting up dataset to training and testing
training = pd.concat([x_train,y_train], axis=1)
training.to_csv("heart_train.csv",index=False)
testing = pd.concat([x_test,y_test], axis=1)
testing.to_csv("heart_test.csv",index=False)

# %%
normalizer = tf.keras.layers.Normalization(axis=-1)
normalizer.adapt(x_train)

# %%
print("--Make model--")
model = tf.keras.models.Sequential([
  normalizer,
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dropout(0.4),
  tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

print("--Fit model--")
model.fit(x_train, y_train, epochs=200, verbose=2)
# Out:
# --Make model--
# --Fit model--
# Epoch 1/200
# 12/12 - 1s - loss: 0.7135 - accuracy: 0.4824 - 975ms/epoch - 81ms/step
# Epoch 2/200
# 12/12 - 0s - loss: 0.6352 - accuracy: 0.6341 - 35ms/epoch - 3ms/step
# Epoch 3/200
# 12/12 - 0s - loss: 0.5905 - accuracy: 0.7127 - 31ms/epoch - 3ms/step
# Epoch 4/200
# 12/12 - 0s - loss: 0.5696 - accuracy: 0.6992 - 37ms/epoch - 3ms/step
# Epoch 5/200
# 12/12 - 0s - loss: 0.5505 - accuracy: 0.7209 - 40ms/epoch - 3ms/step
# Epoch 6/200
# 12/12 - 0s - loss: 0.5429 - accuracy: 0.7182 - 31ms/epoch - 3ms/step
# Epoch 7/200
# 12/12 - 0s - loss: 0.5476 - accuracy: 0.7290 - 31ms/epoch - 3ms/step
# Epoch 8/200
# 12/12 - 0s - loss: 0.5368 - accuracy: 0.7236 - 35ms/epoch - 3ms/step
# Epoch 9/200
# 12/12 - 0s - loss: 0.5286 - accuracy: 0.7290 - 44ms/epoch - 4ms/step
# Epoch 10/200
# 12/12 - 0s - loss: 0.5276 - accuracy: 0.7100 - 44ms/epoch - 4ms/step
# Epoch 11/200
# 12/12 - 0s - loss: 0.5247 - accuracy: 0.7290 - 30ms/epoch - 2ms/step
# Epoch 12/200
# 12/12 - 0s - loss: 0.5212 - accuracy: 0.7344 - 33ms/epoch - 3ms/step
# Epoch 13/200
# 12/12 - 0s - loss: 0.5173 - accuracy: 0.7480 - 34ms/epoch - 3ms/step
# Epoch 14/200
# 12/12 - 0s - loss: 0.5133 - accuracy: 0.7534 - 28ms/epoch - 2ms/step
# Epoch 15/200
# 12/12 - 0s - loss: 0.5159 - accuracy: 0.7371 - 29ms/epoch - 2ms/step
# Epoch 16/200
# 12/12 - 0s - loss: 0.5209 - accuracy: 0.7371 - 32ms/epoch - 3ms/step
# Epoch 17/200
# 12/12 - 0s - loss: 0.5117 - accuracy: 0.7290 - 30ms/epoch - 2ms/step
# Epoch 18/200
# 12/12 - 0s - loss: 0.5069 - accuracy: 0.7453 - 36ms/epoch - 3ms/step
# Epoch 19/200
# 12/12 - 0s - loss: 0.5073 - accuracy: 0.7453 - 33ms/epoch - 3ms/step
# Epoch 20/200
# 12/12 - 0s - loss: 0.5112 - accuracy: 0.7398 - 29ms/epoch - 2ms/step
# Epoch 21/200
# 12/12 - 0s - loss: 0.5120 - accuracy: 0.7534 - 34ms/epoch - 3ms/step
# Epoch 22/200
# 12/12 - 0s - loss: 0.5044 - accuracy: 0.7398 - 29ms/epoch - 2ms/step
# Epoch 23/200
# 12/12 - 0s - loss: 0.5012 - accuracy: 0.7534 - 38ms/epoch - 3ms/step
# Epoch 24/200
# 12/12 - 0s - loss: 0.5027 - accuracy: 0.7642 - 35ms/epoch - 3ms/step
# Epoch 25/200
# 12/12 - 0s - loss: 0.5027 - accuracy: 0.7615 - 35ms/epoch - 3ms/step
# Epoch 26/200
# 12/12 - 0s - loss: 0.5041 - accuracy: 0.7561 - 31ms/epoch - 3ms/step
# Epoch 27/200
# 12/12 - 0s - loss: 0.4964 - accuracy: 0.7480 - 34ms/epoch - 3ms/step
# Epoch 28/200
# 12/12 - 0s - loss: 0.5007 - accuracy: 0.7561 - 35ms/epoch - 3ms/step
# Epoch 29/200
# 12/12 - 0s - loss: 0.5066 - accuracy: 0.7534 - 30ms/epoch - 3ms/step
# Epoch 30/200
# 12/12 - 0s - loss: 0.4917 - accuracy: 0.7534 - 33ms/epoch - 3ms/step
# Epoch 31/200
# 12/12 - 0s - loss: 0.4932 - accuracy: 0.7615 - 31ms/epoch - 3ms/step
# Epoch 32/200
# 12/12 - 0s - loss: 0.4941 - accuracy: 0.7507 - 29ms/epoch - 2ms/step
# Epoch 33/200
# 12/12 - 0s - loss: 0.4910 - accuracy: 0.7371 - 30ms/epoch - 2ms/step
# Epoch 34/200
# 12/12 - 0s - loss: 0.5002 - accuracy: 0.7507 - 32ms/epoch - 3ms/step
# Epoch 35/200
# 12/12 - 0s - loss: 0.5080 - accuracy: 0.7453 - 30ms/epoch - 2ms/step
# Epoch 36/200
# 12/12 - 0s - loss: 0.4889 - accuracy: 0.7751 - 27ms/epoch - 2ms/step
# Epoch 37/200
# 12/12 - 0s - loss: 0.4979 - accuracy: 0.7534 - 39ms/epoch - 3ms/step
# Epoch 38/200
# 12/12 - 0s - loss: 0.4759 - accuracy: 0.7751 - 33ms/epoch - 3ms/step
# Epoch 39/200
# 12/12 - 0s - loss: 0.4827 - accuracy: 0.7588 - 28ms/epoch - 2ms/step
# Epoch 40/200
# 12/12 - 0s - loss: 0.4970 - accuracy: 0.7561 - 32ms/epoch - 3ms/step
# Epoch 41/200
# 12/12 - 0s - loss: 0.4926 - accuracy: 0.7425 - 36ms/epoch - 3ms/step
# Epoch 42/200
# 12/12 - 0s - loss: 0.4922 - accuracy: 0.7507 - 31ms/epoch - 3ms/step
# Epoch 43/200
# 12/12 - 0s - loss: 0.4875 - accuracy: 0.7724 - 40ms/epoch - 3ms/step
# Epoch 44/200
# 12/12 - 0s - loss: 0.4918 - accuracy: 0.7615 - 30ms/epoch - 3ms/step
# Epoch 45/200
# 12/12 - 0s - loss: 0.4740 - accuracy: 0.7669 - 35ms/epoch - 3ms/step
# Epoch 46/200
# 12/12 - 0s - loss: 0.4893 - accuracy: 0.7425 - 29ms/epoch - 2ms/step
# Epoch 47/200
# 12/12 - 0s - loss: 0.4740 - accuracy: 0.7805 - 31ms/epoch - 3ms/step
# Epoch 48/200
# 12/12 - 0s - loss: 0.4781 - accuracy: 0.7724 - 32ms/epoch - 3ms/step
# Epoch 49/200
# 12/12 - 0s - loss: 0.4733 - accuracy: 0.7615 - 32ms/epoch - 3ms/step
# Epoch 50/200
# 12/12 - 0s - loss: 0.4908 - accuracy: 0.7669 - 36ms/epoch - 3ms/step
# Epoch 51/200
# 12/12 - 0s - loss: 0.4786 - accuracy: 0.7669 - 37ms/epoch - 3ms/step
# Epoch 52/200
# 12/12 - 0s - loss: 0.4730 - accuracy: 0.7724 - 34ms/epoch - 3ms/step
# Epoch 53/200
# 12/12 - 0s - loss: 0.4708 - accuracy: 0.7724 - 39ms/epoch - 3ms/step
# Epoch 54/200
# 12/12 - 0s - loss: 0.4831 - accuracy: 0.7696 - 32ms/epoch - 3ms/step
# Epoch 55/200
# 12/12 - 0s - loss: 0.4778 - accuracy: 0.7642 - 32ms/epoch - 3ms/step
# Epoch 56/200
# 12/12 - 0s - loss: 0.4706 - accuracy: 0.7751 - 36ms/epoch - 3ms/step
# Epoch 57/200
# 12/12 - 0s - loss: 0.4779 - accuracy: 0.7642 - 43ms/epoch - 4ms/step
# Epoch 58/200
# 12/12 - 0s - loss: 0.4659 - accuracy: 0.7778 - 30ms/epoch - 3ms/step
# Epoch 59/200
# 12/12 - 0s - loss: 0.4793 - accuracy: 0.7724 - 29ms/epoch - 2ms/step
# Epoch 60/200
# 12/12 - 0s - loss: 0.4659 - accuracy: 0.7832 - 29ms/epoch - 2ms/step
# Epoch 61/200
# 12/12 - 0s - loss: 0.4770 - accuracy: 0.7615 - 32ms/epoch - 3ms/step
# Epoch 62/200
# 12/12 - 0s - loss: 0.4597 - accuracy: 0.7778 - 35ms/epoch - 3ms/step
# Epoch 63/200
# 12/12 - 0s - loss: 0.4729 - accuracy: 0.7453 - 43ms/epoch - 4ms/step
# Epoch 64/200
# 12/12 - 0s - loss: 0.4571 - accuracy: 0.7913 - 33ms/epoch - 3ms/step
# Epoch 65/200
# 12/12 - 0s - loss: 0.4666 - accuracy: 0.7886 - 36ms/epoch - 3ms/step
# Epoch 66/200
# 12/12 - 0s - loss: 0.4603 - accuracy: 0.7805 - 46ms/epoch - 4ms/step
# Epoch 67/200
# 12/12 - 0s - loss: 0.4762 - accuracy: 0.7561 - 39ms/epoch - 3ms/step
# Epoch 68/200
# 12/12 - 0s - loss: 0.4698 - accuracy: 0.7669 - 40ms/epoch - 3ms/step
# Epoch 69/200
# 12/12 - 0s - loss: 0.4548 - accuracy: 0.7751 - 40ms/epoch - 3ms/step
# Epoch 70/200
# 12/12 - 0s - loss: 0.4723 - accuracy: 0.7669 - 44ms/epoch - 4ms/step
# Epoch 71/200
# 12/12 - 0s - loss: 0.4799 - accuracy: 0.7696 - 31ms/epoch - 3ms/step
# Epoch 72/200
# 12/12 - 0s - loss: 0.4751 - accuracy: 0.7724 - 29ms/epoch - 2ms/step
# Epoch 73/200
# 12/12 - 0s - loss: 0.4646 - accuracy: 0.7669 - 30ms/epoch - 2ms/step
# Epoch 74/200
# 12/12 - 0s - loss: 0.4616 - accuracy: 0.7642 - 31ms/epoch - 3ms/step
# Epoch 75/200
# 12/12 - 0s - loss: 0.4606 - accuracy: 0.7940 - 28ms/epoch - 2ms/step
# Epoch 76/200
# 12/12 - 0s - loss: 0.4666 - accuracy: 0.7669 - 29ms/epoch - 2ms/step
# Epoch 77/200
# 12/12 - 0s - loss: 0.4487 - accuracy: 0.7778 - 38ms/epoch - 3ms/step
# Epoch 78/200
# 12/12 - 0s - loss: 0.4595 - accuracy: 0.7724 - 35ms/epoch - 3ms/step
# Epoch 79/200
# 12/12 - 0s - loss: 0.4698 - accuracy: 0.7588 - 30ms/epoch - 3ms/step
# Epoch 80/200
# 12/12 - 0s - loss: 0.4604 - accuracy: 0.7669 - 37ms/epoch - 3ms/step
# Epoch 81/200
# 12/12 - 0s - loss: 0.4644 - accuracy: 0.7642 - 47ms/epoch - 4ms/step
# Epoch 82/200
# 12/12 - 0s - loss: 0.4632 - accuracy: 0.7778 - 36ms/epoch - 3ms/step
# Epoch 83/200
# 12/12 - 0s - loss: 0.4527 - accuracy: 0.7642 - 42ms/epoch - 4ms/step
# Epoch 84/200
# 12/12 - 0s - loss: 0.4675 - accuracy: 0.7859 - 34ms/epoch - 3ms/step
# Epoch 85/200
# 12/12 - 0s - loss: 0.4562 - accuracy: 0.7913 - 34ms/epoch - 3ms/step
# Epoch 86/200
# 12/12 - 0s - loss: 0.4546 - accuracy: 0.7886 - 36ms/epoch - 3ms/step
# Epoch 87/200
# 12/12 - 0s - loss: 0.4540 - accuracy: 0.7886 - 45ms/epoch - 4ms/step
# Epoch 88/200
# 12/12 - 0s - loss: 0.4487 - accuracy: 0.7832 - 29ms/epoch - 2ms/step
# Epoch 89/200
# 12/12 - 0s - loss: 0.4551 - accuracy: 0.7751 - 33ms/epoch - 3ms/step
# Epoch 90/200
# 12/12 - 0s - loss: 0.4598 - accuracy: 0.7859 - 35ms/epoch - 3ms/step
# Epoch 91/200
# 12/12 - 0s - loss: 0.4570 - accuracy: 0.7913 - 29ms/epoch - 2ms/step
# Epoch 92/200
# 12/12 - 0s - loss: 0.4547 - accuracy: 0.7859 - 33ms/epoch - 3ms/step
# Epoch 93/200
# 12/12 - 0s - loss: 0.4572 - accuracy: 0.7724 - 30ms/epoch - 3ms/step
# Epoch 94/200
# 12/12 - 0s - loss: 0.4419 - accuracy: 0.8103 - 31ms/epoch - 3ms/step
# Epoch 95/200
# 12/12 - 0s - loss: 0.4471 - accuracy: 0.7751 - 37ms/epoch - 3ms/step
# Epoch 96/200
# 12/12 - 0s - loss: 0.4612 - accuracy: 0.7778 - 28ms/epoch - 2ms/step
# Epoch 97/200
# 12/12 - 0s - loss: 0.4518 - accuracy: 0.7805 - 30ms/epoch - 2ms/step
# Epoch 98/200
# 12/12 - 0s - loss: 0.4500 - accuracy: 0.7886 - 30ms/epoch - 2ms/step
# Epoch 99/200
# 12/12 - 0s - loss: 0.4504 - accuracy: 0.7886 - 36ms/epoch - 3ms/step
# Epoch 100/200
# 12/12 - 0s - loss: 0.4548 - accuracy: 0.8130 - 36ms/epoch - 3ms/step
# Epoch 101/200
# 12/12 - 0s - loss: 0.4531 - accuracy: 0.7832 - 34ms/epoch - 3ms/step
# Epoch 102/200
# 12/12 - 0s - loss: 0.4440 - accuracy: 0.7832 - 39ms/epoch - 3ms/step
# Epoch 103/200
# 12/12 - 0s - loss: 0.4576 - accuracy: 0.7724 - 48ms/epoch - 4ms/step
# Epoch 104/200
# 12/12 - 0s - loss: 0.4392 - accuracy: 0.7995 - 31ms/epoch - 3ms/step
# Epoch 105/200
# 12/12 - 0s - loss: 0.4585 - accuracy: 0.7886 - 34ms/epoch - 3ms/step
# Epoch 106/200
# 12/12 - 0s - loss: 0.4481 - accuracy: 0.7859 - 30ms/epoch - 3ms/step
# Epoch 107/200
# 12/12 - 0s - loss: 0.4509 - accuracy: 0.7940 - 36ms/epoch - 3ms/step
# Epoch 108/200
# 12/12 - 0s - loss: 0.4506 - accuracy: 0.7805 - 30ms/epoch - 3ms/step
# Epoch 109/200
# 12/12 - 0s - loss: 0.4440 - accuracy: 0.7778 - 32ms/epoch - 3ms/step
# Epoch 110/200
# 12/12 - 0s - loss: 0.4442 - accuracy: 0.7886 - 35ms/epoch - 3ms/step
# Epoch 111/200
# 12/12 - 0s - loss: 0.4498 - accuracy: 0.7940 - 29ms/epoch - 2ms/step
# Epoch 112/200
# 12/12 - 0s - loss: 0.4330 - accuracy: 0.8103 - 30ms/epoch - 3ms/step
# Epoch 113/200
# 12/12 - 0s - loss: 0.4358 - accuracy: 0.8076 - 42ms/epoch - 3ms/step
# Epoch 114/200
# 12/12 - 0s - loss: 0.4428 - accuracy: 0.7886 - 30ms/epoch - 3ms/step
# Epoch 115/200
# 12/12 - 0s - loss: 0.4580 - accuracy: 0.7778 - 33ms/epoch - 3ms/step
# Epoch 116/200
# 12/12 - 0s - loss: 0.4291 - accuracy: 0.7859 - 41ms/epoch - 3ms/step
# Epoch 117/200
# 12/12 - 0s - loss: 0.4440 - accuracy: 0.7886 - 42ms/epoch - 4ms/step
# Epoch 118/200
# 12/12 - 0s - loss: 0.4442 - accuracy: 0.7913 - 29ms/epoch - 2ms/step
# Epoch 119/200
# 12/12 - 0s - loss: 0.4553 - accuracy: 0.7913 - 35ms/epoch - 3ms/step
# Epoch 120/200
# 12/12 - 0s - loss: 0.4559 - accuracy: 0.7778 - 36ms/epoch - 3ms/step
# Epoch 121/200
# 12/12 - 0s - loss: 0.4347 - accuracy: 0.7859 - 33ms/epoch - 3ms/step
# Epoch 122/200
# 12/12 - 0s - loss: 0.4308 - accuracy: 0.7913 - 32ms/epoch - 3ms/step
# Epoch 123/200
# 12/12 - 0s - loss: 0.4509 - accuracy: 0.7778 - 33ms/epoch - 3ms/step
# Epoch 124/200
# 12/12 - 0s - loss: 0.4414 - accuracy: 0.7995 - 31ms/epoch - 3ms/step
# Epoch 125/200
# 12/12 - 0s - loss: 0.4343 - accuracy: 0.7859 - 30ms/epoch - 2ms/step
# Epoch 126/200
# 12/12 - 0s - loss: 0.4417 - accuracy: 0.8103 - 33ms/epoch - 3ms/step
# Epoch 127/200
# 12/12 - 0s - loss: 0.4284 - accuracy: 0.7967 - 29ms/epoch - 2ms/step
# Epoch 128/200
# 12/12 - 0s - loss: 0.4408 - accuracy: 0.7995 - 31ms/epoch - 3ms/step
# Epoch 129/200
# 12/12 - 0s - loss: 0.4232 - accuracy: 0.7995 - 30ms/epoch - 3ms/step
# Epoch 130/200
# 12/12 - 0s - loss: 0.4371 - accuracy: 0.8022 - 34ms/epoch - 3ms/step
# Epoch 131/200
# 12/12 - 0s - loss: 0.4436 - accuracy: 0.7696 - 39ms/epoch - 3ms/step
# Epoch 132/200
# 12/12 - 0s - loss: 0.4390 - accuracy: 0.7940 - 30ms/epoch - 3ms/step
# Epoch 133/200
# 12/12 - 0s - loss: 0.4328 - accuracy: 0.7995 - 32ms/epoch - 3ms/step
# Epoch 134/200
# 12/12 - 0s - loss: 0.4369 - accuracy: 0.7913 - 28ms/epoch - 2ms/step
# Epoch 135/200
# 12/12 - 0s - loss: 0.4333 - accuracy: 0.7995 - 30ms/epoch - 3ms/step
# Epoch 136/200
# 12/12 - 0s - loss: 0.4338 - accuracy: 0.7696 - 37ms/epoch - 3ms/step
# Epoch 137/200
# 12/12 - 0s - loss: 0.4174 - accuracy: 0.8049 - 32ms/epoch - 3ms/step
# Epoch 138/200
# 12/12 - 0s - loss: 0.4338 - accuracy: 0.7805 - 32ms/epoch - 3ms/step
# Epoch 139/200
# 12/12 - 0s - loss: 0.4346 - accuracy: 0.7913 - 43ms/epoch - 4ms/step
# Epoch 140/200
# 12/12 - 0s - loss: 0.4172 - accuracy: 0.8184 - 34ms/epoch - 3ms/step
# Epoch 141/200
# 12/12 - 0s - loss: 0.4341 - accuracy: 0.8022 - 30ms/epoch - 3ms/step
# Epoch 142/200
# 12/12 - 0s - loss: 0.4387 - accuracy: 0.7886 - 33ms/epoch - 3ms/step
# Epoch 143/200
# 12/12 - 0s - loss: 0.4283 - accuracy: 0.7940 - 35ms/epoch - 3ms/step
# Epoch 144/200
# 12/12 - 0s - loss: 0.4267 - accuracy: 0.7940 - 32ms/epoch - 3ms/step
# Epoch 145/200
# 12/12 - 0s - loss: 0.4276 - accuracy: 0.8022 - 30ms/epoch - 3ms/step
# Epoch 146/200
# 12/12 - 0s - loss: 0.4176 - accuracy: 0.8076 - 41ms/epoch - 3ms/step
# Epoch 147/200
# 12/12 - 0s - loss: 0.4169 - accuracy: 0.7967 - 31ms/epoch - 3ms/step
# Epoch 148/200
# 12/12 - 0s - loss: 0.4263 - accuracy: 0.7832 - 31ms/epoch - 3ms/step
# Epoch 149/200
# 12/12 - 0s - loss: 0.4400 - accuracy: 0.7940 - 38ms/epoch - 3ms/step
# Epoch 150/200
# 12/12 - 0s - loss: 0.4291 - accuracy: 0.7967 - 39ms/epoch - 3ms/step
# Epoch 151/200
# 12/12 - 0s - loss: 0.4257 - accuracy: 0.7859 - 40ms/epoch - 3ms/step
# Epoch 152/200
# 12/12 - 0s - loss: 0.4025 - accuracy: 0.8157 - 34ms/epoch - 3ms/step
# Epoch 153/200
# 12/12 - 0s - loss: 0.4407 - accuracy: 0.7805 - 31ms/epoch - 3ms/step
# Epoch 154/200
# 12/12 - 0s - loss: 0.4357 - accuracy: 0.7913 - 31ms/epoch - 3ms/step
# Epoch 155/200
# 12/12 - 0s - loss: 0.4117 - accuracy: 0.7995 - 36ms/epoch - 3ms/step
# Epoch 156/200
# 12/12 - 0s - loss: 0.4138 - accuracy: 0.8049 - 39ms/epoch - 3ms/step
# Epoch 157/200
# 12/12 - 0s - loss: 0.4194 - accuracy: 0.8103 - 40ms/epoch - 3ms/step
# Epoch 158/200
# 12/12 - 0s - loss: 0.4227 - accuracy: 0.8022 - 30ms/epoch - 3ms/step
# Epoch 159/200
# 12/12 - 0s - loss: 0.4211 - accuracy: 0.8076 - 27ms/epoch - 2ms/step
# Epoch 160/200
# 12/12 - 0s - loss: 0.4141 - accuracy: 0.7940 - 31ms/epoch - 3ms/step
# Epoch 161/200
# 12/12 - 0s - loss: 0.4218 - accuracy: 0.8049 - 39ms/epoch - 3ms/step
# Epoch 162/200
# 12/12 - 0s - loss: 0.4273 - accuracy: 0.8049 - 31ms/epoch - 3ms/step
# Epoch 163/200
# 12/12 - 0s - loss: 0.4134 - accuracy: 0.8022 - 29ms/epoch - 2ms/step
# Epoch 164/200
# 12/12 - 0s - loss: 0.4305 - accuracy: 0.7778 - 31ms/epoch - 3ms/step
# Epoch 165/200
# 12/12 - 0s - loss: 0.4280 - accuracy: 0.7940 - 35ms/epoch - 3ms/step
# Epoch 166/200
# 12/12 - 0s - loss: 0.4091 - accuracy: 0.8130 - 30ms/epoch - 3ms/step
# Epoch 167/200
# 12/12 - 0s - loss: 0.4274 - accuracy: 0.7995 - 31ms/epoch - 3ms/step
# Epoch 168/200
# 12/12 - 0s - loss: 0.4239 - accuracy: 0.7913 - 30ms/epoch - 3ms/step
# Epoch 169/200
# 12/12 - 0s - loss: 0.4240 - accuracy: 0.8049 - 30ms/epoch - 2ms/step
# Epoch 170/200
# 12/12 - 0s - loss: 0.4221 - accuracy: 0.7913 - 31ms/epoch - 3ms/step
# Epoch 171/200
# 12/12 - 0s - loss: 0.4044 - accuracy: 0.8103 - 36ms/epoch - 3ms/step
# Epoch 172/200
# 12/12 - 0s - loss: 0.4193 - accuracy: 0.8103 - 35ms/epoch - 3ms/step
# Epoch 173/200
# 12/12 - 0s - loss: 0.4124 - accuracy: 0.8022 - 29ms/epoch - 2ms/step
# Epoch 174/200
# 12/12 - 0s - loss: 0.4251 - accuracy: 0.7967 - 30ms/epoch - 3ms/step
# Epoch 175/200
# 12/12 - 0s - loss: 0.4286 - accuracy: 0.7995 - 32ms/epoch - 3ms/step
# Epoch 176/200
# 12/12 - 0s - loss: 0.4248 - accuracy: 0.7940 - 34ms/epoch - 3ms/step
# Epoch 177/200
# 12/12 - 0s - loss: 0.4139 - accuracy: 0.7913 - 30ms/epoch - 2ms/step
# Epoch 178/200
# 12/12 - 0s - loss: 0.4208 - accuracy: 0.7940 - 32ms/epoch - 3ms/step
# Epoch 179/200
# 12/12 - 0s - loss: 0.4045 - accuracy: 0.8022 - 31ms/epoch - 3ms/step
# Epoch 180/200
# 12/12 - 0s - loss: 0.4228 - accuracy: 0.7995 - 29ms/epoch - 2ms/step
# Epoch 181/200
# 12/12 - 0s - loss: 0.4155 - accuracy: 0.8076 - 30ms/epoch - 3ms/step
# Epoch 182/200
# 12/12 - 0s - loss: 0.4285 - accuracy: 0.7859 - 32ms/epoch - 3ms/step
# Epoch 183/200
# 12/12 - 0s - loss: 0.4167 - accuracy: 0.8049 - 35ms/epoch - 3ms/step
# Epoch 184/200
# 12/12 - 0s - loss: 0.4134 - accuracy: 0.7967 - 32ms/epoch - 3ms/step
# Epoch 185/200
# 12/12 - 0s - loss: 0.3969 - accuracy: 0.8157 - 34ms/epoch - 3ms/step
# Epoch 186/200
# 12/12 - 0s - loss: 0.4223 - accuracy: 0.7940 - 30ms/epoch - 3ms/step
# Epoch 187/200
# 12/12 - 0s - loss: 0.4238 - accuracy: 0.7696 - 29ms/epoch - 2ms/step
# Epoch 188/200
# 12/12 - 0s - loss: 0.4256 - accuracy: 0.7913 - 36ms/epoch - 3ms/step
# Epoch 189/200
# 12/12 - 0s - loss: 0.4223 - accuracy: 0.7940 - 36ms/epoch - 3ms/step
# Epoch 190/200
# 12/12 - 0s - loss: 0.4243 - accuracy: 0.7940 - 29ms/epoch - 2ms/step
# Epoch 191/200
# 12/12 - 0s - loss: 0.4125 - accuracy: 0.8211 - 35ms/epoch - 3ms/step
# Epoch 192/200
# 12/12 - 0s - loss: 0.4217 - accuracy: 0.8022 - 38ms/epoch - 3ms/step
# Epoch 193/200
# 12/12 - 0s - loss: 0.4211 - accuracy: 0.8049 - 33ms/epoch - 3ms/step
# Epoch 194/200
# 12/12 - 0s - loss: 0.4130 - accuracy: 0.7995 - 45ms/epoch - 4ms/step
# Epoch 195/200
# 12/12 - 0s - loss: 0.4014 - accuracy: 0.8103 - 42ms/epoch - 3ms/step
# Epoch 196/200
# 12/12 - 0s - loss: 0.4068 - accuracy: 0.8103 - 48ms/epoch - 4ms/step
# Epoch 197/200
# 12/12 - 0s - loss: 0.4173 - accuracy: 0.7886 - 40ms/epoch - 3ms/step
# Epoch 198/200
# 12/12 - 0s - loss: 0.4024 - accuracy: 0.8211 - 43ms/epoch - 4ms/step
# Epoch 199/200
# 12/12 - 0s - loss: 0.4131 - accuracy: 0.8022 - 41ms/epoch - 3ms/step
# Epoch 200/200
# 12/12 - 0s - loss: 0.4027 - accuracy: 0.8184 - 34ms/epoch - 3ms/step

# %%
print("--Evaluate model--")
model_loss1, model_acc1 = model.evaluate(x_train,  y_train, verbose=2)
model_loss2, model_acc2 = model.evaluate(x_test,  y_test, verbose=2)
print(f"Train / Test Accuracy: {model_acc1*100:.1f}% / {model_acc2*100:.1f}%")
# Out:
# --Evaluate model--
# 12/12 - 0s - loss: 0.3816 - accuracy: 0.8184 - 39ms/epoch - 3ms/step
# 3/3 - 0s - loss: 0.4924 - accuracy: 0.7634 - 27ms/epoch - 9ms/step
# Train / Test Accuracy: 81.8% / 76.3%

# %%
#Ran this to save my model
model.save('CHD_Model.h5') #Changed name so it doesnt overwrite my current
#76.3% accuracy model

# %% [markdown]
# # New Section
